# %% [markdown]
# newgrp docker
#
# ./start-simulation.sh

# %% [markdown]
# ## Stop and Wait

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
total_packet_delay = 0
packetCount = 0

# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    seq_id = 0
    sent_empty = False

    # Run a timer for throughput
    while True:
        
        timeoutDuration = 1
        udp_socket.settimeout(1)
        
        # construct message
        # sequence id of length SEQ_ID_SIZE + message of remaining PACKET_SIZE - SEQ_ID_SIZE bytes
        message = int.to_bytes(seq_id, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id : seq_id + MESSAGE_SIZE]

        # constructs the empty packet if we have sent all previous data
        if seq_id > len(data) and not sent_empty:
            message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
            sent_empty = True
            
        # send message
        udp_socket.sendto(message, ('localhost', 5001))
        packet_delay = time()
        packetCount += 1
        
        # wait for acknowledgement
        ack_id = 0
        while True:
            try:
                # wait for ack
                ack, _ = udp_socket.recvfrom(PACKET_SIZE)
                total_packet_delay += time() - packet_delay

                # extract ack id
                ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
                
                if ack_id != len(data) or not sent_empty:
                    break
                
            except socket.timeout:
                # no ack received, resend unacked message
                timeoutDuration += timeoutDuration
                udp_socket.settimeout(timeoutDuration)
                udp_socket.sendto(message, ('localhost', 5001))
          
        if ack_id == len(data) + 3:
            break
    
        # move sequence id forward
        seq_id += MESSAGE_SIZE      

    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()
    
    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = total_packet_delay / packetCount

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')
    
    # close the connection
    udp_socket.close()
# Out:
# 10091.86, 0.1, 100103.51

# %% [markdown]
# Output: 9898.89, 0.1, 97115.41 8.57s

# %% [markdown]
# # Sliding Window

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
# total packets to send
WINDOW_SIZE = 100

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 0.1
    udp_socket.settimeout(0.1)

    seq_id = 0
    sent_empty = False
    windowSpace = WINDOW_SIZE

    startTimes = {}
    endTimes = {}

    dupCount = 0
    prevAck = 0
    retransmitted = False

    acks = {}
    messages = []

    # start sending data from 0th sequence
    ack_id = 0
    while True:

        for _ in range(windowSpace):
            message = int.to_bytes(seq_id, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id: seq_id + MESSAGE_SIZE]
            
            # constructs the empty packet if we have sent all previous data
            if seq_id > len(data) and not sent_empty:
                message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
                sent_empty = True
            
            messages.append((seq_id, message))
            acks[seq_id] = False
            
            if seq_id not in startTimes:
                startTimes[seq_id] = time()

            udp_socket.sendto(message, ('localhost', 5001))

            seq_id += MESSAGE_SIZE
            windowSpace -= 1

            if len(message) == 0:
                break
            
        try:
            
            ack, _ = udp_socket.recvfrom(PACKET_SIZE)
            
            ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
            ack_message = ack[SEQ_ID_SIZE:]
            
            if ack_message == b'fin':
                break

            # update acks below cumulative ack
            for a in acks:
                if a < ack_id and acks[a] != True:
                    acks[a] = True
                    windowSpace += 1
                    if a not in endTimes:
                            endTimes[a] = time()

            if prevAck == ack_id and not retransmitted:
                dupCount += 1

                if dupCount == 3:
                    raise socket.timeout
            else:
                prevAck = ack_id
                dupCount = 0
                retransmitted = False

                timeoutDuration = 0.1
                udp_socket.settimeout(0.1)
                
        except socket.timeout:

            # no ack received, resend unacked messages
            for sid, message in messages:
                if not acks[sid]:
                    udp_socket.sendto(message, ('localhost', 5001))
                    startTimes[ack_id] = time()
                    retransmitted = True
                    break

            # Doubles timeout duration
            timeoutDuration += timeoutDuration
            udp_socket.settimeout(timeoutDuration)
     
    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()

    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))   
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = 0
    for k in endTimes.keys():
        packet_delay = endTimes[k] - startTimes[k]
        avg_packet_delay += packet_delay

    avg_packet_delay /= len(endTimes.keys())

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')

    # close the connection
    udp_socket.close()
# Out:
# 81811.56, 1.22, 67080.23

# %% [markdown]
# Output: 79425.86, 1.22, 65279.71 1m 6s

# %% [markdown]
# ## TCP Tahoe

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
# total packets to send
WINDOW_SIZE = 1

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 0.1
    udp_socket.settimeout(0.1)

    seq_id = 0
    sent_empty = False

    startTimes = {}
    endTimes = {}

    dupCount = 0
    prevAck = 0
    timeout = False

    cwnd = WINDOW_SIZE
    ssthresh = 64
    
    # start sending data from 0th sequence
    ack_id = 0
    while seq_id < len(data):

        messages = []
        acks = {}

        seq_id_tmp = seq_id
        for i in range(cwnd):

            if sent_empty:
                break
            
            # construct messages
            message = int.to_bytes(seq_id_tmp, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id_tmp : seq_id_tmp + MESSAGE_SIZE]
            
            # constructs the empty packet if we have sent all previous data
            if seq_id_tmp > len(data) and not sent_empty:
                message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
                sent_empty = True

            messages.append((seq_id_tmp, message))
            acks[seq_id_tmp] = False

            if seq_id_tmp not in startTimes:
                startTimes[seq_id_tmp] = time()

            udp_socket.sendto(message, ('localhost', 5001))

            # move seq_id tmp pointer ahead
            seq_id_tmp += MESSAGE_SIZE
            
        # wait for acknowledgement
        retransmitted = False
        while True:
            
            try:
                # wait for ack
                ack, _ = udp_socket.recvfrom(PACKET_SIZE)
                # extract ack id
                ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
                ack_message = ack[SEQ_ID_SIZE:]
            
                if ack_message == b'fin':
                    break

                # update acks below cumulative ack
                for a in acks:
                    if a < ack_id and acks[a] != True:
                        acks[a] = True
                        if a not in endTimes:
                                endTimes[a] = time()
                
                if prevAck == ack_id and not retransmitted:
                    dupCount += 1

                    if dupCount == 3:
                        raise socket.timeout
                else:
                    prevAck = ack_id
                    dupCount = 0
                    retransmitted = False

                    timeoutDuration = 0.1
                    udp_socket.settimeout(0.1)
                
                # all acks received, move on
                if all(acks.values()):

                    if not timeout:
                        if cwnd >= ssthresh:
                            cwnd += 1
                        else:
                            cwnd += cwnd
                    else:
                        cwnd = 1

                    timeout = False

                    break

            except socket.timeout:

                timeout = True

                # no ack received, resend unacked messages
                for sid, message in messages:
                    if not acks[sid]:
                        udp_socket.sendto(message, ('localhost', 5001))
                        startTimes[ack_id] = time()
                        retransmitted = True
                        break
                
                # Halfs the slow start threshhold and resets window size
                ssthresh = max(cwnd // 2, 1)

                # Doubles timeout duration
                timeoutDuration += timeoutDuration
                udp_socket.settimeout(timeoutDuration)
                
        # move sequence id forward
        seq_id = seq_id_tmp
        
    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()

    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))   
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = 0
    for k in endTimes.keys():
        packet_delay = endTimes[k] - startTimes[k]
        avg_packet_delay += packet_delay

    avg_packet_delay /= len(endTimes.keys())

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')

    # close the connection
    udp_socket.close()
# Out:
# 14871.93, 0.06, 248577.35

# %% [markdown]
# Output: 20060.41, 0.1, 203374.25 4m 25s

# %% [markdown]
# ## TCP Reno

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
# total packets to send
WINDOW_SIZE = 1

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 0.1
    udp_socket.settimeout(0.1)

    seq_id = 0
    sent_empty = False

    startTimes = {}
    endTimes = {}

    dupCount = 0
    prevAck = 0

    dupAck = False
    timeout = False

    cwnd = WINDOW_SIZE
    ssthresh = 64
    
    # start sending data from 0th sequence
    ack_id = 0
    while seq_id < len(data):

        messages = []
        acks = {}

        seq_id_tmp = seq_id
        for i in range(cwnd):

            if sent_empty:
                break

            # construct messages
            message = int.to_bytes(seq_id_tmp, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id_tmp : seq_id_tmp + MESSAGE_SIZE]
            
            # constructs the empty packet if we have sent all previous data
            if seq_id_tmp > len(data) and not sent_empty:
                message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
                sent_empty = True

            messages.append((seq_id_tmp, message))
            acks[seq_id_tmp] = False

            if seq_id_tmp not in startTimes:
                startTimes[seq_id_tmp] = time()

            udp_socket.sendto(message, ('localhost', 5001))

            # move seq_id tmp pointer ahead
            seq_id_tmp += MESSAGE_SIZE
            
        # wait for acknowledgement
        retransmitted = False
        while True:
            
            try:
                # wait for ack
                ack, _ = udp_socket.recvfrom(PACKET_SIZE)
                # extract ack id
                ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
                ack_message = ack[SEQ_ID_SIZE:]
                
                if ack_message == b'fin':
                    break

                # update acks below cumulative ack
                for a in acks:
                    if a < ack_id and acks[a] != True:
                        acks[a] = True
                        if a not in endTimes:
                                endTimes[a] = time()
                
                if prevAck == ack_id and not retransmitted:
                    dupCount += 1

                    if dupCount == 3:
                        dupAck = True
                        raise socket.timeout
                else:
                    prevAck = ack_id
                    dupCount = 0
                    retransmitted = False

                    timeoutDuration = 0.1
                    udp_socket.settimeout(0.1)
                
                # all acks received, move on
                if all(acks.values()):

                    if not timeout:
                        if cwnd >= ssthresh:
                            cwnd += 1
                        else:
                            cwnd += cwnd
                    else:
                        if dupAck:
                            cwnd = ssthresh
                        else:
                            cwnd = 1

                    timeout = False
                    dupAck = False

                    break

            except socket.timeout:

                timeout = True

                # no ack received, resend unacked messages
                for sid, message in messages:
                    if not acks[sid]:
                        udp_socket.sendto(message, ('localhost', 5001))
                        startTimes[ack_id] = time()
                        retransmitted = True
                        break
                
                # Halfs the slow start threshhold and resets window size
                ssthresh = max(cwnd // 2, 1)

                # Doubles timeout duration
                timeoutDuration += timeoutDuration
                udp_socket.settimeout(timeoutDuration)
                
        # move sequence id forward
        seq_id = seq_id_tmp
        
    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()

    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))   
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = 0
    for k in endTimes.keys():
        packet_delay = endTimes[k] - startTimes[k]
        avg_packet_delay += packet_delay

    avg_packet_delay /= len(endTimes.keys())

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')

    # close the connection
    udp_socket.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/a/Documents/Project3/ecs152a-project3/tester.ipynb Cell 12 line 8
#      <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=78'>79</a> while True:
#      <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=80'>81</a>     try:
#      <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=81'>82</a>         # wait for ack
# ---> <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=82'>83</a>         ack, _ = udp_socket.recvfrom(PACKET_SIZE)
#      <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=83'>84</a>         # extract ack id
#      <a href='vscode-notebook-cell:/home/a/Documents/Project3/ecs152a-project3/tester.ipynb#X14sZmlsZQ%3D%3D?line=84'>85</a>         ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
#
# KeyboardInterrupt:

# %% [markdown]
# Output: 23635.09, 0.14, 169931.68 3m 45s

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
# total packets to send
WINDOW_SIZE = 1


# Vegas' buffer window; 2 KB/s and 4 KB/s
alpha = 2000
beta = 4000

# Congestion Avoidance trigger
delta = 1000

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()

def increaseInterval(cwnd):
    cwnd += cwnd
    return cwnd

def evaluationInterval(diff):
    if diff <= delta:
        return False
    else:
        return True

# Determine cwnd with Vegas protocol
def congestionInterval(extra_data, cwnd):
    # If between thresholds, cwnd is not updated.
    if (extra_data < alpha):
        cwnd += 1
    elif (extra_data > beta):
        cwnd -= 1
    
    return cwnd
 
# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 0.1
    udp_socket.settimeout(timeoutDuration)

    seq_id = 0
    sent_empty = False

    startTimes = {}
    endTimes = {}

    dupCount = 0
    prevAck = 0
    timeout = False

    cwnd = WINDOW_SIZE

    # vegas protocol that follows a retransmission. check if next 2 also need retransmission
    checkNext2 = 3
    
    # Allow storage of lowest (optimal) RTT seen so far. 
    baseRTT = float('inf')

    isCongest = False

    switchInterval = True

    # start sending data from 0th sequence
    ack_id = 0
    while seq_id < len(data):

        messages = []
        acks = {}

        seq_id_tmp = seq_id
        for i in range(cwnd):

            if sent_empty:
                break
            
            # construct messages
            message = int.to_bytes(seq_id_tmp, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id_tmp : seq_id_tmp + MESSAGE_SIZE]
            
            # constructs the empty packet if we have sent all previous data
            if seq_id_tmp > len(data) and not sent_empty:
                message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
                sent_empty = True

            messages.append((seq_id_tmp, message))
            acks[seq_id_tmp] = False
            
            udp_socket.sendto(message, ('localhost', 5001))

            if seq_id_tmp not in startTimes:
                startTimes[seq_id_tmp] = time()

            # move seq_id tmp pointer ahead
            seq_id_tmp += MESSAGE_SIZE
            
        # wait for acknowledgement
        retransmitted = False
        while True:
            
            try:
                # wait for ack
                ack, _ = udp_socket.recvfrom(PACKET_SIZE)
                # extract ack id
                ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
                ack_message = ack[SEQ_ID_SIZE:]

                if ack_message == b'fin':
                    break

                # Measure current time for RTT calculations and comparisons
                currentTime = time()

                # ACK returned has an ID corresponding to the next ID. So need to make an adjustment
                actual_ack = ack_id - MESSAGE_SIZE
                # Compute various delay values to be used in Vegas
                # Determine BaseRTT
                if actual_ack in startTimes:
                    if currentTime - startTimes[actual_ack] < baseRTT:
                        baseRTT = currentTime - startTimes[actual_ack]

                    # Determine currentRTT
                    currentRTT = currentTime - startTimes[actual_ack]
                
                # Determine expected and actual throughput
                expected = cwnd / baseRTT
                actual = cwnd / currentRTT
                
                # monitor extra data
                extra_data = (expected - actual) * baseRTT

                # diff
                diff = expected - actual
                
                # update acks below cumulative ack
                for a in acks:
                    if a < ack_id and acks[a] != True:
                        acks[a] = True
                        if a not in endTimes:
                                endTimes[a] = currentTime
                
                # monitor next 2 packets following retransmission
                """if checkNext2 < 3:
                    if checkNext2 != 0:
                        checkNext2 -= 1
                        if currentTime - startTimes[actual_ack] >= timeoutDuration:
                            raise socket.timeout
                    else:
                        checkNext2 = 3"""

                # duplicate detected
                if prevAck == ack_id and not retransmitted:
                    """ # does estimated RTT exceed RTO?
                    if currentTime - startTimes[actual_ack] >= timeoutDuration:
                        checkNext2 -= 1
                        raise socket.timeout
                    # If not, 3xACK still applies
                    else: """
                    dupCount += 1

                    if dupCount == 3:
                        #checkNext2 -= 1
                        raise socket.timeout
                # no duplicate detected 
                else:
                    prevAck = ack_id
                    dupCount = 0
                    retransmitted = False

                    timeoutDuration = 0.1
                    udp_socket.settimeout(0.1)
                
                # all acks received, move on
                if all(acks.values()):

                    # update congestion window
                    if not timeout:
                        # Congestion Avoidance
                        if isCongest:
                            cwnd = congestionInterval(extra_data, cwnd)
                            
                        # Slow Start
                        else:

                            # Next slow-start round: evaluation or increase?
                            if switchInterval:
                                cwnd = increaseInterval(cwnd)
                                switchInterval = False
                    
                            else:
                                isCongest = evaluationInterval(diff)
                                switchInterval = True

                    timeout = False
                    
                    break

            except socket.timeout:

                timeout = True

                # no ack received, resend unacked messages
                for sid, message in messages:
                    if not acks[sid]:
                        udp_socket.sendto(message, ('localhost', 5001))
                        startTimes[ack_id] = time()
                        retransmitted = True
                        break

                # Doubles timeout duration
                timeoutDuration += timeoutDuration
                udp_socket.settimeout(timeoutDuration)
                
        # move sequence id forward
        seq_id = seq_id_tmp
        
    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()

    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))   
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = 0
    for k in endTimes.keys():
        packet_delay = endTimes[k] - startTimes[k]
        avg_packet_delay += packet_delay

    avg_packet_delay /= len(endTimes.keys())

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')

    # close the connection
    udp_socket.close()
# Out:
# ack_id recv: 1020
# ack_id recv: 1020
# ack_id recv: 2040
# ack_id recv: 2040
# ack_id recv: 3060
# ack_id recv: 4080
# ack_id recv: 5100
# ack_id recv: 5100
# ack_id recv: 6120
# ack_id recv: 7140
# ack_id recv: 7140
# ack_id recv: 8160
# ack_id recv: 9180
# ack_id recv: 10200
# ack_id recv: 11220
# ack_id recv: 11220
# ack_id recv: 12240
# ack_id recv: 13260
# ack_id recv: 14280
# ack_id recv: 15300
# ack_id recv: 16320
# ack_id recv: 17340
# ack_id recv: 18360
# ack_id recv: 19380
# ack_id recv: 20400
# ack_id recv: 21420
# ack_id recv: 22440
# ack_id recv: 23460
# ack_id recv: 24480
# ack_id recv: 25500
# ack_id recv: 26520
# ack_id recv: 27540
# ack_id recv: 28560
# ack_id recv: 29580
# ack_id recv: 30600
# ack_id recv: 31620
# ack_id recv: 32640
# ack_id recv: 33660
# ack_id recv: 34680
# ack_id recv: 35700
# ack_id recv: 36720
# ack_id recv: 37740
# ack_id recv: 38760
# ack_id recv: 39780
# ack_id recv: 40800
# ack_id recv: 41820
# ack_id recv: 42840
# ack_id recv: 43860
# ack_id recv: 44880
# ack_id recv: 45900
# ack_id recv: 46920
# ack_id recv: 46920
# ack_id recv: 47940
# ack_id recv: 48960
# ack_id recv: 49980
# ack_id recv: 51000
# ack_id recv: 52020
# ack_id recv: 53040
# ack_id recv: 54060
# ack_id recv: 55080
# ack_id recv: 56100
# ack_id recv: 57120
# ack_id recv: 58140
# ack_id recv: 59160
# ack_id recv: 60180
# ack_id recv: 61200
# ack_id recv: 62220
# ack_id recv: 63240
# ack_id recv: 64260
# ack_id recv: 64260
# ack_id recv: 65280
# ack_id recv: 66300
# ack_id recv: 67320
# ack_id recv: 68340
# ack_id recv: 69360
# ack_id recv: 70380
# ack_id recv: 71400
# ack_id recv: 72420
# ack_id recv: 73440
# ack_id recv: 73440
# ack_id recv: 74460
# ack_id recv: 75480
# ack_id recv: 76500
# ack_id recv: 77520
# ack_id recv: 78540
# ack_id recv: 79560
# ack_id recv: 80580
# ack_id recv: 81600
# ack_id recv: 82620
# ack_id recv: 83640
# ack_id recv: 84660
# ack_id recv: 85680
# ack_id recv: 86700
# ack_id recv: 87720
# ack_id recv: 88740
# ack_id recv: 89760
# ack_id recv: 90780
# ack_id recv: 91800
# ack_id recv: 92820
# ack_id recv: 92820
# ack_id recv: 93840
# ack_id recv: 94860
# ack_id recv: 95880
# ack_id recv: 96900
# ack_id recv: 97920
# ack_id recv: 98940
# ack_id recv: 99960
# ack_id recv: 100980
# ack_id recv: 102000
# ack_id recv: 103020
# ack_id recv: 104040
# ack_id recv: 105060
# ack_id recv: 106080
# ack_id recv: 107100
# ack_id recv: 108120
# ack_id recv: 109140
# ack_id recv: 110160
# ack_id recv: 111180
# ack_id recv: 112200
# ack_id recv: 113220
# ack_id recv: 114240
# ack_id recv: 114240
# ack_id recv: 115260
# ack_id recv: 116280
# ack_id recv: 117300
# ack_id recv: 118320
# ack_id recv: 119340
# ack_id recv: 120360
# ack_id recv: 121380
# ack_id recv: 122400
# ack_id recv: 123420
# ack_id recv: 124440
# ack_id recv: 125460
# ack_id recv: 126480
# ack_id recv: 127500
# ack_id recv: 128520
# ack_id recv: 129540
# ack_id recv: 130560
# ack_id recv: 131580
# ack_id recv: 132600
# ack_id recv: 133620
# ack_id recv: 134640
# ack_id recv: 135660
# ack_id recv: 136680
# ack_id recv: 137700
# ack_id recv: 137700
# ack_id recv: 138720
# ack_id recv: 139740
# ack_id recv: 140760
# ack_id recv: 141780
# ack_id recv: 142800
# ack_id recv: 143820
# ack_id recv: 144840
# ack_id recv: 145860
# ack_id recv: 146880
# ack_id recv: 147900
# ack_id recv: 148920
# ack_id recv: 149940
# ack_id recv: 149940
# ack_id recv: 150960
# ack_id recv: 151980
# ack_id recv: 153000
# ack_id recv: 154020
# ack_id recv: 155040
# ack_id recv: 156060
# ack_id recv: 157080
# ack_id recv: 158100
# ack_id recv: 159120
# ack_id recv: 160140
# ack_id recv: 161160
# ack_id recv: 162180
# ack_id recv: 163200
# ack_id recv: 164220
# ack_id recv: 165240
# ack_id recv: 166260
# ack_id recv: 167280
# ack_id recv: 168300
# ack_id recv: 169320
# ack_id recv: 170340
# ack_id recv: 171360
# ack_id recv: 172380
# ack_id recv: 173400
# ack_id recv: 174420
# ack_id recv: 175440
# ack_id recv: 175440
# ack_id recv: 176460
# ack_id recv: 177480
# ack_id recv: 178500
# ack_id recv: 179520
# ack_id recv: 180540
# ack_id recv: 181560
# ack_id recv: 182580
# ack_id recv: 183600
# ack_id recv: 184620
# ack_id recv: 185640
# ack_id recv: 186660
# ack_id recv: 187680
# ack_id recv: 188700
# ack_id recv: 189720
# ack_id recv: 190740
# ack_id recv: 191760
# ack_id recv: 192780
# ack_id recv: 193800
# ack_id recv: 194820
# ack_id recv: 195840
# ack_id recv: 196860
# ack_id recv: 197880
# ack_id recv: 198900
# ack_id recv: 199920
# ack_id recv: 200940
# ack_id recv: 201960
# ack_id recv: 202980
# ack_id recv: 204000
# ack_id recv: 205020
# ack_id recv: 206040
# ack_id recv: 207060
# ack_id recv: 208080
# ack_id recv: 209100
# ack_id recv: 210120
# ack_id recv: 211140
# ack_id recv: 212160
# ack_id recv: 213180
# ack_id recv: 214200
# ack_id recv: 215220
# ack_id recv: 216240
# ack_id recv: 217260
# ack_id recv: 218280
# ack_id recv: 219300
# ack_id recv: 220320
# ack_id recv: 221340
# ack_id recv: 222360
# ack_id recv: 223380
# ack_id recv: 224400
# ack_id recv: 225420
# ack_id recv: 226440
# ack_id recv: 227460
# ack_id recv: 228480
# ack_id recv: 229500
# ack_id recv: 230520
# ack_id recv: 231540
# ack_id recv: 232560
# ack_id recv: 233580
# ack_id recv: 234600
# ack_id recv: 235620
# ack_id recv: 236640
# ack_id recv: 237660
# ack_id recv: 238680
# ack_id recv: 239700
# ack_id recv: 240720
# ack_id recv: 241740
# ack_id recv: 242760
# ack_id recv: 243780
# ack_id recv: 244800
# ack_id recv: 245820
# ack_id recv: 246840
# ack_id recv: 247860
# ack_id recv: 248880
# ack_id recv: 249900
# ack_id recv: 250920
# ack_id recv: 251940
# ack_id recv: 252960
# ack_id recv: 253980
# ack_id recv: 255000
# ack_id recv: 256020
# ack_id recv: 257040
# ack_id recv: 258060
# ack_id recv: 259080
# ack_id recv: 260100
# ack_id recv: 261120
# ack_id recv: 262140
# ack_id recv: 263160
# ack_id recv: 264180
# ack_id recv: 265200
# ack_id recv: 266220
# ack_id recv: 267240
# ack_id recv: 268260
# ack_id recv: 269280
# ack_id recv: 270300
# ack_id recv: 271320
# ack_id recv: 272340
# ack_id recv: 273360
# ack_id recv: 274380
# ack_id recv: 275400
# ack_id recv: 276420
# ack_id recv: 277440
# ack_id recv: 278460
# ack_id recv: 279480
# ack_id recv: 280500
# ack_id recv: 281520
# ack_id recv: 282540
# ack_id recv: 283560
# ack_id recv: 284580
# ack_id recv: 285600
# ack_id recv: 286620
# ack_id recv: 287640
# ack_id recv: 288660
# ack_id recv: 289680
# ack_id recv: 290700
# ack_id recv: 291720
# ack_id recv: 292740
# ack_id recv: 293760
# ack_id recv: 294780
# ack_id recv: 295800
# ack_id recv: 296820
# ack_id recv: 297840
# ack_id recv: 298860
# ack_id recv: 299880
# ack_id recv: 300900
# ack_id recv: 301920
# ack_id recv: 302940
# ack_id recv: 303960
# ack_id recv: 304980
# ack_id recv: 306000
# ack_id recv: 307020
# ack_id recv: 308040
# ack_id recv: 309060
# ack_id recv: 310080
# ack_id recv: 310080
# ack_id recv: 311100
# ack_id recv: 312120
# ack_id recv: 313140
# ack_id recv: 314160
# ack_id recv: 315180
# ack_id recv: 316200
# ack_id recv: 317220
# ack_id recv: 318240
# ack_id recv: 319260
# ack_id recv: 320280
# ack_id recv: 321300
# ack_id recv: 322320
# ack_id recv: 323340
# ack_id recv: 324360
# ack_id recv: 325380
# ack_id recv: 326400
# ack_id recv: 327420
# ack_id recv: 328440
# ack_id recv: 329460
# ack_id recv: 330480
# ack_id recv: 331500
# ack_id recv: 332520
# ack_id recv: 333540
# ack_id recv: 334560
# ack_id recv: 335580
# ack_id recv: 336600
# ack_id recv: 337620
# ack_id recv: 338640
# ack_id recv: 339660
# ack_id recv: 340680
# ack_id recv: 341700
# ack_id recv: 342720
# ack_id recv: 343740
# ack_id recv: 344760
# ack_id recv: 345780
# ack_id recv: 346800
# ack_id recv: 347820
# ack_id recv: 348840
# ack_id recv: 349860
# ack_id recv: 350880
# ack_id recv: 351900
# ack_id recv: 352920
# ack_id recv: 353940
# ack_id recv: 354960
# ack_id recv: 355980
# ack_id recv: 357000
# ack_id recv: 358020
# ack_id recv: 359040
# ack_id recv: 360060
# ack_id recv: 361080
# ack_id recv: 362100
# ack_id recv: 363120
# ack_id recv: 364140
# ack_id recv: 365160
# ack_id recv: 366180
# ack_id recv: 367200
# ack_id recv: 368220
# ack_id recv: 369240
# ack_id recv: 370260
# ack_id recv: 371280
# ack_id recv: 372300
# ack_id recv: 373320
# ack_id recv: 374340
# ack_id recv: 375360
# ack_id recv: 376380
# ack_id recv: 377400
# ack_id recv: 378420
# ack_id recv: 379440
# ack_id recv: 380460
# ack_id recv: 381480
# ack_id recv: 382500
# ack_id recv: 383520
# ack_id recv: 384540
# ack_id recv: 385560
# ack_id recv: 386580
# ack_id recv: 387600
# ack_id recv: 388620
# ack_id recv: 389640
# ack_id recv: 390660
# ack_id recv: 391680
# ack_id recv: 392700
# ack_id recv: 393720
# ack_id recv: 394740
# ack_id recv: 395760
# ack_id recv: 396780
# ack_id recv: 397800
# ack_id recv: 398820
# ack_id recv: 399840
# ack_id recv: 400860
# ack_id recv: 401880
# ack_id recv: 402900
# ack_id recv: 403920
# ack_id recv: 404940
# ack_id recv: 405960
# ack_id recv: 406980
# ack_id recv: 408000
# ack_id recv: 409020
# ack_id recv: 410040
# ack_id recv: 411060
# ack_id recv: 412080
# ack_id recv: 413100
# ack_id recv: 414120
# ack_id recv: 415140
# ack_id recv: 416160
# ack_id recv: 417180
# ack_id recv: 418200
# ack_id recv: 419220
# ack_id recv: 420240
# ack_id recv: 421260
# ack_id recv: 422280
# ack_id recv: 422280
# ack_id recv: 422280
# ack_id recv: 422280
# ack_id recv: 422280
# ack_id recv: 422280
# ack_id recv: 423300
# ack_id recv: 424320
# ack_id recv: 425340
# ack_id recv: 426360
# ack_id recv: 427380
# ack_id recv: 428400
# ack_id recv: 429420
# ack_id recv: 430440
# ack_id recv: 431460
# ack_id recv: 432480
# ack_id recv: 433500
# ack_id recv: 434520
# ack_id recv: 435540
# ack_id recv: 436560
# ack_id recv: 437580
# ack_id recv: 438600
# ack_id recv: 439620
# ack_id recv: 440640
# ack_id recv: 441660
# ack_id recv: 442680
# ack_id recv: 443700
# ack_id recv: 444720
# ack_id recv: 445740
# ack_id recv: 446760
# ack_id recv: 446760
# ack_id recv: 446760
# ack_id recv: 446760
# ack_id recv: 446760
# ack_id recv: 446760
# ack_id recv: 447780
# ack_id recv: 448800
# ack_id recv: 449820
# ack_id recv: 450840
# ack_id recv: 451860
# ack_id recv: 452880
# ack_id recv: 453900
# ack_id recv: 454920
# ack_id recv: 455940
# ack_id recv: 456960
# ack_id recv: 457980
# ack_id recv: 459000
# ack_id recv: 460020
# ack_id recv: 461040
# ack_id recv: 462060
# ack_id recv: 463080
# ack_id recv: 464100
# ack_id recv: 465120
# ack_id recv: 466140
# ack_id recv: 467160
# ack_id recv: 468180
# ack_id recv: 469200
# ack_id recv: 470220
# ack_id recv: 471240
# ack_id recv: 471240
# ack_id recv: 472260
# ack_id recv: 473280
# ack_id recv: 474300
# ack_id recv: 475320
# ack_id recv: 476340
# ack_id recv: 477360
# ack_id recv: 478380
# ack_id recv: 479400
# ack_id recv: 480420
# ack_id recv: 481440
# ack_id recv: 482460
# ack_id recv: 483480
# ack_id recv: 484500
# ack_id recv: 485520
# ack_id recv: 486540
# ack_id recv: 487560
# ack_id recv: 488580
# ack_id recv: 489600
# ack_id recv: 490620
# ack_id recv: 491640
# ack_id recv: 492660
# ack_id recv: 493680
# ack_id recv: 494700
# ack_id recv: 495720
# ack_id recv: 496740
# ack_id recv: 497760
# ack_id recv: 498780
# ack_id recv: 499800
# ack_id recv: 500820
# ack_id recv: 501840
# ack_id recv: 502860
# ack_id recv: 503880
# ack_id recv: 504900
# ack_id recv: 505920
# ack_id recv: 506940
# ack_id recv: 507960
# ack_id recv: 508980
# ack_id recv: 510000
# ack_id recv: 511020
# ack_id recv: 512040
# ack_id recv: 513060
# ack_id recv: 514080
# ack_id recv: 515100
# ack_id recv: 516120
# ack_id recv: 517140
# ack_id recv: 518160
# ack_id recv: 519180
# ack_id recv: 520200
# ack_id recv: 521220
# ack_id recv: 522240
# ack_id recv: 523260
# ack_id recv: 524280
# ack_id recv: 525300
# ack_id recv: 526320
# ack_id recv: 527340
# ack_id recv: 528360
# ack_id recv: 529380
# ack_id recv: 530400
# ack_id recv: 531420
# ack_id recv: 532440
# ack_id recv: 533460
# ack_id recv: 534480
# ack_id recv: 535500
# ack_id recv: 536520
# ack_id recv: 537540
# ack_id recv: 538560
# ack_id recv: 539580
# ack_id recv: 540600
# ack_id recv: 541620
# ack_id recv: 542640
# ack_id recv: 543660
# ack_id recv: 544680
# ack_id recv: 545700
# ack_id recv: 546720
# ack_id recv: 547740
# ack_id recv: 548760
# ack_id recv: 549780
# ack_id recv: 550800
# ack_id recv: 551820
# ack_id recv: 552840
# ack_id recv: 553860
# ack_id recv: 554880
# ack_id recv: 555900
# ack_id recv: 556920
# ack_id recv: 557940
# ack_id recv: 558960
# ack_id recv: 559980
# ack_id recv: 561000
# ack_id recv: 562020
# ack_id recv: 563040
# ack_id recv: 564060
# ack_id recv: 565080
# ack_id recv: 566100
# ack_id recv: 567120
# ack_id recv: 568140
# ack_id recv: 569160
# ack_id recv: 570180
# ack_id recv: 571200
# ack_id recv: 572220
# ack_id recv: 573240
# ack_id recv: 574260
# ack_id recv: 575280
# ack_id recv: 576300
# ack_id recv: 577320
# ack_id recv: 578340
# ack_id recv: 579360
# ack_id recv: 580380
# ack_id recv: 581400
# ack_id recv: 582420
# ack_id recv: 583440
# ack_id recv: 584460
# ack_id recv: 585480
# ack_id recv: 586500
# ack_id recv: 587520
# ack_id recv: 588540
# ack_id recv: 589560
# ack_id recv: 590580
# ack_id recv: 591600
# ack_id recv: 592620
# ack_id recv: 593640
# ack_id recv: 594660
# ack_id recv: 595680
# ack_id recv: 596700
# ack_id recv: 597720
# ack_id recv: 598740
# ack_id recv: 599760
# ack_id recv: 600780
# ack_id recv: 601800
# ack_id recv: 602820
# ack_id recv: 603840
# ack_id recv: 604860
# ack_id recv: 605880
# ack_id recv: 606900
# ack_id recv: 607920
# ack_id recv: 608940
# ack_id recv: 609960
# ack_id recv: 610980
# ack_id recv: 612000
# ack_id recv: 613020
# ack_id recv: 614040
# ack_id recv: 615060
# ack_id recv: 616080
# ack_id recv: 617100
# ack_id recv: 618120
# ack_id recv: 619140
# ack_id recv: 620160
# ack_id recv: 621180
# ack_id recv: 622200
# ack_id recv: 623220
# ack_id recv: 624240
# ack_id recv: 625260
# ack_id recv: 626280
# ack_id recv: 627300
# ack_id recv: 628320
# ack_id recv: 629340
# ack_id recv: 630360
# ack_id recv: 631380
# ack_id recv: 632400
# ack_id recv: 633420
# ack_id recv: 634440
# ack_id recv: 635460
# ack_id recv: 636480
# ack_id recv: 637500
# ack_id recv: 638520
# ack_id recv: 639540
# ack_id recv: 640560
# ack_id recv: 641580
# ack_id recv: 642600
# ack_id recv: 643620
# ack_id recv: 644640
# ack_id recv: 645660
# ack_id recv: 646680
# ack_id recv: 647700
# ack_id recv: 648720
# ack_id recv: 649740
# ack_id recv: 650760
# ack_id recv: 651780
# ack_id recv: 652800
# ack_id recv: 653820
# ack_id recv: 654840
# ack_id recv: 655860
# ack_id recv: 656880
# ack_id recv: 657900
# ack_id recv: 658920
# ack_id recv: 659940
# ack_id recv: 660960
# ack_id recv: 661980
# ack_id recv: 663000
# ack_id recv: 664020
# ack_id recv: 665040
# ack_id recv: 666060
# ack_id recv: 667080
# ack_id recv: 668100
# ack_id recv: 669120
# ack_id recv: 670140
# ack_id recv: 671160
# ack_id recv: 672180
# ack_id recv: 673200
# ack_id recv: 674220
# ack_id recv: 675240
# ack_id recv: 676260
# ack_id recv: 677280
# ack_id recv: 678300
# ack_id recv: 679320
# ack_id recv: 680340
# ack_id recv: 681360
# ack_id recv: 682380
# ack_id recv: 683400
# ack_id recv: 684420
# ack_id recv: 685440
# ack_id recv: 686460
# ack_id recv: 687480
# ack_id recv: 688500
# ack_id recv: 689520
# ack_id recv: 690540
# ack_id recv: 691560
# ack_id recv: 692580
# ack_id recv: 693600
# ack_id recv: 694620
# ack_id recv: 695640
# ack_id recv: 696660
# ack_id recv: 697680
# ack_id recv: 698700
# ack_id recv: 699720
# ack_id recv: 700740
# ack_id recv: 701760
# ack_id recv: 702780
# ack_id recv: 703800
# ack_id recv: 704820
# ack_id recv: 705840
# ack_id recv: 706860
# ack_id recv: 707880
# ack_id recv: 708900
# ack_id recv: 709920
# ack_id recv: 710940
# ack_id recv: 711960
# ack_id recv: 712980
# ack_id recv: 714000
# ack_id recv: 715020
# ack_id recv: 716040
# ack_id recv: 717060
# ack_id recv: 718080
# ack_id recv: 719100
# ack_id recv: 720120
# ack_id recv: 721140
# ack_id recv: 722160
# ack_id recv: 723180
# ack_id recv: 724200
# ack_id recv: 725220
# ack_id recv: 726240
# ack_id recv: 727260
# ack_id recv: 728280
# ack_id recv: 729300
# ack_id recv: 730320
# ack_id recv: 731340
# ack_id recv: 732360
# ack_id recv: 733380
# ack_id recv: 734400
# ack_id recv: 735420
# ack_id recv: 736440
# ack_id recv: 737460
# ack_id recv: 738480
# ack_id recv: 739500
# ack_id recv: 740520
# ack_id recv: 741540
# ack_id recv: 742560
# ack_id recv: 743580
# ack_id recv: 744600
# ack_id recv: 745620
# ack_id recv: 746640
# ack_id recv: 747660
# ack_id recv: 748680
# ack_id recv: 749700
# ack_id recv: 750720
# ack_id recv: 751740
# ack_id recv: 752760
# ack_id recv: 753780
# ack_id recv: 754800
# ack_id recv: 755820
# ack_id recv: 756840
# ack_id recv: 757860
# ack_id recv: 758880
# ack_id recv: 759900
# ack_id recv: 760920
# ack_id recv: 761940
# ack_id recv: 762960
# ack_id recv: 763980
# ack_id recv: 765000
# ack_id recv: 766020
# ack_id recv: 767040
# ack_id recv: 768060
# ack_id recv: 769080
# ack_id recv: 770100
# ack_id recv: 771120
# ack_id recv: 772140
# ack_id recv: 773160
# ack_id recv: 774180
# ack_id recv: 775200
# ack_id recv: 776220
# ack_id recv: 777240
# ack_id recv: 778260
# ack_id recv: 779280
# ack_id recv: 780300
# ack_id recv: 781320
# ack_id recv: 782340
# ack_id recv: 783360
# ack_id recv: 784380
# ack_id recv: 785400
# ack_id recv: 786420
# ack_id recv: 787440
# ack_id recv: 788460
# ack_id recv: 789480
# ack_id recv: 790500
# ack_id recv: 791520
# ack_id recv: 792540
# ack_id recv: 793560
# ack_id recv: 794580
# ack_id recv: 795600
# ack_id recv: 796620
# ack_id recv: 797640
# ack_id recv: 798660
# ack_id recv: 799680
# ack_id recv: 800700
# ack_id recv: 801720
# ack_id recv: 802740
# ack_id recv: 803760
# ack_id recv: 804780
# ack_id recv: 805800
# ack_id recv: 806820
# ack_id recv: 807840
# ack_id recv: 808860
# ack_id recv: 809880
# ack_id recv: 810900
# ack_id recv: 811920
# ack_id recv: 812940
# ack_id recv: 813960
# ack_id recv: 814980
# ack_id recv: 816000
# ack_id recv: 817020
# ack_id recv: 818040
# ack_id recv: 819060
# ack_id recv: 820080
# ack_id recv: 821100
# ack_id recv: 822120
# ack_id recv: 823140
# ack_id recv: 824160
# ack_id recv: 825180
# ack_id recv: 826200
# ack_id recv: 827220
# ack_id recv: 828240
# ack_id recv: 829260
# ack_id recv: 830280
# ack_id recv: 831300
# ack_id recv: 832320
# ack_id recv: 833340
# ack_id recv: 834360
# ack_id recv: 835380
# ack_id recv: 836400
# ack_id recv: 837420
# ack_id recv: 838440
# ack_id recv: 839460
# ack_id recv: 840480
# ack_id recv: 841500
# ack_id recv: 842520
# ack_id recv: 843540
# ack_id recv: 844560
# ack_id recv: 845580
# ack_id recv: 846600
# ack_id recv: 847620
# ack_id recv: 848640
# ack_id recv: 849660
# ack_id recv: 850680
# ack_id recv: 851700
# ack_id recv: 852720
# ack_id recv: 853740
# ack_id recv: 854760
# ack_id recv: 855780
# ack_id recv: 856800
# ack_id recv: 857820
# ack_id recv: 858840
# ack_id recv: 859860
# ack_id recv: 860880
# ack_id recv: 861900
# ack_id recv: 862920
# ack_id recv: 863940
# ack_id recv: 864960
# ack_id recv: 865980
# ack_id recv: 867000
# ack_id recv: 868020
# ack_id recv: 869040
# ack_id recv: 870060
# ack_id recv: 871080
# ack_id recv: 872100
# ack_id recv: 873120
# ack_id recv: 874140
# ack_id recv: 875160
# ack_id recv: 876180
# ack_id recv: 877200
# ack_id recv: 878220
# ack_id recv: 879240
# ack_id recv: 880260
# ack_id recv: 881280
# ack_id recv: 882300
# ack_id recv: 883320
# ack_id recv: 884340
# ack_id recv: 885360
# ack_id recv: 886380
# ack_id recv: 887400
# ack_id recv: 888420
# ack_id recv: 889440
# ack_id recv: 890460
# ack_id recv: 891480
# ack_id recv: 892500
# ack_id recv: 893520
# ack_id recv: 894540
# ack_id recv: 895560
# ack_id recv: 896580
# ack_id recv: 897600
# ack_id recv: 898620
# ack_id recv: 899640
# ack_id recv: 900660
# ack_id recv: 901680
# ack_id recv: 902700
# ack_id recv: 903720
# ack_id recv: 904740
# ack_id recv: 905760
# ack_id recv: 906780
# ack_id recv: 907800
# ack_id recv: 908820
# ack_id recv: 909840
# ack_id recv: 910860
# ack_id recv: 911880
# ack_id recv: 912900
# ack_id recv: 913920
# ack_id recv: 914940
# ack_id recv: 915960
# ack_id recv: 916980
# ack_id recv: 918000
# ack_id recv: 919020
# ack_id recv: 920040
# ack_id recv: 921060
# ack_id recv: 922080
# ack_id recv: 923100
# ack_id recv: 924120
# ack_id recv: 925140
# ack_id recv: 926160
# ack_id recv: 927180
# ack_id recv: 928200
# ack_id recv: 929220
# ack_id recv: 930240
# ack_id recv: 931260
# ack_id recv: 932280
# ack_id recv: 933300
# ack_id recv: 934320
# ack_id recv: 935340
# ack_id recv: 936360
# ack_id recv: 937380
# ack_id recv: 938400
# ack_id recv: 939420
# ack_id recv: 940440
# ack_id recv: 941460
# ack_id recv: 942480
# ack_id recv: 943500
# ack_id recv: 944520
# ack_id recv: 945540
# ack_id recv: 946560
# ack_id recv: 947580
# ack_id recv: 948600
# ack_id recv: 949620
# ack_id recv: 950640
# ack_id recv: 951660
# ack_id recv: 952680
# ack_id recv: 953700
# ack_id recv: 954720
# ack_id recv: 955740
# ack_id recv: 956760
# ack_id recv: 957780
# ack_id recv: 958800
# ack_id recv: 959820
# ack_id recv: 960840
# ack_id recv: 961860
# ack_id recv: 962880
# ack_id recv: 963900
# ack_id recv: 964920
# ack_id recv: 965940
# ack_id recv: 966960
# ack_id recv: 967980
# ack_id recv: 969000
# ack_id recv: 970020
# ack_id recv: 971040
# ack_id recv: 972060
# ack_id recv: 973080
# ack_id recv: 974100
# ack_id recv: 975120
# ack_id recv: 976140
# ack_id recv: 977160
# ack_id recv: 978180
# ack_id recv: 979200
# ack_id recv: 980220
# ack_id recv: 981240
# ack_id recv: 982260
# ack_id recv: 983280
# ack_id recv: 984300
# ack_id recv: 985320
# ack_id recv: 986340
# ack_id recv: 987360
# ack_id recv: 988380
# ack_id recv: 989400
# ack_id recv: 990420
# ack_id recv: 991440
# ack_id recv: 992460
# ack_id recv: 993480
# ack_id recv: 994500
# ack_id recv: 995520
# ack_id recv: 996540
# ack_id recv: 997560
# ack_id recv: 998580
# ack_id recv: 999600
# ack_id recv: 1000620
# ack_id recv: 1001640
# ack_id recv: 1002660
# ack_id recv: 1003680
# ack_id recv: 1004700
# ack_id recv: 1005720
# ack_id recv: 1006740
# ack_id recv: 1007760
# ack_id recv: 1008780
# ack_id recv: 1009800
# ack_id recv: 1010820
# ack_id recv: 1011840
# ack_id recv: 1012860
# ack_id recv: 1013880
# ack_id recv: 1014900
# ack_id recv: 1015920
# ack_id recv: 1016940
# ack_id recv: 1017960
# ack_id recv: 1018980
# ack_id recv: 1020000
# ack_id recv: 1021020
# ack_id recv: 1022040
# ack_id recv: 1023060
# ack_id recv: 1024080
# ack_id recv: 1025100
# ack_id recv: 1026120
# ack_id recv: 1027140
# ack_id recv: 1028160
# ack_id recv: 1029180
# ack_id recv: 1030200
# ack_id recv: 1031220
# ack_id recv: 1032240
# ack_id recv: 1033260
# ack_id recv: 1034280
# ack_id recv: 1035300
# ack_id recv: 1036320
# ack_id recv: 1037340
# ack_id recv: 1038360
# ack_id recv: 1039380
# ack_id recv: 1040400
# ack_id recv: 1041420
# ack_id recv: 1042440
# ack_id recv: 1043460
# ack_id recv: 1044480
# ack_id recv: 1045500
# ack_id recv: 1046520
# ack_id recv: 1047540
# ack_id recv: 1048560
# ack_id recv: 1049580
# ack_id recv: 1050600
# ack_id recv: 1051620
# ack_id recv: 1052640
# ack_id recv: 1053660
# ack_id recv: 1054680
# ack_id recv: 1055700
# ack_id recv: 1056720
# ack_id recv: 1057740
# ack_id recv: 1058760
# ack_id recv: 1059780
# ack_id recv: 1060800
# ack_id recv: 1061820
# ack_id recv: 1062840
# ack_id recv: 1063860
# ack_id recv: 1064880
# ack_id recv: 1065900
# ack_id recv: 1066920
# ack_id recv: 1067940
# ack_id recv: 1068960
# ack_id recv: 1069980
# ack_id recv: 1071000
# ack_id recv: 1072020
# ack_id recv: 1073040
# ack_id recv: 1074060
# ack_id recv: 1075080
# ack_id recv: 1076100
# ack_id recv: 1077120
# ack_id recv: 1078140
# ack_id recv: 1079160
# ack_id recv: 1080180
# ack_id recv: 1081200
# ack_id recv: 1082220
# ack_id recv: 1083240
# ack_id recv: 1084260
# ack_id recv: 1085280
# ack_id recv: 1086300
# ack_id recv: 1087320
# ack_id recv: 1088340
# ack_id recv: 1089360
# ack_id recv: 1090380
# ack_id recv: 1091400
# ack_id recv: 1092420
# ack_id recv: 1093440
# ack_id recv: 1094460
# ack_id recv: 1095480
# ack_id recv: 1096500
# ack_id recv: 1097520
# ack_id recv: 1098540
# ack_id recv: 1099560
# ack_id recv: 1100580
# ack_id recv: 1101600
# ack_id recv: 1102620
# ack_id recv: 1103640
# ack_id recv: 1104660
# ack_id recv: 1105680
# ack_id recv: 1106700
# ack_id recv: 1107720
# ack_id recv: 1108740
# ack_id recv: 1109760
# ack_id recv: 1110780
# ack_id recv: 1111800
# ack_id recv: 1112820
# ack_id recv: 1113840
# ack_id recv: 1114860
# ack_id recv: 1115880
# ack_id recv: 1116900
# ack_id recv: 1117920
# ack_id recv: 1118940
# ack_id recv: 1119960
# ack_id recv: 1120980
# ack_id recv: 1122000
# ack_id recv: 1123020
# ack_id recv: 1124040
# ack_id recv: 1125060
# ack_id recv: 1126080
# ack_id recv: 1127100
# ack_id recv: 1128120
# ack_id recv: 1129140
# ack_id recv: 1130160
# ack_id recv: 1131180
# ack_id recv: 1132200
# ack_id recv: 1133220
# ack_id recv: 1134240
# ack_id recv: 1135260
# ack_id recv: 1136280
# ack_id recv: 1137300
# ack_id recv: 1138320
# ack_id recv: 1139340
# ack_id recv: 1140360
# ack_id recv: 1141380
# ack_id recv: 1142400
# ack_id recv: 1143420
# ack_id recv: 1144440
# ack_id recv: 1145460
# ack_id recv: 1146480
# ack_id recv: 1147500
# ack_id recv: 1148520
# ack_id recv: 1149540
# ack_id recv: 1150560
# ack_id recv: 1151580
# ack_id recv: 1152600
# ack_id recv: 1153620
# ack_id recv: 1154640
# ack_id recv: 1155660
# ack_id recv: 1156680
# ack_id recv: 1157700
# ack_id recv: 1158720
# ack_id recv: 1159740
# ack_id recv: 1160760
# ack_id recv: 1161780
# ack_id recv: 1162800
# ack_id recv: 1163820
# ack_id recv: 1164840
# ack_id recv: 1165860
# ack_id recv: 1166880
# ack_id recv: 1167900
# ack_id recv: 1168920
# ack_id recv: 1169940
# ack_id recv: 1170960
# ack_id recv: 1171980
# ack_id recv: 1173000
# ack_id recv: 1174020
# ack_id recv: 1175040
# ack_id recv: 1176060
# ack_id recv: 1177080
# ack_id recv: 1178100
# ack_id recv: 1179120
# ack_id recv: 1180140
# ack_id recv: 1181160
# ack_id recv: 1182180
# ack_id recv: 1183200
# ack_id recv: 1184220
# ack_id recv: 1185240
# ack_id recv: 1186260
# ack_id recv: 1187280
# ack_id recv: 1188300
# ack_id recv: 1189320
# ack_id recv: 1190340
# ack_id recv: 1191360
# ack_id recv: 1192380
# ack_id recv: 1193400
# ack_id recv: 1194420
# ack_id recv: 1195440
# ack_id recv: 1196460
# ack_id recv: 1197480
# ack_id recv: 1198500
# ack_id recv: 1199520
# ack_id recv: 1200540
# ack_id recv: 1201560
# ack_id recv: 1202580
# ack_id recv: 1203600
# ack_id recv: 1204620
# ack_id recv: 1205640
# ack_id recv: 1206660
# ack_id recv: 1207680
# ack_id recv: 1208700
# ack_id recv: 1209720
# ack_id recv: 1210740
# ack_id recv: 1211760
# ack_id recv: 1212780
# ack_id recv: 1213800
# ack_id recv: 1214820
# ack_id recv: 1215840
# ack_id recv: 1216860
# ack_id recv: 1217880
# ack_id recv: 1218900
# ack_id recv: 1219920
# ack_id recv: 1220940
# ack_id recv: 1221960
# ack_id recv: 1222980
# ack_id recv: 1224000
# ack_id recv: 1225020
# ack_id recv: 1226040
# ack_id recv: 1227060
# ack_id recv: 1228080
# ack_id recv: 1229100
# ack_id recv: 1230120
# ack_id recv: 1231140
# ack_id recv: 1232160
# ack_id recv: 1233180
# ack_id recv: 1234200
# ack_id recv: 1235220
# ack_id recv: 1236240
# ack_id recv: 1237260
# ack_id recv: 1238280
# ack_id recv: 1239300
# ack_id recv: 1240320
# ack_id recv: 1241340
# ack_id recv: 1242360
# ack_id recv: 1243380
# ack_id recv: 1244400
# ack_id recv: 1245420
# ack_id recv: 1246440
# ack_id recv: 1247460
# ack_id recv: 1248480
# ack_id recv: 1249500
# ack_id recv: 1250520
# ack_id recv: 1251540
# ack_id recv: 1252560
# ack_id recv: 1253580
# ack_id recv: 1254600
# ack_id recv: 1255620
# ack_id recv: 1256640
# ack_id recv: 1257660
# ack_id recv: 1258680
# ack_id recv: 1259700
# ack_id recv: 1260720
# ack_id recv: 1261740
# ack_id recv: 1262760
# ack_id recv: 1263780
# ack_id recv: 1264800
# ack_id recv: 1265820
# ack_id recv: 1266840
# ack_id recv: 1267860
# ack_id recv: 1268880
# ack_id recv: 1269900
# ack_id recv: 1270920
# ack_id recv: 1271940
# ack_id recv: 1272960
# ack_id recv: 1273980
# ack_id recv: 1275000
# ack_id recv: 1276020
# ack_id recv: 1277040
# ack_id recv: 1278060
# ack_id recv: 1279080
# ack_id recv: 1280100
# ack_id recv: 1281120
# ack_id recv: 1282140
# ack_id recv: 1283160
# ack_id recv: 1284180
# ack_id recv: 1285200
# ack_id recv: 1286220
# ack_id recv: 1287240
# ack_id recv: 1288260
# ack_id recv: 1289280
# ack_id recv: 1290300
# ack_id recv: 1291320
# ack_id recv: 1292340
# ack_id recv: 1293360
# ack_id recv: 1294380
# ack_id recv: 1295400
# ack_id recv: 1296420
# ack_id recv: 1297440
# ack_id recv: 1298460
# ack_id recv: 1299480
# ack_id recv: 1300500
# ack_id recv: 1301520
# ack_id recv: 1302540
# ack_id recv: 1303560
# ack_id recv: 1304580
# ack_id recv: 1305600
# ack_id recv: 1306620
# ack_id recv: 1307640
# ack_id recv: 1308660
# ack_id recv: 1309680
# ack_id recv: 1310700
# ack_id recv: 1311720
# ack_id recv: 1312740
# ack_id recv: 1313760
# ack_id recv: 1314780
# ack_id recv: 1315800
# ack_id recv: 1316820
# ack_id recv: 1317840
# ack_id recv: 1318860
# ack_id recv: 1319880
# ack_id recv: 1320900
# ack_id recv: 1321920
# ack_id recv: 1322940
# ack_id recv: 1323960
# ack_id recv: 1324980
# ack_id recv: 1326000
# ack_id recv: 1327020
# ack_id recv: 1328040
# ack_id recv: 1329060
# ack_id recv: 1330080
# ack_id recv: 1331100
# ack_id recv: 1332120
# ack_id recv: 1333140
# ack_id recv: 1334160
# ack_id recv: 1335180
# ack_id recv: 1336200
# ack_id recv: 1337220
# ack_id recv: 1338240
# ack_id recv: 1339260
# ack_id recv: 1340280
# ack_id recv: 1341300
# ack_id recv: 1342320
# ack_id recv: 1343340
# ack_id recv: 1344360
# ack_id recv: 1345380
# ack_id recv: 1346400
# ack_id recv: 1347420
# ack_id recv: 1348440
# ack_id recv: 1349460
# ack_id recv: 1350480
# ack_id recv: 1351500
# ack_id recv: 1352520
# ack_id recv: 1353540
# ack_id recv: 1354560
# ack_id recv: 1355580
# ack_id recv: 1356600
# ack_id recv: 1357620
# ack_id recv: 1358640
# ack_id recv: 1359660
# ack_id recv: 1360680
# ack_id recv: 1361700
# ack_id recv: 1362720
# ack_id recv: 1363740
# ack_id recv: 1364760
# ack_id recv: 1365780
# ack_id recv: 1366800
# ack_id recv: 1367820
# ack_id recv: 1368840
# ack_id recv: 1369860
# ack_id recv: 1370880
# ack_id recv: 1371900
# ack_id recv: 1372920
# ack_id recv: 1373940
# ack_id recv: 1374960
# ack_id recv: 1375980
# ack_id recv: 1377000
# ack_id recv: 1378020
# ack_id recv: 1379040
# ack_id recv: 1380060
# ack_id recv: 1381080
# ack_id recv: 1382100
# ack_id recv: 1383120
# ack_id recv: 1384140
# ack_id recv: 1385160
# ack_id recv: 1386180
# ack_id recv: 1387200
# ack_id recv: 1388220
# ack_id recv: 1389240
# ack_id recv: 1390260
# ack_id recv: 1391280
# ack_id recv: 1392300
# ack_id recv: 1393320
# ack_id recv: 1394340
# ack_id recv: 1395360
# ack_id recv: 1396380
# ack_id recv: 1397400
# ack_id recv: 1398420
# ack_id recv: 1399440
# ack_id recv: 1400460
# ack_id recv: 1401480
# ack_id recv: 1402500
# ack_id recv: 1403520
# ack_id recv: 1404540
# ack_id recv: 1405560
# ack_id recv: 1406580
# ack_id recv: 1407600
# ack_id recv: 1408620
# ack_id recv: 1409640
# ack_id recv: 1410660
# ack_id recv: 1411680
# ack_id recv: 1412700
# ack_id recv: 1413720
# ack_id recv: 1414740
# ack_id recv: 1415760
# ack_id recv: 1416780
# ack_id recv: 1417800
# ack_id recv: 1418820
# ack_id recv: 1419840
# ack_id recv: 1420860
# ack_id recv: 1421880
# ack_id recv: 1422900
# ack_id recv: 1423920
# ack_id recv: 1424940
# ack_id recv: 1425960
# ack_id recv: 1426980
# ack_id recv: 1428000
# ack_id recv: 1429020
# ack_id recv: 1430040
# ack_id recv: 1431060
# ack_id recv: 1432080
# ack_id recv: 1433100
# ack_id recv: 1434120
# ack_id recv: 1435140
# ack_id recv: 1436160
# ack_id recv: 1437180
# ack_id recv: 1438200
# ack_id recv: 1439220
# ack_id recv: 1440240
# ack_id recv: 1441260
# ack_id recv: 1442280
# ack_id recv: 1443300
# ack_id recv: 1444320
# ack_id recv: 1445340
# ack_id recv: 1446360
# ack_id recv: 1447380
# ack_id recv: 1448400
# ack_id recv: 1449420
# ack_id recv: 1450440
# ack_id recv: 1451460
# ack_id recv: 1452480
# ack_id recv: 1453500
# ack_id recv: 1454520
# ack_id recv: 1455540
# ack_id recv: 1456560
# ack_id recv: 1457580
# ack_id recv: 1458600
# ack_id recv: 1459620
# ack_id recv: 1460640
# ack_id recv: 1461660
# ack_id recv: 1462680
# ack_id recv: 1463700
# ack_id recv: 1464720
# ack_id recv: 1465740
# ack_id recv: 1466760
# ack_id recv: 1467780
# ack_id recv: 1468800
# ack_id recv: 1469820
# ack_id recv: 1470840
# ack_id recv: 1471860
# ack_id recv: 1472880
# ack_id recv: 1473900
# ack_id recv: 1474920
# ack_id recv: 1475940
# ack_id recv: 1476960
# ack_id recv: 1477980
# ack_id recv: 1479000
# ack_id recv: 1480020
# ack_id recv: 1481040
# ack_id recv: 1482060
# ack_id recv: 1483080
# ack_id recv: 1484100
# ack_id recv: 1485120
# ack_id recv: 1486140
# ack_id recv: 1487160
# ack_id recv: 1488180
# ack_id recv: 1489200
# ack_id recv: 1490220
# ack_id recv: 1491240
# ack_id recv: 1492260
# ack_id recv: 1493280
# ack_id recv: 1494300
# ack_id recv: 1495320
# ack_id recv: 1496340
# ack_id recv: 1497360
# ack_id recv: 1498380
# ack_id recv: 1499400
# ack_id recv: 1500420
# ack_id recv: 1501440
# ack_id recv: 1502460
# ack_id recv: 1503480
# ack_id recv: 1504500
# ack_id recv: 1505520
# ack_id recv: 1506540
# ack_id recv: 1507560
# ack_id recv: 1508580
# ack_id recv: 1509600
# ack_id recv: 1510620
# ack_id recv: 1511640
# ack_id recv: 1512660
# ack_id recv: 1513680
# ack_id recv: 1514700
# ack_id recv: 1515720
# ack_id recv: 1516740
# ack_id recv: 1517760
# ack_id recv: 1518780
# ack_id recv: 1519800
# ack_id recv: 1520820
# ack_id recv: 1521840
# ack_id recv: 1522860
# ack_id recv: 1523880
# ack_id recv: 1524900
# ack_id recv: 1525920
# ack_id recv: 1526940
# ack_id recv: 1527960
# ack_id recv: 1528980
# ack_id recv: 1530000
# ack_id recv: 1531020
# ack_id recv: 1532040
# ack_id recv: 1533060
# ack_id recv: 1534080
# ack_id recv: 1535100
# ack_id recv: 1536120
# ack_id recv: 1537140
# ack_id recv: 1538160
# ack_id recv: 1539180
# ack_id recv: 1540200
# ack_id recv: 1541220
# ack_id recv: 1542240
# ack_id recv: 1543260
# ack_id recv: 1544280
# ack_id recv: 1545300
# ack_id recv: 1546320
# ack_id recv: 1547340
# ack_id recv: 1548360
# ack_id recv: 1549380
# ack_id recv: 1550400
# ack_id recv: 1551420
# ack_id recv: 1552440
# ack_id recv: 1553460
# ack_id recv: 1554480
# ack_id recv: 1555500
# ack_id recv: 1556520
# ack_id recv: 1557540
# ack_id recv: 1558560
# ack_id recv: 1559580
# ack_id recv: 1560600
# ack_id recv: 1561620
# ack_id recv: 1562640
# ack_id recv: 1563660
# ack_id recv: 1564680
# ack_id recv: 1565700
# ack_id recv: 1566720
# ack_id recv: 1567740
# ack_id recv: 1568760
# ack_id recv: 1569780
# ack_id recv: 1570800
# ack_id recv: 1571820
# ack_id recv: 1572840
# ack_id recv: 1573860
# ack_id recv: 1574880
# ack_id recv: 1575900
# ack_id recv: 1576920
# ack_id recv: 1577940
# ack_id recv: 1578960
# ack_id recv: 1579980
# ack_id recv: 1581000
# ack_id recv: 1582020
# ack_id recv: 1583040
# ack_id recv: 1584060
# ack_id recv: 1585080
# ack_id recv: 1586100
# ack_id recv: 1587120
# ack_id recv: 1588140
# ack_id recv: 1589160
# ack_id recv: 1590180
# ack_id recv: 1591200
# ack_id recv: 1592220
# ack_id recv: 1593240
# ack_id recv: 1594260
# ack_id recv: 1595280
# ack_id recv: 1596300
# ack_id recv: 1597320
# ack_id recv: 1598340
# ack_id recv: 1599360
# ack_id recv: 1600380
# ack_id recv: 1601400
# ack_id recv: 1602420
# ack_id recv: 1603440
# ack_id recv: 1604460
# ack_id recv: 1605480
# ack_id recv: 1606500
# ack_id recv: 1607520
# ack_id recv: 1608540
# ack_id recv: 1609560
# ack_id recv: 1610580
# ack_id recv: 1611600
# ack_id recv: 1612620
# ack_id recv: 1613640
# ack_id recv: 1614660
# ack_id recv: 1615680
# ack_id recv: 1616700
# ack_id recv: 1617720
# ack_id recv: 1618740
# ack_id recv: 1619760
# ack_id recv: 1620780
# ack_id recv: 1621800
# ack_id recv: 1622820
# ack_id recv: 1623840
# ack_id recv: 1624860
# ack_id recv: 1625880
# ack_id recv: 1626900
# ack_id recv: 1627920
# ack_id recv: 1628940
# ack_id recv: 1629960
# ack_id recv: 1630980
# ack_id recv: 1632000
# ack_id recv: 1633020
# ack_id recv: 1634040
# ack_id recv: 1635060
# ack_id recv: 1636080
# ack_id recv: 1637100
# ack_id recv: 1638120
# ack_id recv: 1639140
# ack_id recv: 1640160
# ack_id recv: 1641180
# ack_id recv: 1642200
# ack_id recv: 1643220
# ack_id recv: 1644240
# ack_id recv: 1645260
# ack_id recv: 1646280
# ack_id recv: 1647300
# ack_id recv: 1648320
# ack_id recv: 1649340
# ack_id recv: 1650360
# ack_id recv: 1651380
# ack_id recv: 1652400
# ack_id recv: 1653420
# ack_id recv: 1654440
# ack_id recv: 1655460
# ack_id recv: 1656480
# ack_id recv: 1657500
# ack_id recv: 1658520
# ack_id recv: 1659540
# ack_id recv: 1660560
# ack_id recv: 1661580
# ack_id recv: 1662600
# ack_id recv: 1663620
# ack_id recv: 1664640
# ack_id recv: 1665660
# ack_id recv: 1666680
# ack_id recv: 1667700
# ack_id recv: 1668720
# ack_id recv: 1669740
# ack_id recv: 1670760
# ack_id recv: 1671780
# ack_id recv: 1672800
# ack_id recv: 1673820
# ack_id recv: 1674840
# ack_id recv: 1675860
# ack_id recv: 1676880
# ack_id recv: 1677900
# ack_id recv: 1678920
# ack_id recv: 1679940
# ack_id recv: 1680960
# ack_id recv: 1681980
# ack_id recv: 1683000
# ack_id recv: 1684020
# ack_id recv: 1685040
# ack_id recv: 1686060
# ack_id recv: 1687080
# ack_id recv: 1688100
# ack_id recv: 1689120
# ack_id recv: 1690140
# ack_id recv: 1691160
# ack_id recv: 1692180
# ack_id recv: 1693200
# ack_id recv: 1694220
# ack_id recv: 1695240
# ack_id recv: 1696260
# ack_id recv: 1697280
# ack_id recv: 1698300
# ack_id recv: 1699320
# ack_id recv: 1700340
# ack_id recv: 1701360
# ack_id recv: 1702380
# ack_id recv: 1703400
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1704420
# ack_id recv: 1705440
# ack_id recv: 1706460
# ack_id recv: 1707480
# ack_id recv: 1708500
# ack_id recv: 1709520
# ack_id recv: 1710540
# ack_id recv: 1711560
# ack_id recv: 1712580
# ack_id recv: 1713600
# ack_id recv: 1714620
# ack_id recv: 1715640
# ack_id recv: 1716660
# ack_id recv: 1717680
# ack_id recv: 1718700
# ack_id recv: 1719720
# ack_id recv: 1720740
# ack_id recv: 1721760
# ack_id recv: 1722780
# ack_id recv: 1723800
# ack_id recv: 1724820
# ack_id recv: 1725840
# ack_id recv: 1726860
# ack_id recv: 1727880
# ack_id recv: 1728900
# ack_id recv: 1729920
# ack_id recv: 1730940
# ack_id recv: 1731960
# ack_id recv: 1732980
# ack_id recv: 1734000
# ack_id recv: 1735020
# ack_id recv: 1736040
# ack_id recv: 1737060
# ack_id recv: 1738080
# ack_id recv: 1739100
# ack_id recv: 1740120
# ack_id recv: 1741140
# ack_id recv: 1742160
# ack_id recv: 1743180
# ack_id recv: 1744200
# ack_id recv: 1745220
# ack_id recv: 1746240
# ack_id recv: 1747260
# ack_id recv: 1748280
# ack_id recv: 1749300
# ack_id recv: 1750320
# ack_id recv: 1751340
# ack_id recv: 1752360
# ack_id recv: 1753380
# ack_id recv: 1754400
# ack_id recv: 1755420
# ack_id recv: 1756440
# ack_id recv: 1757460
# ack_id recv: 1758480
# ack_id recv: 1759500
# ack_id recv: 1759500
# ack_id recv: 1759500
# ack_id recv: 1760520
# ack_id recv: 1761540
# ack_id recv: 1762560
# ack_id recv: 1763580
# ack_id recv: 1764600
# ack_id recv: 1765620
# ack_id recv: 1766640
# ack_id recv: 1767660
# ack_id recv: 1768680
# ack_id recv: 1769700
# ack_id recv: 1770720
# ack_id recv: 1771740
# ack_id recv: 1772760
# ack_id recv: 1773780
# ack_id recv: 1774800
# ack_id recv: 1775820
# ack_id recv: 1776840
# ack_id recv: 1777860
# ack_id recv: 1778880
# ack_id recv: 1779900
# ack_id recv: 1780920
# ack_id recv: 1781940
# ack_id recv: 1782960
# ack_id recv: 1783980
# ack_id recv: 1785000
# ack_id recv: 1786020
# ack_id recv: 1787040
# ack_id recv: 1788060
# ack_id recv: 1789080
# ack_id recv: 1790100
# ack_id recv: 1791120
# ack_id recv: 1792140
# ack_id recv: 1793160
# ack_id recv: 1794180
# ack_id recv: 1795200
# ack_id recv: 1796220
# ack_id recv: 1797240
# ack_id recv: 1798260
# ack_id recv: 1799280
# ack_id recv: 1800300
# ack_id recv: 1801320
# ack_id recv: 1802340
# ack_id recv: 1803360
# ack_id recv: 1804380
# ack_id recv: 1805400
# ack_id recv: 1806420
# ack_id recv: 1807440
# ack_id recv: 1808460
# ack_id recv: 1809480
# ack_id recv: 1810500
# ack_id recv: 1811520
# ack_id recv: 1812540
# ack_id recv: 1813560
# ack_id recv: 1814580
# ack_id recv: 1815600
# ack_id recv: 1816620
# ack_id recv: 1817640
# ack_id recv: 1818660
# ack_id recv: 1819680
# ack_id recv: 1820700
# ack_id recv: 1821720
# ack_id recv: 1822740
# ack_id recv: 1823760
# ack_id recv: 1824780
# ack_id recv: 1825800
# ack_id recv: 1826820
# ack_id recv: 1827840
# ack_id recv: 1828860
# ack_id recv: 1829880
# ack_id recv: 1830900
# ack_id recv: 1831920
# ack_id recv: 1832940
# ack_id recv: 1833960
# ack_id recv: 1834980
# ack_id recv: 1836000
# ack_id recv: 1837020
# ack_id recv: 1838040
# ack_id recv: 1839060
# ack_id recv: 1840080
# ack_id recv: 1841100
# ack_id recv: 1842120
# ack_id recv: 1843140
# ack_id recv: 1844160
# ack_id recv: 1845180
# ack_id recv: 1846200
# ack_id recv: 1847220
# ack_id recv: 1848240
# ack_id recv: 1849260
# ack_id recv: 1850280
# ack_id recv: 1851300
# ack_id recv: 1852320
# ack_id recv: 1853340
# ack_id recv: 1854360
# ack_id recv: 1855380
# ack_id recv: 1856400
# ack_id recv: 1857420
# ack_id recv: 1858440
# ack_id recv: 1859460
# ack_id recv: 1860480
# ack_id recv: 1861500
# ack_id recv: 1862520
# ack_id recv: 1863540
# ack_id recv: 1864560
# ack_id recv: 1865580
# ack_id recv: 1866600
# ack_id recv: 1867620
# ack_id recv: 1868640
# ack_id recv: 1869660
# ack_id recv: 1870680
# ack_id recv: 1871700
# ack_id recv: 1872720
# ack_id recv: 1873740
# ack_id recv: 1874760
# ack_id recv: 1875780
# ack_id recv: 1876800
# ack_id recv: 1877820
# ack_id recv: 1878840
# ack_id recv: 1879860
# ack_id recv: 1880880
# ack_id recv: 1881900
# ack_id recv: 1882920
# ack_id recv: 1883940
# ack_id recv: 1884960
# ack_id recv: 1885980
# ack_id recv: 1887000
# ack_id recv: 1888020
# ack_id recv: 1889040
# ack_id recv: 1890060
# ack_id recv: 1891080
# ack_id recv: 1892100
# ack_id recv: 1893120
# ack_id recv: 1894140
# ack_id recv: 1895160
# ack_id recv: 1896180
# ack_id recv: 1897200
# ack_id recv: 1898220
# ack_id recv: 1899240
# ack_id recv: 1900260
# ack_id recv: 1901280
# ack_id recv: 1902300
# ack_id recv: 1903320
# ack_id recv: 1904340
# ack_id recv: 1905360
# ack_id recv: 1906380
# ack_id recv: 1907400
# ack_id recv: 1908420
# ack_id recv: 1909440
# ack_id recv: 1910460
# ack_id recv: 1911480
# ack_id recv: 1912500
# ack_id recv: 1913520
# ack_id recv: 1914540
# ack_id recv: 1915560
# ack_id recv: 1916580
# ack_id recv: 1917600
# ack_id recv: 1918620
# ack_id recv: 1919640
# ack_id recv: 1920660
# ack_id recv: 1921680
# ack_id recv: 1922700
# ack_id recv: 1923720
# ack_id recv: 1924740
# ack_id recv: 1925760
# ack_id recv: 1926780
# ack_id recv: 1927800
# ack_id recv: 1928820
# ack_id recv: 1929840
# ack_id recv: 1930860
# ack_id recv: 1931880
# ack_id recv: 1932900
# ack_id recv: 1933920
# ack_id recv: 1934940
# ack_id recv: 1935960
# ack_id recv: 1936980
# ack_id recv: 1938000
# ack_id recv: 1939020
# ack_id recv: 1940040
# ack_id recv: 1941060
# ack_id recv: 1942080
# ack_id recv: 1943100
# ack_id recv: 1944120
# ack_id recv: 1945140
# ack_id recv: 1946160
# ack_id recv: 1947180
# ack_id recv: 1948200
# ack_id recv: 1949220
# ack_id recv: 1950240
# ack_id recv: 1951260
# ack_id recv: 1952280
# ack_id recv: 1953300
# ack_id recv: 1954320
# ack_id recv: 1955340
# ack_id recv: 1956360
# ack_id recv: 1957380
# ack_id recv: 1958400
# ack_id recv: 1959420
# ack_id recv: 1960440
# ack_id recv: 1961460
# ack_id recv: 1962480
# ack_id recv: 1963500
# ack_id recv: 1964520
# ack_id recv: 1965540
# ack_id recv: 1966560
# ack_id recv: 1967580
# ack_id recv: 1968600
# ack_id recv: 1969620
# ack_id recv: 1970640
# ack_id recv: 1971660
# ack_id recv: 1972680
# ack_id recv: 1973700
# ack_id recv: 1974720
# ack_id recv: 1975740
# ack_id recv: 1976760
# ack_id recv: 1977780
# ack_id recv: 1978800
# ack_id recv: 1979820
# ack_id recv: 1980840
# ack_id recv: 1981860
# ack_id recv: 1982880
# ack_id recv: 1983900
# ack_id recv: 1984920
# ack_id recv: 1985940
# ack_id recv: 1986960
# ack_id recv: 1987980
# ack_id recv: 1989000
# ack_id recv: 1990020
# ack_id recv: 1991040
# ack_id recv: 1992060
# ack_id recv: 1993080
# ack_id recv: 1994100
# ack_id recv: 1995120
# ack_id recv: 1996140
# ack_id recv: 1997160
# ack_id recv: 1998180
# ack_id recv: 1999200
# ack_id recv: 2000220
# ack_id recv: 2001240
# ack_id recv: 2002260
# ack_id recv: 2003280
# ack_id recv: 2004300
# ack_id recv: 2005320
# ack_id recv: 2006340
# ack_id recv: 2007360
# ack_id recv: 2008380
# ack_id recv: 2009400
# ack_id recv: 2010420
# ack_id recv: 2011440
# ack_id recv: 2012460
# ack_id recv: 2013480
# ack_id recv: 2014500
# ack_id recv: 2015520
# ack_id recv: 2016540
# ack_id recv: 2017560
# ack_id recv: 2018580
# ack_id recv: 2019600
# ack_id recv: 2020620
# ack_id recv: 2021640
# ack_id recv: 2022660
# ack_id recv: 2023680
# ack_id recv: 2024700
# ack_id recv: 2025720
# ack_id recv: 2026740
# ack_id recv: 2027760
# ack_id recv: 2028780
# ack_id recv: 2029800
# ack_id recv: 2030820
# ack_id recv: 2031840
# ack_id recv: 2032860
# ack_id recv: 2033880
# ack_id recv: 2034900
# ack_id recv: 2035920
# ack_id recv: 2036940
# ack_id recv: 2037960
# ack_id recv: 2038980
# ack_id recv: 2040000
# ack_id recv: 2041020
# ack_id recv: 2042040
# ack_id recv: 2043060
# ack_id recv: 2044080
# ack_id recv: 2045100
# ack_id recv: 2046120
# ack_id recv: 2047140
# ack_id recv: 2048160
# ack_id recv: 2049180
# ack_id recv: 2050200
# ack_id recv: 2051220
# ack_id recv: 2052240
# ack_id recv: 2053260
# ack_id recv: 2054280
# ack_id recv: 2055300
# ack_id recv: 2056320
# ack_id recv: 2057340
# ack_id recv: 2058360
# ack_id recv: 2059380
# ack_id recv: 2060400
# ack_id recv: 2061420
# ack_id recv: 2062440
# ack_id recv: 2063460
# ack_id recv: 2064480
# ack_id recv: 2065500
# ack_id recv: 2066520
# ack_id recv: 2067540
# ack_id recv: 2068560
# ack_id recv: 2069580
# ack_id recv: 2070600
# ack_id recv: 2071620
# ack_id recv: 2072640
# ack_id recv: 2073660
# ack_id recv: 2074680
# ack_id recv: 2075700
# ack_id recv: 2076720
# ack_id recv: 2077740
# ack_id recv: 2078760
# ack_id recv: 2079780
# ack_id recv: 2080800
# ack_id recv: 2081820
# ack_id recv: 2082840
# ack_id recv: 2083860
# ack_id recv: 2084880
# ack_id recv: 2085900
# ack_id recv: 2086920
# ack_id recv: 2087940
# ack_id recv: 2088960
# ack_id recv: 2089980
# ack_id recv: 2091000
# ack_id recv: 2092020
# ack_id recv: 2093040
# ack_id recv: 2094060
# ack_id recv: 2095080
# ack_id recv: 2096100
# ack_id recv: 2097120
# ack_id recv: 2098140
# ack_id recv: 2099160
# ack_id recv: 2100180
# ack_id recv: 2101200
# ack_id recv: 2102220
# ack_id recv: 2103240
# ack_id recv: 2104260
# ack_id recv: 2105280
# ack_id recv: 2106300
# ack_id recv: 2107320
# ack_id recv: 2108340
# ack_id recv: 2109360
# ack_id recv: 2110380
# ack_id recv: 2111400
# ack_id recv: 2112420
# ack_id recv: 2113440
# ack_id recv: 2114460
# ack_id recv: 2115480
# ack_id recv: 2116500
# ack_id recv: 2117520
# ack_id recv: 2118540
# ack_id recv: 2119560
# ack_id recv: 2120580
# ack_id recv: 2121600
# ack_id recv: 2122620
# ack_id recv: 2123640
# ack_id recv: 2124660
# ack_id recv: 2125680
# ack_id recv: 2126700
# ack_id recv: 2127720
# ack_id recv: 2128740
# ack_id recv: 2129760
# ack_id recv: 2130780
# ack_id recv: 2131800
# ack_id recv: 2132820
# ack_id recv: 2133840
# ack_id recv: 2134860
# ack_id recv: 2135880
# ack_id recv: 2136900
# ack_id recv: 2137920
# ack_id recv: 2138940
# ack_id recv: 2139960
# ack_id recv: 2140980
# ack_id recv: 2142000
# ack_id recv: 2143020
# ack_id recv: 2144040
# ack_id recv: 2145060
# ack_id recv: 2146080
# ack_id recv: 2147100
# ack_id recv: 2148120
# ack_id recv: 2149140
# ack_id recv: 2150160
# ack_id recv: 2151180
# ack_id recv: 2152200
# ack_id recv: 2153220
# ack_id recv: 2154240
# ack_id recv: 2155260
# ack_id recv: 2156280
# ack_id recv: 2157300
# ack_id recv: 2158320
# ack_id recv: 2159340
# ack_id recv: 2160360
# ack_id recv: 2161380
# ack_id recv: 2162400
# ack_id recv: 2163420
# ack_id recv: 2164440
# ack_id recv: 2165460
# ack_id recv: 2166480
# ack_id recv: 2167500
# ack_id recv: 2168520
# ack_id recv: 2169540
# ack_id recv: 2170560
# ack_id recv: 2171580
# ack_id recv: 2172600
# ack_id recv: 2173620
# ack_id recv: 2174640
# ack_id recv: 2175660
# ack_id recv: 2176680
# ack_id recv: 2177700
# ack_id recv: 2178720
# ack_id recv: 2179740
# ack_id recv: 2180760
# ack_id recv: 2181780
# ack_id recv: 2182800
# ack_id recv: 2183820
# ack_id recv: 2184840
# ack_id recv: 2185860
# ack_id recv: 2186880
# ack_id recv: 2187900
# ack_id recv: 2188920
# ack_id recv: 2189940
# ack_id recv: 2190960
# ack_id recv: 2191980
# ack_id recv: 2193000
# ack_id recv: 2194020
# ack_id recv: 2195040
# ack_id recv: 2196060
# ack_id recv: 2197080
# ack_id recv: 2198100
# ack_id recv: 2199120
# ack_id recv: 2200140
# ack_id recv: 2201160
# ack_id recv: 2202180
# ack_id recv: 2203200
# ack_id recv: 2204220
# ack_id recv: 2205240
# ack_id recv: 2206260
# ack_id recv: 2207280
# ack_id recv: 2208300
# ack_id recv: 2209320
# ack_id recv: 2210340
# ack_id recv: 2211360
# ack_id recv: 2212380
# ack_id recv: 2213400
# ack_id recv: 2214420
# ack_id recv: 2215440
# ack_id recv: 2216460
# ack_id recv: 2217480
# ack_id recv: 2218500
# ack_id recv: 2219520
# ack_id recv: 2220540
# ack_id recv: 2221560
# ack_id recv: 2222580
# ack_id recv: 2223600
# ack_id recv: 2224620
# ack_id recv: 2225640
# ack_id recv: 2226660
# ack_id recv: 2227680
# ack_id recv: 2228700
# ack_id recv: 2229720
# ack_id recv: 2230740
# ack_id recv: 2231760
# ack_id recv: 2232780
# ack_id recv: 2233800
# ack_id recv: 2234820
# ack_id recv: 2235840
# ack_id recv: 2236860
# ack_id recv: 2237880
# ack_id recv: 2238900
# ack_id recv: 2239920
# ack_id recv: 2240940
# ack_id recv: 2241960
# ack_id recv: 2242980
# ack_id recv: 2244000
# ack_id recv: 2245020
# ack_id recv: 2246040
# ack_id recv: 2247060
# ack_id recv: 2248080
# ack_id recv: 2249100
# ack_id recv: 2250120
# ack_id recv: 2251140
# ack_id recv: 2252160
# ack_id recv: 2253180
# ack_id recv: 2254200
# ack_id recv: 2255220
# ack_id recv: 2256240
# ack_id recv: 2257260
# ack_id recv: 2258280
# ack_id recv: 2259300
# ack_id recv: 2260320
# ack_id recv: 2261340
# ack_id recv: 2262360
# ack_id recv: 2263380
# ack_id recv: 2264400
# ack_id recv: 2265420
# ack_id recv: 2266440
# ack_id recv: 2267460
# ack_id recv: 2268480
# ack_id recv: 2269500
# ack_id recv: 2270520
# ack_id recv: 2271540
# ack_id recv: 2272560
# ack_id recv: 2273580
# ack_id recv: 2274600
# ack_id recv: 2275620
# ack_id recv: 2276640
# ack_id recv: 2277660
# ack_id recv: 2278680
# ack_id recv: 2279700
# ack_id recv: 2280720
# ack_id recv: 2281740
# ack_id recv: 2282760
# ack_id recv: 2283780
# ack_id recv: 2284800
# ack_id recv: 2285820
# ack_id recv: 2286840
# ack_id recv: 2287860
# ack_id recv: 2288880
# ack_id recv: 2289900
# ack_id recv: 2290920
# ack_id recv: 2291940
# ack_id recv: 2292960
# ack_id recv: 2293980
# ack_id recv: 2295000
# ack_id recv: 2296020
# ack_id recv: 2297040
# ack_id recv: 2298060
# ack_id recv: 2299080
# ack_id recv: 2300100
# ack_id recv: 2301120
# ack_id recv: 2302140
# ack_id recv: 2303160
# ack_id recv: 2304180
# ack_id recv: 2305200
# ack_id recv: 2306220
# ack_id recv: 2307240
# ack_id recv: 2308260
# ack_id recv: 2309280
# ack_id recv: 2310300
# ack_id recv: 2311320
# ack_id recv: 2312340
# ack_id recv: 2313360
# ack_id recv: 2314380
# ack_id recv: 2315400
# ack_id recv: 2316420
# ack_id recv: 2317440
# ack_id recv: 2318460
# ack_id recv: 2319480
# ack_id recv: 2320500
# ack_id recv: 2321520
# ack_id recv: 2322540
# ack_id recv: 2323560
# ack_id recv: 2324580
# ack_id recv: 2325600
# ack_id recv: 2326620
# ack_id recv: 2327640
# ack_id recv: 2328660
# ack_id recv: 2329680
# ack_id recv: 2330700
# ack_id recv: 2331720
# ack_id recv: 2332740
# ack_id recv: 2333760
# ack_id recv: 2334780
# ack_id recv: 2335800
# ack_id recv: 2336820
# ack_id recv: 2337840
# ack_id recv: 2338860
# ack_id recv: 2339880
# ack_id recv: 2340900
# ack_id recv: 2341920
# ack_id recv: 2342940
# ack_id recv: 2343960
# ack_id recv: 2344980
# ack_id recv: 2346000
# ack_id recv: 2347020
# ack_id recv: 2348040
# ...
# ack_id recv: 4549200
# ack_id recv: 4550220
# ack_id recv: 4551240
# ack_id recv: 4552260
# ack_id recv: 4553280
# ack_id recv: 4554300
# ack_id recv: 4555320
# ack_id recv: 4556340
# ack_id recv: 4557360
# ack_id recv: 4558380
# ack_id recv: 4559400
# ack_id recv: 4560420
# ack_id recv: 4561440
# ack_id recv: 4562460
# ack_id recv: 4563480
# ack_id recv: 4564500
# ack_id recv: 4565520
# ack_id recv: 4566540
# ack_id recv: 4567560
# ack_id recv: 4568580
# ack_id recv: 4569600
# ack_id recv: 4570620
# ack_id recv: 4571640
# ack_id recv: 4572660
# ack_id recv: 4573680
# ack_id recv: 4574700
# ack_id recv: 4575720
# ack_id recv: 4576740
# ack_id recv: 4577760
# ack_id recv: 4578780
# ack_id recv: 4579800
# ack_id recv: 4580820
# ack_id recv: 4581840
# ack_id recv: 4582860
# ack_id recv: 4583880
# ack_id recv: 4584900
# ack_id recv: 4585920
# ack_id recv: 4586940
# ack_id recv: 4587960
# ack_id recv: 4588980
# ack_id recv: 4590000
# ack_id recv: 4591020
# ack_id recv: 4592040
# ack_id recv: 4593060
# ack_id recv: 4594080
# ack_id recv: 4595100
# ack_id recv: 4596120
# ack_id recv: 4597140
# ack_id recv: 4598160
# ack_id recv: 4599180
# ack_id recv: 4600200
# ack_id recv: 4601220
# ack_id recv: 4602240
# ack_id recv: 4603260
# ack_id recv: 4604280
# ack_id recv: 4605300
# ack_id recv: 4606320
# ack_id recv: 4607340
# ack_id recv: 4608360
# ack_id recv: 4609380
# ack_id recv: 4610400
# ack_id recv: 4611420
# ack_id recv: 4612440
# ack_id recv: 4613460
# ack_id recv: 4614480
# ack_id recv: 4615500
# ack_id recv: 4616520
# ack_id recv: 4617540
# ack_id recv: 4618560
# ack_id recv: 4619580
# ack_id recv: 4620600
# ack_id recv: 4621620
# ack_id recv: 4622640
# ack_id recv: 4623660
# ack_id recv: 4624680
# ack_id recv: 4625700
# ack_id recv: 4626720
# ack_id recv: 4627740
# ack_id recv: 4628760
# ack_id recv: 4629780
# ack_id recv: 4630800
# ack_id recv: 4631820
# ack_id recv: 4632840
# ack_id recv: 4633860
# ack_id recv: 4634880
# ack_id recv: 4635900
# ack_id recv: 4636920
# ack_id recv: 4637940
# ack_id recv: 4638960
# ack_id recv: 4639980
# ack_id recv: 4641000
# ack_id recv: 4642020
# ack_id recv: 4643040
# ack_id recv: 4644060
# ack_id recv: 4645080
# ack_id recv: 4646100
# ack_id recv: 4647120
# ack_id recv: 4648140
# ack_id recv: 4649160
# ack_id recv: 4650180
# ack_id recv: 4651200
# ack_id recv: 4652220
# ack_id recv: 4653240
# ack_id recv: 4654260
# ack_id recv: 4655280
# ack_id recv: 4656300
# ack_id recv: 4657320
# ack_id recv: 4658340
# ack_id recv: 4659360
# ack_id recv: 4660380
# ack_id recv: 4661400
# ack_id recv: 4662420
# ack_id recv: 4663440
# ack_id recv: 4664460
# ack_id recv: 4665480
# ack_id recv: 4666500
# ack_id recv: 4667520
# ack_id recv: 4668540
# ack_id recv: 4669560
# ack_id recv: 4670580
# ack_id recv: 4671600
# ack_id recv: 4672620
# ack_id recv: 4673640
# ack_id recv: 4674660
# ack_id recv: 4675680
# ack_id recv: 4676700
# ack_id recv: 4677720
# ack_id recv: 4678740
# ack_id recv: 4679760
# ack_id recv: 4680780
# ack_id recv: 4681800
# ack_id recv: 4682820
# ack_id recv: 4683840
# ack_id recv: 4684860
# ack_id recv: 4685880
# ack_id recv: 4686900
# ack_id recv: 4687920
# ack_id recv: 4688940
# ack_id recv: 4689960
# ack_id recv: 4690980
# ack_id recv: 4692000
# ack_id recv: 4693020
# ack_id recv: 4694040
# ack_id recv: 4695060
# ack_id recv: 4696080
# ack_id recv: 4697100
# ack_id recv: 4698120
# ack_id recv: 4699140
# ack_id recv: 4700160
# ack_id recv: 4701180
# ack_id recv: 4702200
# ack_id recv: 4703220
# ack_id recv: 4704240
# ack_id recv: 4705260
# ack_id recv: 4706280
# ack_id recv: 4707300
# ack_id recv: 4708320
# ack_id recv: 4709340
# ack_id recv: 4710360
# ack_id recv: 4711380
# ack_id recv: 4712400
# ack_id recv: 4713420
# ack_id recv: 4714440
# ack_id recv: 4715460
# ack_id recv: 4716480
# ack_id recv: 4717500
# ack_id recv: 4718520
# ack_id recv: 4719540
# ack_id recv: 4720560
# ack_id recv: 4721580
# ack_id recv: 4722600
# ack_id recv: 4723620
# ack_id recv: 4724640
# ack_id recv: 4725660
# ack_id recv: 4726680
# ack_id recv: 4727700
# ack_id recv: 4728720
# ack_id recv: 4729740
# ack_id recv: 4730760
# ack_id recv: 4731780
# ack_id recv: 4732800
# ack_id recv: 4733820
# ack_id recv: 4734840
# ack_id recv: 4735860
# ack_id recv: 4736880
# ack_id recv: 4737900
# ack_id recv: 4738920
# ack_id recv: 4739940
# ack_id recv: 4740960
# ack_id recv: 4741980
# ack_id recv: 4743000
# ack_id recv: 4744020
# ack_id recv: 4745040
# ack_id recv: 4746060
# ack_id recv: 4747080
# ack_id recv: 4748100
# ack_id recv: 4749120
# ack_id recv: 4750140
# ack_id recv: 4751160
# ack_id recv: 4752180
# ack_id recv: 4753200
# ack_id recv: 4754220
# ack_id recv: 4755240
# ack_id recv: 4756260
# ack_id recv: 4757280
# ack_id recv: 4758300
# ack_id recv: 4759320
# ack_id recv: 4760340
# ack_id recv: 4761360
# ack_id recv: 4762380
# ack_id recv: 4763400
# ack_id recv: 4764420
# ack_id recv: 4765440
# ack_id recv: 4766460
# ack_id recv: 4767480
# ack_id recv: 4768500
# ack_id recv: 4769520
# ack_id recv: 4770540
# ack_id recv: 4771560
# ack_id recv: 4772580
# ack_id recv: 4773600
# ack_id recv: 4774620
# ack_id recv: 4775640
# ack_id recv: 4776660
# ack_id recv: 4777680
# ack_id recv: 4778700
# ack_id recv: 4779720
# ack_id recv: 4780740
# ack_id recv: 4781760
# ack_id recv: 4782780
# ack_id recv: 4783800
# ack_id recv: 4784820
# ack_id recv: 4785840
# ack_id recv: 4786860
# ack_id recv: 4787880
# ack_id recv: 4788900
# ack_id recv: 4789920
# ack_id recv: 4790940
# ack_id recv: 4791960
# ack_id recv: 4792980
# ack_id recv: 4794000
# ack_id recv: 4795020
# ack_id recv: 4796040
# ack_id recv: 4797060
# ack_id recv: 4798080
# ack_id recv: 4799100
# ack_id recv: 4800120
# ack_id recv: 4801140
# ack_id recv: 4802160
# ack_id recv: 4803180
# ack_id recv: 4804200
# ack_id recv: 4805220
# ack_id recv: 4806240
# ack_id recv: 4807260
# ack_id recv: 4808280
# ack_id recv: 4809300
# ack_id recv: 4810320
# ack_id recv: 4811340
# ack_id recv: 4812360
# ack_id recv: 4813380
# ack_id recv: 4814400
# ack_id recv: 4815420
# ack_id recv: 4816440
# ack_id recv: 4817460
# ack_id recv: 4818480
# ack_id recv: 4819500
# ack_id recv: 4820520
# ack_id recv: 4821540
# ack_id recv: 4822560
# ack_id recv: 4823580
# ack_id recv: 4824600
# ack_id recv: 4825620
# ack_id recv: 4826640
# ack_id recv: 4827660
# ack_id recv: 4828680
# ack_id recv: 4829700
# ack_id recv: 4830720
# ack_id recv: 4831740
# ack_id recv: 4832760
# ack_id recv: 4833780
# ack_id recv: 4834800
# ack_id recv: 4835820
# ack_id recv: 4836840
# ack_id recv: 4837860
# ack_id recv: 4838880
# ack_id recv: 4839900
# ack_id recv: 4840920
# ack_id recv: 4841940
# ack_id recv: 4842960
# ack_id recv: 4843980
# ack_id recv: 4845000
# ack_id recv: 4846020
# ack_id recv: 4847040
# ack_id recv: 4848060
# ack_id recv: 4849080
# ack_id recv: 4850100
# ack_id recv: 4851120
# ack_id recv: 4852140
# ack_id recv: 4853160
# ack_id recv: 4854180
# ack_id recv: 4855200
# ack_id recv: 4856220
# ack_id recv: 4857240
# ack_id recv: 4858260
# ack_id recv: 4859280
# ack_id recv: 4860300
# ack_id recv: 4861320
# ack_id recv: 4862340
# ack_id recv: 4863360
# ack_id recv: 4864380
# ack_id recv: 4865400
# ack_id recv: 4866420
# ack_id recv: 4867440
# ack_id recv: 4868460
# ack_id recv: 4869480
# ack_id recv: 4870500
# ack_id recv: 4871520
# ack_id recv: 4872540
# ack_id recv: 4873560
# ack_id recv: 4874580
# ack_id recv: 4875600
# ack_id recv: 4876620
# ack_id recv: 4877640
# ack_id recv: 4878660
# ack_id recv: 4879680
# ack_id recv: 4880700
# ack_id recv: 4881720
# ack_id recv: 4882740
# ack_id recv: 4883760
# ack_id recv: 4884780
# ack_id recv: 4885800
# ack_id recv: 4886820
# ack_id recv: 4887840
# ack_id recv: 4888860
# ack_id recv: 4889880
# ack_id recv: 4890900
# ack_id recv: 4891920
# ack_id recv: 4892940
# ack_id recv: 4893960
# ack_id recv: 4894980
# ack_id recv: 4896000
# ack_id recv: 4897020
# ack_id recv: 4898040
# ack_id recv: 4899060
# ack_id recv: 4900080
# ack_id recv: 4901100
# ack_id recv: 4902120
# ack_id recv: 4903140
# ack_id recv: 4904160
# ack_id recv: 4905180
# ack_id recv: 4906200
# ack_id recv: 4907220
# ack_id recv: 4908240
# ack_id recv: 4909260
# ack_id recv: 4910280
# ack_id recv: 4911300
# ack_id recv: 4912320
# ack_id recv: 4913340
# ack_id recv: 4914360
# ack_id recv: 4915380
# ack_id recv: 4916400
# ack_id recv: 4917420
# ack_id recv: 4918440
# ack_id recv: 4919460
# ack_id recv: 4920480
# ack_id recv: 4921500
# ack_id recv: 4922520
# ack_id recv: 4923540
# ack_id recv: 4924560
# ack_id recv: 4925580
# ack_id recv: 4926600
# ack_id recv: 4927620
# ack_id recv: 4928640
# ack_id recv: 4929660
# ack_id recv: 4930680
# ack_id recv: 4931700
# ack_id recv: 4932720
# ack_id recv: 4933740
# ack_id recv: 4934760
# ack_id recv: 4935780
# ack_id recv: 4936800
# ack_id recv: 4937820
# ack_id recv: 4938840
# ack_id recv: 4939860
# ack_id recv: 4940880
# ack_id recv: 4941900
# ack_id recv: 4942920
# ack_id recv: 4943940
# ack_id recv: 4944960
# ack_id recv: 4945980
# ack_id recv: 4947000
# ack_id recv: 4948020
# ack_id recv: 4949040
# ack_id recv: 4950060
# ack_id recv: 4951080
# ack_id recv: 4952100
# ack_id recv: 4953120
# ack_id recv: 4954140
# ack_id recv: 4955160
# ack_id recv: 4956180
# ack_id recv: 4957200
# ack_id recv: 4958220
# ack_id recv: 4959240
# ack_id recv: 4960260
# ack_id recv: 4961280
# ack_id recv: 4962300
# ack_id recv: 4963320
# ack_id recv: 4964340
# ack_id recv: 4965360
# ack_id recv: 4966380
# ack_id recv: 4967400
# ack_id recv: 4968420
# ack_id recv: 4969440
# ack_id recv: 4970460
# ack_id recv: 4971480
# ack_id recv: 4972500
# ack_id recv: 4973520
# ack_id recv: 4974540
# ack_id recv: 4975560
# ack_id recv: 4976580
# ack_id recv: 4977600
# ack_id recv: 4978620
# ack_id recv: 4979640
# ack_id recv: 4980660
# ack_id recv: 4981680
# ack_id recv: 4982700
# ack_id recv: 4983720
# ack_id recv: 4984740
# ack_id recv: 4985760
# ack_id recv: 4986780
# ack_id recv: 4987800
# ack_id recv: 4988820
# ack_id recv: 4989840
# ack_id recv: 4990860
# ack_id recv: 4991880
# ack_id recv: 4992900
# ack_id recv: 4993920
# ack_id recv: 4994940
# ack_id recv: 4995960
# ack_id recv: 4996980
# ack_id recv: 4998000
# ack_id recv: 4999020
# ack_id recv: 5000040
# ack_id recv: 5001060
# ack_id recv: 5002080
# ack_id recv: 5003100
# ack_id recv: 5004120
# ack_id recv: 5005140
# ack_id recv: 5006160
# ack_id recv: 5007180
# ack_id recv: 5008200
# ack_id recv: 5009220
# ack_id recv: 5010240
# ack_id recv: 5011260
# ack_id recv: 5012280
# ack_id recv: 5013300
# ack_id recv: 5014320
# ack_id recv: 5015340
# ack_id recv: 5016360
# ack_id recv: 5017380
# ack_id recv: 5018400
# ack_id recv: 5019420
# ack_id recv: 5020440
# ack_id recv: 5021460
# ack_id recv: 5022480
# ack_id recv: 5023500
# ack_id recv: 5024520
# ack_id recv: 5025540
# ack_id recv: 5026560
# ack_id recv: 5027580
# ack_id recv: 5028600
# ack_id recv: 5029620
# ack_id recv: 5030640
# ack_id recv: 5031660
# ack_id recv: 5032680
# ack_id recv: 5033700
# ack_id recv: 5034720
# ack_id recv: 5035740
# ack_id recv: 5036760
# ack_id recv: 5037780
# ack_id recv: 5038800
# ack_id recv: 5039820
# ack_id recv: 5040840
# ack_id recv: 5041860
# ack_id recv: 5042880
# ack_id recv: 5043900
# ack_id recv: 5044920
# ack_id recv: 5045940
# ack_id recv: 5046960
# ack_id recv: 5047980
# ack_id recv: 5049000
# ack_id recv: 5050020
# ack_id recv: 5051040
# ack_id recv: 5052060
# ack_id recv: 5053080
# ack_id recv: 5054100
# ack_id recv: 5055120
# ack_id recv: 5056140
# ack_id recv: 5057160
# ack_id recv: 5058180
# ack_id recv: 5059200
# ack_id recv: 5060220
# ack_id recv: 5061240
# ack_id recv: 5062260
# ack_id recv: 5063280
# ack_id recv: 5064300
# ack_id recv: 5065320
# ack_id recv: 5066340
# ack_id recv: 5067360
# ack_id recv: 5068380
# ack_id recv: 5069400
# ack_id recv: 5070420
# ack_id recv: 5071440
# ack_id recv: 5072460
# ack_id recv: 5073480
# ack_id recv: 5074500
# ack_id recv: 5075520
# ack_id recv: 5076540
# ack_id recv: 5077560
# ack_id recv: 5078580
# ack_id recv: 5079600
# ack_id recv: 5080620
# ack_id recv: 5081640
# ack_id recv: 5082660
# ack_id recv: 5083680
# ack_id recv: 5084700
# ack_id recv: 5085720
# ack_id recv: 5086740
# ack_id recv: 5087760
# ack_id recv: 5088780
# ack_id recv: 5089800
# ack_id recv: 5090820
# ack_id recv: 5091840
# ack_id recv: 5092860
# ack_id recv: 5093880
# ack_id recv: 5094900
# ack_id recv: 5095920
# ack_id recv: 5096940
# ack_id recv: 5097960
# ack_id recv: 5098980
# ack_id recv: 5100000
# ack_id recv: 5101020
# ack_id recv: 5102040
# ack_id recv: 5103060
# ack_id recv: 5104080
# ack_id recv: 5105100
# ack_id recv: 5106120
# ack_id recv: 5107140
# ack_id recv: 5108160
# ack_id recv: 5109180
# ack_id recv: 5110200
# ack_id recv: 5111220
# ack_id recv: 5112240
# ack_id recv: 5113260
# ack_id recv: 5114280
# ack_id recv: 5115300
# ack_id recv: 5116320
# ack_id recv: 5117340
# ack_id recv: 5118360
# ack_id recv: 5119380
# ack_id recv: 5120400
# ack_id recv: 5121420
# ack_id recv: 5122440
# ack_id recv: 5123460
# ack_id recv: 5124480
# ack_id recv: 5125500
# ack_id recv: 5126520
# ack_id recv: 5127540
# ack_id recv: 5128560
# ack_id recv: 5129580
# ack_id recv: 5130600
# ack_id recv: 5131620
# ack_id recv: 5132640
# ack_id recv: 5133660
# ack_id recv: 5134680
# ack_id recv: 5135700
# ack_id recv: 5136720
# ack_id recv: 5137740
# ack_id recv: 5138760
# ack_id recv: 5139780
# ack_id recv: 5140800
# ack_id recv: 5141820
# ack_id recv: 5142840
# ack_id recv: 5143860
# ack_id recv: 5144880
# ack_id recv: 5145900
# ack_id recv: 5146920
# ack_id recv: 5147940
# ack_id recv: 5148960
# ack_id recv: 5149980
# ack_id recv: 5151000
# ack_id recv: 5152020
# ack_id recv: 5153040
# ack_id recv: 5154060
# ack_id recv: 5155080
# ack_id recv: 5156100
# ack_id recv: 5157120
# ack_id recv: 5158140
# ack_id recv: 5159160
# ack_id recv: 5160180
# ack_id recv: 5161200
# ack_id recv: 5162220
# ack_id recv: 5163240
# ack_id recv: 5164260
# ack_id recv: 5165280
# ack_id recv: 5166300
# ack_id recv: 5167320
# ack_id recv: 5168340
# ack_id recv: 5169360
# ack_id recv: 5170380
# ack_id recv: 5171400
# ack_id recv: 5172420
# ack_id recv: 5173440
# ack_id recv: 5174460
# ack_id recv: 5175480
# ack_id recv: 5176500
# ack_id recv: 5177520
# ack_id recv: 5178540
# ack_id recv: 5179560
# ack_id recv: 5180580
# ack_id recv: 5181600
# ack_id recv: 5182620
# ack_id recv: 5183640
# ack_id recv: 5184660
# ack_id recv: 5185680
# ack_id recv: 5186700
# ack_id recv: 5187720
# ack_id recv: 5188740
# ack_id recv: 5189760
# ack_id recv: 5190780
# ack_id recv: 5191800
# ack_id recv: 5192820
# ack_id recv: 5193840
# ack_id recv: 5194860
# ack_id recv: 5195880
# ack_id recv: 5196900
# ack_id recv: 5197920
# ack_id recv: 5198940
# ack_id recv: 5199960
# ack_id recv: 5200980
# ack_id recv: 5202000
# ack_id recv: 5203020
# ack_id recv: 5204040
# ack_id recv: 5205060
# ack_id recv: 5206080
# ack_id recv: 5207100
# ack_id recv: 5208120
# ack_id recv: 5209140
# ack_id recv: 5210160
# ack_id recv: 5211180
# ack_id recv: 5212200
# ack_id recv: 5213220
# ack_id recv: 5214240
# ack_id recv: 5215260
# ack_id recv: 5216280
# ack_id recv: 5217300
# ack_id recv: 5218320
# ack_id recv: 5219340
# ack_id recv: 5220360
# ack_id recv: 5221380
# ack_id recv: 5222400
# ack_id recv: 5223420
# ack_id recv: 5224440
# ack_id recv: 5225460
# ack_id recv: 5226480
# ack_id recv: 5227500
# ack_id recv: 5228520
# ack_id recv: 5229540
# ack_id recv: 5230560
# ack_id recv: 5231580
# ack_id recv: 5232600
# ack_id recv: 5233620
# ack_id recv: 5234640
# ack_id recv: 5235660
# ack_id recv: 5236680
# ack_id recv: 5237700
# ack_id recv: 5238720
# ack_id recv: 5239740
# ack_id recv: 5240760
# ack_id recv: 5241780
# ack_id recv: 5242800
# ack_id recv: 5243820
# ack_id recv: 5244840
# ack_id recv: 5245860
# ack_id recv: 5246880
# ack_id recv: 5247900
# ack_id recv: 5248920
# ack_id recv: 5249940
# ack_id recv: 5250960
# ack_id recv: 5251980
# ack_id recv: 5253000
# ack_id recv: 5254020
# ack_id recv: 5255040
# ack_id recv: 5256060
# ack_id recv: 5257080
# ack_id recv: 5258100
# ack_id recv: 5259120
# ack_id recv: 5260140
# ack_id recv: 5261160
# ack_id recv: 5262180
# ack_id recv: 5263200
# ack_id recv: 5264220
# ack_id recv: 5265240
# ack_id recv: 5266260
# ack_id recv: 5267280
# ack_id recv: 5268300
# ack_id recv: 5269320
# ack_id recv: 5270340
# ack_id recv: 5271360
# ack_id recv: 5272380
# ack_id recv: 5273400
# ack_id recv: 5274420
# ack_id recv: 5275440
# ack_id recv: 5276460
# ack_id recv: 5277480
# ack_id recv: 5278500
# ack_id recv: 5279520
# ack_id recv: 5280540
# ack_id recv: 5281560
# ack_id recv: 5282580
# ack_id recv: 5283600
# ack_id recv: 5284620
# ack_id recv: 5285640
# ack_id recv: 5286660
# ack_id recv: 5287680
# ack_id recv: 5288700
# ack_id recv: 5289720
# ack_id recv: 5290740
# ack_id recv: 5291760
# ack_id recv: 5292780
# ack_id recv: 5293800
# ack_id recv: 5294820
# ack_id recv: 5295840
# ack_id recv: 5296860
# ack_id recv: 5297880
# ack_id recv: 5298900
# ack_id recv: 5299920
# ack_id recv: 5300940
# ack_id recv: 5301960
# ack_id recv: 5302980
# ack_id recv: 5304000
# ack_id recv: 5305020
# ack_id recv: 5306040
# ack_id recv: 5307060
# ack_id recv: 5308080
# ack_id recv: 5309100
# ack_id recv: 5310120
# ack_id recv: 5311140
# ack_id recv: 5312160
# ack_id recv: 5313180
# ack_id recv: 5314200
# ack_id recv: 5315220
# ack_id recv: 5316240
# ack_id recv: 5317260
# ack_id recv: 5318280
# ack_id recv: 5319300
# ack_id recv: 5319693
# ack_id recv: 5319693
# ack_id recv: 5319693
# ack_id recv: 5319696
# 87333.3, 0.37, 233162.13

# %% [markdown]
# Output: 87333.3, 0.37, 233162.13 1m 9s

# %% [markdown]
# ## Stop the Receiver

# %%
import socket

PACKET_SIZE = 1024
SEQ_ID_SIZE = 4
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
Receiver = ('localhost', 5001)
def sendFinack(sender):
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    sender.sendto(finack, Receiver)
    sender.close()
sender = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
sender.bind(("localhost", 5002))
sender.settimeout(1)

sendFinack(sender)
