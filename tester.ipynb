# %% [markdown]
# newgrp docker
#
# ./start-simulation.sh

# %% [markdown]
# ## Stop the Receiver

# %%
import socket

PACKET_SIZE = 1024
SEQ_ID_SIZE = 4
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
Receiver = ('localhost', 5001)
def sendFinack(sender):
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    sender.sendto(finack, Receiver)
    sender.close()
sender = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
sender.bind(("localhost", 5002))
sender.settimeout(1)

sendFinack(sender)

# %% [markdown]
# ## Stop and Wait

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
total_packet_delay = 0
packetCount = 0

# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 1
    
    # start sending data from 0th sequence
    seq_id = 0
    sent_empty = False
    # Run a timer for throughput
    while True:
        
        udp_socket.settimeout(1)
        
        # construct message
        # sequence id of length SEQ_ID_SIZE + message of remaining PACKET_SIZE - SEQ_ID_SIZE bytes
        message = int.to_bytes(seq_id, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id : seq_id + MESSAGE_SIZE]

        # constructs the empty packet if we have sent all previous data
        if seq_id > len(data) and not sent_empty:
            message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
            sent_empty = True
            print("is making")
            

        # send message
        udp_socket.sendto(message, ('localhost', 5001))
        packet_delay = time()
        packetCount += 1
        
        # wait for acknowledgement
        ack_id = 0
        while True:
            try:
                # wait for ack
                ack, _ = udp_socket.recvfrom(PACKET_SIZE)
                total_packet_delay += time() - packet_delay

                # extract ack id
                ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
                
                print(ack_id, ack[SEQ_ID_SIZE:])

                if ack_id != len(data) or not sent_empty:
                    break
                
            except socket.timeout:
                # no ack received, resend unacked message
                timeoutDuration += timeoutDuration
                udp_socket.settimeout(timeoutDuration)
                udp_socket.sendto(message, ('localhost', 5001))
          
        if ack_id == len(data) + 3:
            break
    
        # move sequence id forward
        seq_id += MESSAGE_SIZE      

    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_packet_delay = total_packet_delay / packetCount

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_packet_delay

    print(f'{round(throughput, 2)}, {round(avg_packet_delay, 2)}, {round(performance_metric, 2)}')
    
    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))
    
    # close the connection
    udp_socket.close()
# Out:
# 1020 b'ack'
# 2040 b'ack'
# 3060 b'ack'
# 4080 b'ack'
# 5100 b'ack'
# 6120 b'ack'
# 7140 b'ack'
# 8160 b'ack'
# 9180 b'ack'
# 10200 b'ack'
# 11220 b'ack'
# 12240 b'ack'
# 13260 b'ack'
# 14280 b'ack'
# 15300 b'ack'
# 16320 b'ack'
# 17340 b'ack'
# 18360 b'ack'
# 19380 b'ack'
# 20400 b'ack'
# 21420 b'ack'
# 22440 b'ack'
# 23460 b'ack'
# 24480 b'ack'
# 25500 b'ack'
# 26520 b'ack'
# 27540 b'ack'
# 28560 b'ack'
# 29580 b'ack'
# 30600 b'ack'
# 31620 b'ack'
# 32640 b'ack'
# 33660 b'ack'
# 34680 b'ack'
# 35700 b'ack'
# 36720 b'ack'
# 37740 b'ack'
# 38760 b'ack'
# 39780 b'ack'
# 40800 b'ack'
# 41820 b'ack'
# 42840 b'ack'
# 43860 b'ack'
# 44880 b'ack'
# 45900 b'ack'
# 46920 b'ack'
# 47940 b'ack'
# 48960 b'ack'
# 49980 b'ack'
# 51000 b'ack'
# 52020 b'ack'
# 53040 b'ack'
# 54060 b'ack'
# 55080 b'ack'
# 56100 b'ack'
# 57120 b'ack'
# 58140 b'ack'
# 59160 b'ack'
# 60180 b'ack'
# 61200 b'ack'
# 62220 b'ack'
# 63240 b'ack'
# 64260 b'ack'
# 65280 b'ack'
# 66300 b'ack'
# 67320 b'ack'
# 68340 b'ack'
# 69360 b'ack'
# 70380 b'ack'
# 71400 b'ack'
# 72420 b'ack'
# 73440 b'ack'
# 74460 b'ack'
# 75480 b'ack'
# 76500 b'ack'
# 77520 b'ack'
# 78540 b'ack'
# 79560 b'ack'
# 80580 b'ack'
# 81600 b'ack'
# 82620 b'ack'
# 83640 b'ack'
# 84660 b'ack'
# 85680 b'ack'
# 86700 b'ack'
# 87720 b'ack'
# 88740 b'ack'
# 89760 b'ack'
# 90780 b'ack'
# 91800 b'ack'
# 92820 b'ack'
# 93840 b'ack'
# 94860 b'ack'
# 95880 b'ack'
# 96900 b'ack'
# 97920 b'ack'
# 98940 b'ack'
# 99960 b'ack'
# 100980 b'ack'
# 102000 b'ack'
# 103020 b'ack'
# 104040 b'ack'
# 105060 b'ack'
# 106080 b'ack'
# 107100 b'ack'
# 108120 b'ack'
# 109140 b'ack'
# 110160 b'ack'
# 111180 b'ack'
# 112200 b'ack'
# 113220 b'ack'
# 114240 b'ack'
# 115260 b'ack'
# 116280 b'ack'
# 117300 b'ack'
# 118320 b'ack'
# 119340 b'ack'
# 120360 b'ack'
# 121380 b'ack'
# 122400 b'ack'
# 123420 b'ack'
# 124440 b'ack'
# 125460 b'ack'
# 126480 b'ack'
# 127500 b'ack'
# 128520 b'ack'
# 129540 b'ack'
# 130560 b'ack'
# 131580 b'ack'
# 132600 b'ack'
# 133620 b'ack'
# 134640 b'ack'
# 135660 b'ack'
# 136680 b'ack'
# 137700 b'ack'
# 138720 b'ack'
# 139740 b'ack'
# 140760 b'ack'
# 141780 b'ack'
# 142800 b'ack'
# 143820 b'ack'
# 144840 b'ack'
# 145860 b'ack'
# 146880 b'ack'
# 147900 b'ack'
# 148920 b'ack'
# 149940 b'ack'
# 150960 b'ack'
# 151980 b'ack'
# 153000 b'ack'
# 154020 b'ack'
# 155040 b'ack'
# 156060 b'ack'
# 157080 b'ack'
# 158100 b'ack'
# 159120 b'ack'
# 160140 b'ack'
# 161160 b'ack'
# 162180 b'ack'
# 163200 b'ack'
# 164220 b'ack'
# 165240 b'ack'
# 166260 b'ack'
# 167280 b'ack'
# 168300 b'ack'
# 169320 b'ack'
# 170340 b'ack'
# 171360 b'ack'
# 172380 b'ack'
# 173400 b'ack'
# 174420 b'ack'
# 175440 b'ack'
# 176460 b'ack'
# 177480 b'ack'
# 178500 b'ack'
# 179520 b'ack'
# 180540 b'ack'
# 181560 b'ack'
# 182580 b'ack'
# 183600 b'ack'
# 184620 b'ack'
# 185640 b'ack'
# 186660 b'ack'
# 187680 b'ack'
# 188700 b'ack'
# 189720 b'ack'
# 190740 b'ack'
# 191760 b'ack'
# 192780 b'ack'
# 193800 b'ack'
# 194820 b'ack'
# 195840 b'ack'
# 196860 b'ack'
# 197880 b'ack'
# 198900 b'ack'
# 199920 b'ack'
# 200940 b'ack'
# 201960 b'ack'
# 202980 b'ack'
# 204000 b'ack'
# 205020 b'ack'
# 206040 b'ack'
# 207060 b'ack'
# 208080 b'ack'
# 209100 b'ack'
# 210120 b'ack'
# 211140 b'ack'
# 212160 b'ack'
# 213180 b'ack'
# 214200 b'ack'
# 215220 b'ack'
# 216240 b'ack'
# 217260 b'ack'
# 218280 b'ack'
# 219300 b'ack'
# 220320 b'ack'
# 221340 b'ack'
# 222360 b'ack'
# 223380 b'ack'
# 224400 b'ack'
# 225420 b'ack'
# 226440 b'ack'
# 227460 b'ack'
# 228480 b'ack'
# 229500 b'ack'
# 230520 b'ack'
# 231540 b'ack'
# 232560 b'ack'
# 233580 b'ack'
# 234600 b'ack'
# 235620 b'ack'
# 236640 b'ack'
# 237660 b'ack'
# 238680 b'ack'
# 239700 b'ack'
# 240720 b'ack'
# 241740 b'ack'
# 242760 b'ack'
# 243780 b'ack'
# 244800 b'ack'
# 245820 b'ack'
# 246840 b'ack'
# 247860 b'ack'
# 248880 b'ack'
# 249900 b'ack'
# 250920 b'ack'
# 251940 b'ack'
# 252960 b'ack'
# 253980 b'ack'
# 255000 b'ack'
# 256020 b'ack'
# 257040 b'ack'
# 258060 b'ack'
# 259080 b'ack'
# 260100 b'ack'
# 261120 b'ack'
# 262140 b'ack'
# 263160 b'ack'
# 264180 b'ack'
# 265200 b'ack'
# 266220 b'ack'
# 267240 b'ack'
# 268260 b'ack'
# 269280 b'ack'
# 270300 b'ack'
# 271320 b'ack'
# 272340 b'ack'
# 273360 b'ack'
# 274380 b'ack'
# 275400 b'ack'
# 276420 b'ack'
# 277440 b'ack'
# 278460 b'ack'
# 279480 b'ack'
# 280500 b'ack'
# 281520 b'ack'
# 282540 b'ack'
# 283560 b'ack'
# 284580 b'ack'
# 285600 b'ack'
# 286620 b'ack'
# 287640 b'ack'
# 288660 b'ack'
# 289680 b'ack'
# 290700 b'ack'
# 291720 b'ack'
# 292740 b'ack'
# 293760 b'ack'
# 294780 b'ack'
# 295800 b'ack'
# 296820 b'ack'
# 297840 b'ack'
# 298860 b'ack'
# 299880 b'ack'
# 300900 b'ack'
# 301920 b'ack'
# 302940 b'ack'
# 303960 b'ack'
# 304980 b'ack'
# 306000 b'ack'
# 307020 b'ack'
# 308040 b'ack'
# 309060 b'ack'
# 310080 b'ack'
# 311100 b'ack'
# 312120 b'ack'
# 313140 b'ack'
# 314160 b'ack'
# 315180 b'ack'

# %% [markdown]
# Output: 9898.89, 0.1, 97115.41

# %% [markdown]
# # Sliding Window

# %%
# Code has been sampled from Muhammad Haroon's code, with modifications.
# Original code: https://github.com/Haroon96/ecs152a-fall-2023/blob/main/week7/docker/sender.py

import socket
from time import time 

# total packet size
PACKET_SIZE = 1024
# bytes reserved for sequence id
SEQ_ID_SIZE = 4
# bytes available for message
MESSAGE_SIZE = PACKET_SIZE - SEQ_ID_SIZE
# total packets to send
WINDOW_SIZE = 100

# read data
with open('./docker/file.mp3', 'rb') as f:
    data = f.read()
 
total_packet_delay = 0
packetCount = 0
 
# create a udp socket
start_throughput = time()
with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as udp_socket:

    # bind the socket to a OS port
    udp_socket.bind(("0.0.0.0", 5000))

    timeoutDuration = 1

    # start sending data from 0th sequence
    seq_id = 0
    windowSpace = WINDOW_SIZE

    acks = {}
    packet_start_times = {}
    packet_end_times = {}
    udp_socket.settimeout(1)

    sent_empty = False

    ack_id = 0
    while True:
        for _ in range(windowSpace):
            message = int.to_bytes(seq_id, SEQ_ID_SIZE, byteorder='big', signed=True) + data[seq_id: seq_id + MESSAGE_SIZE]
            
            # constructs the empty packet if we have sent all previous data
            if seq_id > len(data) and not sent_empty:
                message = int.to_bytes(len(data), SEQ_ID_SIZE, byteorder='big', signed=True)
                sent_empty = True
            
            acks[seq_id] = False
            
            if seq_id not in packet_start_times:
                packet_start_times[seq_id] = time()

            udp_socket.sendto(message, ('localhost', 5001))

            seq_id += MESSAGE_SIZE
            windowSpace -= 1

            if len(message) == 0:
                break
            
        try:
            if ack_id in packet_start_times and time() - packet_start_times[ack_id] >= timeoutDuration:
                print()
                print("timeout resend ack_id: ", ack_id)
                message = int.to_bytes(ack_id, SEQ_ID_SIZE, byteorder='big', signed=True) + data[ack_id: ack_id + MESSAGE_SIZE]

                udp_socket.sendto(message, ('localhost', 5001))
                packet_start_times[ack_id] = time()
                
            ack, _ = udp_socket.recvfrom(PACKET_SIZE)
            
            ack_id = int.from_bytes(ack[:SEQ_ID_SIZE], byteorder='big')
            ack_message = ack[SEQ_ID_SIZE:]
            
            if ack_message == b'fin':
                break

            # update acks below cumulative ack
            for a in acks:
                if a < ack_id and acks[a] != True:
                    acks[a] = True
                    windowSpace += 1
                    if a not in packet_end_times:
                            packet_end_times[a] = time()

        except socket.timeout:
            pass
     
    
    # Run the time until the last packet from the file, and NOT the final closing message. 
    end_throughput = time()

    # send final closing message
    finack = int.to_bytes(0, SEQ_ID_SIZE, byteorder='big', signed=True) + b'==FINACK=='
    udp_socket.sendto(finack, ('localhost', 5001))   
    
    # get throughput
    throughput  = len(data) / (end_throughput - start_throughput)

    # get average packet delay
    avg_delay = 0
    for k in packet_end_times.keys():
        packet_delay = packet_end_times[k] - packet_start_times[k]
        avg_delay += packet_delay

    avg_delay /= len(packet_end_times.keys())

    # get performance metric (throughput/average per packet delay)
    performance_metric = throughput / avg_delay

    print(f'{round(throughput, 2)}, {round(avg_delay, 2)}, {round(performance_metric, 2)}')

    # close the connection
    udp_socket.close()
# Out:
# 0 b'ack'
# timeout resend ack_id:  0
# 1020 b'ack'
# timeout resend ack_id:  1020
# 2040 b'ack'
# timeout resend ack_id:  2040
# 3060 b'ack'
# timeout resend ack_id:  3060
# 4080 b'ack'
# timeout resend ack_id:  4080
# 5100 b'ack'
# timeout resend ack_id:  5100
# 6120 b'ack'
# timeout resend ack_id:  6120
# 7140 b'ack'
# timeout resend ack_id:  7140
# 168300 b'ack'
# timeout resend ack_id:  168300
# 169320 b'ack'
# timeout resend ack_id:  169320
# 170340 b'ack'
# timeout resend ack_id:  170340
# 171360 b'ack'
# timeout resend ack_id:  171360
# 172380 b'ack'
# timeout resend ack_id:  172380
# 173400 b'ack'
# timeout resend ack_id:  173400
# 174420 b'ack'
# timeout resend ack_id:  174420
# 175440 b'ack'
# timeout resend ack_id:  175440
# 176460 b'ack'
# timeout resend ack_id:  176460
# 177480 b'ack'
# timeout resend ack_id:  177480
# 178500 b'ack'
# timeout resend ack_id:  178500
# 179520 b'ack'
# timeout resend ack_id:  179520
# 180540 b'ack'
# timeout resend ack_id:  180540
# 181560 b'ack'
# timeout resend ack_id:  181560
# 182580 b'ack'
# timeout resend ack_id:  182580
# 183600 b'ack'
# timeout resend ack_id:  183600
# 184620 b'ack'
# timeout resend ack_id:  184620
# 185640 b'ack'
# timeout resend ack_id:  185640
# 186660 b'ack'
# timeout resend ack_id:  186660
# 187680 b'ack'
# timeout resend ack_id:  187680
# 188700 b'ack'
# timeout resend ack_id:  188700
# 189720 b'ack'
# timeout resend ack_id:  189720
# 190740 b'ack'
# timeout resend ack_id:  190740
# 191760 b'ack'
# timeout resend ack_id:  191760
# 192780 b'ack'
# timeout resend ack_id:  192780
# 193800 b'ack'
# timeout resend ack_id:  193800
# 194820 b'ack'
# timeout resend ack_id:  194820
# 195840 b'ack'
# timeout resend ack_id:  195840
# 196860 b'ack'
# timeout resend ack_id:  196860
# 197880 b'ack'
# timeout resend ack_id:  197880
# 198900 b'ack'
# timeout resend ack_id:  198900
# 199920 b'ack'
# timeout resend ack_id:  199920
# 200940 b'ack'
# timeout resend ack_id:  200940
# 201960 b'ack'
# timeout resend ack_id:  201960
# 202980 b'ack'
# timeout resend ack_id:  202980
# 204000 b'ack'
# timeout resend ack_id:  204000
# 205020 b'ack'
# timeout resend ack_id:  205020
# 206040 b'ack'
# timeout resend ack_id:  206040
# 207060 b'ack'
# timeout resend ack_id:  207060
# 208080 b'ack'
# timeout resend ack_id:  208080
# 209100 b'ack'
# timeout resend ack_id:  209100
# 210120 b'ack'
# timeout resend ack_id:  210120
# 211140 b'ack'
# timeout resend ack_id:  211140
# 212160 b'ack'
# timeout resend ack_id:  212160
# 213180 b'ack'
# timeout resend ack_id:  213180
# 214200 b'ack'
# timeout resend ack_id:  214200
# 215220 b'ack'
# timeout resend ack_id:  215220
# 216240 b'ack'
# timeout resend ack_id:  216240
# 217260 b'ack'
# timeout resend ack_id:  217260
# 218280 b'ack'
# timeout resend ack_id:  218280
# 219300 b'ack'
# timeout resend ack_id:  219300
# 220320 b'ack'
# timeout resend ack_id:  220320
# 221340 b'ack'
# timeout resend ack_id:  221340
# 222360 b'ack'
# timeout resend ack_id:  222360
# 223380 b'ack'
# timeout resend ack_id:  223380
# 224400 b'ack'
# timeout resend ack_id:  224400
# 225420 b'ack'
# timeout resend ack_id:  225420
# 226440 b'ack'
# timeout resend ack_id:  226440
# 227460 b'ack'
# timeout resend ack_id:  227460
# 228480 b'ack'
# timeout resend ack_id:  228480
# 229500 b'ack'
# timeout resend ack_id:  229500
# 230520 b'ack'
# timeout resend ack_id:  230520
# 231540 b'ack'
# timeout resend ack_id:  231540
# 232560 b'ack'
# timeout resend ack_id:  232560
# 233580 b'ack'
# timeout resend ack_id:  233580
# 234600 b'ack'
# timeout resend ack_id:  234600
# 235620 b'ack'
# timeout resend ack_id:  235620
# 236640 b'ack'
# timeout resend ack_id:  236640
# 237660 b'ack'
# timeout resend ack_id:  237660
# 238680 b'ack'
# timeout resend ack_id:  238680
# 239700 b'ack'
# timeout resend ack_id:  239700
# 240720 b'ack'
# timeout resend ack_id:  240720
# 241740 b'ack'
# timeout resend ack_id:  241740
# 242760 b'ack'
# timeout resend ack_id:  242760
# 243780 b'ack'
# timeout resend ack_id:  243780
# 244800 b'ack'
# timeout resend ack_id:  244800
# 245820 b'ack'
# timeout resend ack_id:  245820
# 246840 b'ack'
# timeout resend ack_id:  246840
# 247860 b'ack'
# timeout resend ack_id:  247860
# 248880 b'ack'
# timeout resend ack_id:  248880
# 249900 b'ack'
# timeout resend ack_id:  249900
# 250920 b'ack'
# timeout resend ack_id:  250920
# 251940 b'ack'
# timeout resend ack_id:  251940
# 252960 b'ack'
# timeout resend ack_id:  252960
# 253980 b'ack'
# timeout resend ack_id:  253980
# 255000 b'ack'
# timeout resend ack_id:  255000
# 256020 b'ack'
# timeout resend ack_id:  256020
# 257040 b'ack'
# timeout resend ack_id:  257040
# 258060 b'ack'
# timeout resend ack_id:  258060
# 259080 b'ack'
# timeout resend ack_id:  259080
# 260100 b'ack'
# timeout resend ack_id:  260100
# 261120 b'ack'
# timeout resend ack_id:  261120
# 262140 b'ack'
# timeout resend ack_id:  262140
# 263160 b'ack'
# timeout resend ack_id:  263160
# 264180 b'ack'
# timeout resend ack_id:  264180
# 265200 b'ack'
# timeout resend ack_id:  265200
# 266220 b'ack'
# timeout resend ack_id:  266220
# 267240 b'ack'
# timeout resend ack_id:  267240
# 268260 b'ack'
# timeout resend ack_id:  268260
# 269280 b'ack'
# timeout resend ack_id:  269280
# 270300 b'ack'
# timeout resend ack_id:  270300
# 271320 b'ack'
# timeout resend ack_id:  271320
# 272340 b'ack'
# timeout resend ack_id:  272340
# 273360 b'ack'
# timeout resend ack_id:  273360
# 274380 b'ack'
# timeout resend ack_id:  274380
# 275400 b'ack'
# timeout resend ack_id:  275400
# 276420 b'ack'
# timeout resend ack_id:  276420
# 277440 b'ack'
# timeout resend ack_id:  277440
# 278460 b'ack'
# timeout resend ack_id:  278460
# 279480 b'ack'
# timeout resend ack_id:  279480
# 280500 b'ack'
# timeout resend ack_id:  280500
# 281520 b'ack'
# timeout resend ack_id:  281520
# 282540 b'ack'
# timeout resend ack_id:  282540
# 283560 b'ack'
# timeout resend ack_id:  283560
# 284580 b'ack'
# timeout resend ack_id:  284580
# 285600 b'ack'
# timeout resend ack_id:  285600
# 286620 b'ack'
# timeout resend ack_id:  286620
# 287640 b'ack'
# timeout resend ack_id:  287640
# 288660 b'ack'
# timeout resend ack_id:  288660
# 289680 b'ack'
# timeout resend ack_id:  289680
# 290700 b'ack'
# timeout resend ack_id:  290700
# 291720 b'ack'
# timeout resend ack_id:  291720
# 292740 b'ack'
# timeout resend ack_id:  292740
# 635460 b'ack'
# timeout resend ack_id:  635460
# 636480 b'ack'
# timeout resend ack_id:  636480
# 637500 b'ack'
# timeout resend ack_id:  637500
# 638520 b'ack'
# timeout resend ack_id:  638520
# 639540 b'ack'
# timeout resend ack_id:  639540
# 640560 b'ack'
# timeout resend ack_id:  640560
# 641580 b'ack'
# timeout resend ack_id:  641580
# 642600 b'ack'
# timeout resend ack_id:  642600
# 643620 b'ack'
# timeout resend ack_id:  643620
# 644640 b'ack'
# timeout resend ack_id:  644640
# 645660 b'ack'
# timeout resend ack_id:  645660
# 646680 b'ack'
# timeout resend ack_id:  646680
# 647700 b'ack'
# timeout resend ack_id:  647700
# 648720 b'ack'
# timeout resend ack_id:  648720
# 649740 b'ack'
# timeout resend ack_id:  649740
# 650760 b'ack'
# timeout resend ack_id:  650760
# 651780 b'ack'
# timeout resend ack_id:  651780
# 652800 b'ack'
# timeout resend ack_id:  652800
# 653820 b'ack'
# timeout resend ack_id:  653820
# 654840 b'ack'
# timeout resend ack_id:  654840
# 655860 b'ack'
# timeout resend ack_id:  655860
# 656880 b'ack'
# timeout resend ack_id:  656880
# 657900 b'ack'
# timeout resend ack_id:  657900
# 658920 b'ack'
# timeout resend ack_id:  658920
# 659940 b'ack'
# timeout resend ack_id:  659940
# 660960 b'ack'
# timeout resend ack_id:  660960
# 661980 b'ack'
# timeout resend ack_id:  661980
# 663000 b'ack'
# timeout resend ack_id:  663000
# 664020 b'ack'
# timeout resend ack_id:  664020
# 665040 b'ack'
# timeout resend ack_id:  665040
# 666060 b'ack'
# timeout resend ack_id:  666060
# 667080 b'ack'
# timeout resend ack_id:  667080
# 668100 b'ack'
# timeout resend ack_id:  668100
# 669120 b'ack'
# timeout resend ack_id:  669120
# 670140 b'ack'
# timeout resend ack_id:  670140
# 671160 b'ack'
# timeout resend ack_id:  671160
# 672180 b'ack'
# timeout resend ack_id:  672180
# 673200 b'ack'
# timeout resend ack_id:  673200
# 674220 b'ack'
# timeout resend ack_id:  674220
# 675240 b'ack'
# timeout resend ack_id:  675240
# 676260 b'ack'
# timeout resend ack_id:  676260
# 677280 b'ack'
# timeout resend ack_id:  677280
# 678300 b'ack'
# timeout resend ack_id:  678300
# 679320 b'ack'
# timeout resend ack_id:  679320
# 680340 b'ack'
# timeout resend ack_id:  680340
# 681360 b'ack'
# timeout resend ack_id:  681360
# 682380 b'ack'
# timeout resend ack_id:  682380
# 683400 b'ack'
# timeout resend ack_id:  683400
# 684420 b'ack'
# timeout resend ack_id:  684420
# 685440 b'ack'
# timeout resend ack_id:  685440
# 686460 b'ack'
# timeout resend ack_id:  686460
# 687480 b'ack'
# timeout resend ack_id:  687480
# 688500 b'ack'
# timeout resend ack_id:  688500
# 689520 b'ack'
# timeout resend ack_id:  689520
# 690540 b'ack'
# timeout resend ack_id:  690540
# 691560 b'ack'
# timeout resend ack_id:  691560
# 692580 b'ack'
# timeout resend ack_id:  692580
# 693600 b'ack'
# timeout resend ack_id:  693600
# 694620 b'ack'
# timeout resend ack_id:  694620
# 695640 b'ack'
# timeout resend ack_id:  695640
# 696660 b'ack'
# timeout resend ack_id:  696660
# 697680 b'ack'
# timeout resend ack_id:  697680
# 698700 b'ack'
# timeout resend ack_id:  698700
# 699720 b'ack'
# timeout resend ack_id:  699720
# 700740 b'ack'
# timeout resend ack_id:  700740
# 701760 b'ack'
# timeout resend ack_id:  701760
# 702780 b'ack'
# timeout resend ack_id:  702780
# 703800 b'ack'
# timeout resend ack_id:  703800
# 704820 b'ack'
# timeout resend ack_id:  704820
# 705840 b'ack'
# timeout resend ack_id:  705840
# 706860 b'ack'
# timeout resend ack_id:  706860
# 707880 b'ack'
# timeout resend ack_id:  707880
# 708900 b'ack'
# timeout resend ack_id:  708900
# 709920 b'ack'
# timeout resend ack_id:  709920
# 710940 b'ack'
# timeout resend ack_id:  710940
# 711960 b'ack'
# timeout resend ack_id:  711960
# 712980 b'ack'
# timeout resend ack_id:  712980
# 714000 b'ack'
# timeout resend ack_id:  714000
# 715020 b'ack'
# timeout resend ack_id:  715020
# 716040 b'ack'
# timeout resend ack_id:  716040
# 717060 b'ack'
# timeout resend ack_id:  717060
# 718080 b'ack'
# timeout resend ack_id:  718080
# 719100 b'ack'
# timeout resend ack_id:  719100
# 720120 b'ack'
# timeout resend ack_id:  720120
# 721140 b'ack'
# timeout resend ack_id:  721140
# 722160 b'ack'
# timeout resend ack_id:  722160
# 723180 b'ack'
# timeout resend ack_id:  723180
# 724200 b'ack'
# timeout resend ack_id:  724200
# 725220 b'ack'
# timeout resend ack_id:  725220
# 726240 b'ack'
# timeout resend ack_id:  726240
# 727260 b'ack'
# timeout resend ack_id:  727260
# 728280 b'ack'
# timeout resend ack_id:  728280
# 729300 b'ack'
# timeout resend ack_id:  729300
# 730320 b'ack'
# timeout resend ack_id:  730320
# 731340 b'ack'
# timeout resend ack_id:  731340
# 732360 b'ack'
# timeout resend ack_id:  732360
# 733380 b'ack'
# timeout resend ack_id:  733380
# 734400 b'ack'
# timeout resend ack_id:  734400
# 735420 b'ack'
# timeout resend ack_id:  735420
# 736440 b'ack'
# timeout resend ack_id:  736440
# 737460 b'ack'
# timeout resend ack_id:  737460
# 738480 b'ack'
# timeout resend ack_id:  738480
# 739500 b'ack'
# timeout resend ack_id:  739500
# 740520 b'ack'
# timeout resend ack_id:  740520
# 741540 b'ack'
# timeout resend ack_id:  741540
# 742560 b'ack'
# timeout resend ack_id:  742560
# 743580 b'ack'
# timeout resend ack_id:  743580
# 744600 b'ack'
# timeout resend ack_id:  744600
# 745620 b'ack'
# timeout resend ack_id:  745620
# 746640 b'ack'
# timeout resend ack_id:  746640
# 747660 b'ack'
# timeout resend ack_id:  747660
# 748680 b'ack'
# timeout resend ack_id:  748680
# 749700 b'ack'
# timeout resend ack_id:  749700
# 750720 b'ack'
# timeout resend ack_id:  750720
# 751740 b'ack'
# timeout resend ack_id:  751740
# 752760 b'ack'
# timeout resend ack_id:  752760
# 753780 b'ack'
# timeout resend ack_id:  753780
# 754800 b'ack'
# timeout resend ack_id:  754800
# 755820 b'ack'
# timeout resend ack_id:  755820
# 756840 b'ack'
# timeout resend ack_id:  756840
# 757860 b'ack'
# timeout resend ack_id:  757860
# 758880 b'ack'
# timeout resend ack_id:  758880
# 759900 b'ack'
# timeout resend ack_id:  759900
# 760920 b'ack'
# timeout resend ack_id:  760920
# 761940 b'ack'
# timeout resend ack_id:  761940
# 762960 b'ack'
# timeout resend ack_id:  762960
# 763980 b'ack'
# timeout resend ack_id:  763980
# 765000 b'ack'
# timeout resend ack_id:  765000
# 766020 b'ack'
# timeout resend ack_id:  766020
# 767040 b'ack'
# timeout resend ack_id:  767040
# 768060 b'ack'
# timeout resend ack_id:  768060
# 769080 b'ack'
# timeout resend ack_id:  769080
# 770100 b'ack'
# timeout resend ack_id:  770100
# 771120 b'ack'
# timeout resend ack_id:  771120
# 772140 b'ack'
# timeout resend ack_id:  772140
# 773160 b'ack'
# timeout resend ack_id:  773160
# 774180 b'ack'
# timeout resend ack_id:  774180
# 775200 b'ack'
# timeout resend ack_id:  775200
# 776220 b'ack'
# timeout resend ack_id:  776220
# 777240 b'ack'
# timeout resend ack_id:  777240
# 778260 b'ack'
# timeout resend ack_id:  778260
# 779280 b'ack'
# timeout resend ack_id:  779280
# 780300 b'ack'
# timeout resend ack_id:  780300
# 781320 b'ack'
# timeout resend ack_id:  781320
# 782340 b'ack'
# timeout resend ack_id:  782340
# 783360 b'ack'
# timeout resend ack_id:  783360
# 784380 b'ack'
# timeout resend ack_id:  784380
# 785400 b'ack'
# timeout resend ack_id:  785400
# 786420 b'ack'
# timeout resend ack_id:  786420
# 787440 b'ack'
# timeout resend ack_id:  787440
# 788460 b'ack'
# timeout resend ack_id:  788460
# 789480 b'ack'
# timeout resend ack_id:  789480
# 790500 b'ack'
# timeout resend ack_id:  790500
# 791520 b'ack'
# timeout resend ack_id:  791520
# 792540 b'ack'
# timeout resend ack_id:  792540
# 793560 b'ack'
# timeout resend ack_id:  793560
# 794580 b'ack'
# timeout resend ack_id:  794580
# 795600 b'ack'
# timeout resend ack_id:  795600
# 796620 b'ack'
# timeout resend ack_id:  796620
# 797640 b'ack'
# timeout resend ack_id:  797640
# 798660 b'ack'
# timeout resend ack_id:  798660
# 799680 b'ack'
# timeout resend ack_id:  799680
# 800700 b'ack'
# timeout resend ack_id:  800700
# 801720 b'ack'
# timeout resend ack_id:  801720
# 802740 b'ack'
# timeout resend ack_id:  802740
# 803760 b'ack'
# timeout resend ack_id:  803760
# 804780 b'ack'
# timeout resend ack_id:  804780
# 805800 b'ack'
# timeout resend ack_id:  805800
# 806820 b'ack'
# timeout resend ack_id:  806820
# 807840 b'ack'
# timeout resend ack_id:  807840
# 808860 b'ack'
# timeout resend ack_id:  808860
# 809880 b'ack'
# timeout resend ack_id:  809880
# 810900 b'ack'
# timeout resend ack_id:  810900
# 811920 b'ack'
# timeout resend ack_id:  811920
# 812940 b'ack'
# timeout resend ack_id:  812940
# 813960 b'ack'
# timeout resend ack_id:  813960
# 814980 b'ack'
# timeout resend ack_id:  814980
# 816000 b'ack'
# timeout resend ack_id:  816000
# 817020 b'ack'
# timeout resend ack_id:  817020
# 818040 b'ack'
# timeout resend ack_id:  818040
# 819060 b'ack'
# timeout resend ack_id:  819060
# 820080 b'ack'
# timeout resend ack_id:  820080
# 821100 b'ack'
# timeout resend ack_id:  821100
# 822120 b'ack'
# timeout resend ack_id:  822120
# 823140 b'ack'
# timeout resend ack_id:  823140
# 824160 b'ack'
# timeout resend ack_id:  824160
# 825180 b'ack'
# timeout resend ack_id:  825180
# 826200 b'ack'
# timeout resend ack_id:  826200
# 827220 b'ack'
# timeout resend ack_id:  827220
# 828240 b'ack'
# timeout resend ack_id:  828240
# 829260 b'ack'
# timeout resend ack_id:  829260
# 830280 b'ack'
# timeout resend ack_id:  830280
# 831300 b'ack'
# timeout resend ack_id:  831300
# 832320 b'ack'
# timeout resend ack_id:  832320
# 833340 b'ack'
# timeout resend ack_id:  833340
# 834360 b'ack'
# timeout resend ack_id:  834360
# 835380 b'ack'
# timeout resend ack_id:  835380
# 836400 b'ack'
# timeout resend ack_id:  836400
# 837420 b'ack'
# timeout resend ack_id:  837420
# 838440 b'ack'
# timeout resend ack_id:  838440
# 839460 b'ack'
# timeout resend ack_id:  839460
# 840480 b'ack'
# timeout resend ack_id:  840480
# 841500 b'ack'
# timeout resend ack_id:  841500
# 842520 b'ack'
# timeout resend ack_id:  842520
# 843540 b'ack'
# timeout resend ack_id:  843540
# 844560 b'ack'
# timeout resend ack_id:  844560
# 845580 b'ack'
# timeout resend ack_id:  845580
# 846600 b'ack'
# timeout resend ack_id:  846600
# 847620 b'ack'
# timeout resend ack_id:  847620
# 848640 b'ack'
# timeout resend ack_id:  848640
# 906780 b'ack'
# timeout resend ack_id:  906780
# 907800 b'ack'
# timeout resend ack_id:  907800
# 908820 b'ack'
# timeout resend ack_id:  908820
# 909840 b'ack'
# timeout resend ack_id:  909840
# 910860 b'ack'
# timeout resend ack_id:  910860
# 911880 b'ack'
# timeout resend ack_id:  911880
# 912900 b'ack'
# timeout resend ack_id:  912900
# 913920 b'ack'
# timeout resend ack_id:  913920
# 914940 b'ack'
# timeout resend ack_id:  914940
# 915960 b'ack'
# timeout resend ack_id:  915960
# 916980 b'ack'
# timeout resend ack_id:  916980
# 918000 b'ack'
# timeout resend ack_id:  918000
# 919020 b'ack'
# timeout resend ack_id:  919020
# 920040 b'ack'
# timeout resend ack_id:  920040
# 921060 b'ack'
# timeout resend ack_id:  921060
# 922080 b'ack'
# timeout resend ack_id:  922080
# 923100 b'ack'
# timeout resend ack_id:  923100
# 924120 b'ack'
# timeout resend ack_id:  924120
# 925140 b'ack'
# timeout resend ack_id:  925140
# 926160 b'ack'
# timeout resend ack_id:  926160
# 927180 b'ack'
# timeout resend ack_id:  927180
# 928200 b'ack'
# timeout resend ack_id:  928200
# 929220 b'ack'
# timeout resend ack_id:  929220
# 930240 b'ack'
# timeout resend ack_id:  930240
# 931260 b'ack'
# timeout resend ack_id:  931260
# 932280 b'ack'
# timeout resend ack_id:  932280
# 933300 b'ack'
# timeout resend ack_id:  933300
# 934320 b'ack'
# timeout resend ack_id:  934320
# 935340 b'ack'
# timeout resend ack_id:  935340
# 936360 b'ack'
# timeout resend ack_id:  936360
# 937380 b'ack'
# timeout resend ack_id:  937380
# 938400 b'ack'
# timeout resend ack_id:  938400
# 939420 b'ack'
# timeout resend ack_id:  939420
# 940440 b'ack'
# timeout resend ack_id:  940440
# 941460 b'ack'
# timeout resend ack_id:  941460
# 942480 b'ack'
# timeout resend ack_id:  942480
# 943500 b'ack'
# timeout resend ack_id:  943500
# 944520 b'ack'
# timeout resend ack_id:  944520
# 945540 b'ack'
# timeout resend ack_id:  945540
# 946560 b'ack'
# timeout resend ack_id:  946560
# 947580 b'ack'
# timeout resend ack_id:  947580
# 948600 b'ack'
# timeout resend ack_id:  948600
# 949620 b'ack'
# timeout resend ack_id:  949620
# 950640 b'ack'
# timeout resend ack_id:  950640
# 951660 b'ack'
# timeout resend ack_id:  951660
# 952680 b'ack'
# timeout resend ack_id:  952680
# 953700 b'ack'
# timeout resend ack_id:  953700
# 954720 b'ack'
# timeout resend ack_id:  954720
# 955740 b'ack'
# timeout resend ack_id:  955740
# 956760 b'ack'
# timeout resend ack_id:  956760
# 957780 b'ack'
# timeout resend ack_id:  957780
# 958800 b'ack'
# timeout resend ack_id:  958800
# 959820 b'ack'
# timeout resend ack_id:  959820
# 960840 b'ack'
# timeout resend ack_id:  960840
# 961860 b'ack'
# timeout resend ack_id:  961860
# 962880 b'ack'
# timeout resend ack_id:  962880
# 963900 b'ack'
# timeout resend ack_id:  963900
# 964920 b'ack'
# timeout resend ack_id:  964920
# 965940 b'ack'
# timeout resend ack_id:  965940
# 966960 b'ack'
# timeout resend ack_id:  966960
# 967980 b'ack'
# timeout resend ack_id:  967980
# 969000 b'ack'
# timeout resend ack_id:  969000
# 970020 b'ack'
# timeout resend ack_id:  970020
# 971040 b'ack'
# timeout resend ack_id:  971040
# 972060 b'ack'
# timeout resend ack_id:  972060
# 973080 b'ack'
# timeout resend ack_id:  973080
# 974100 b'ack'
# timeout resend ack_id:  974100
# 975120 b'ack'
# timeout resend ack_id:  975120
# 976140 b'ack'
# timeout resend ack_id:  976140
# 977160 b'ack'
# timeout resend ack_id:  977160
# 978180 b'ack'
# timeout resend ack_id:  978180
# 979200 b'ack'
# timeout resend ack_id:  979200
# 980220 b'ack'
# timeout resend ack_id:  980220
# 981240 b'ack'
# timeout resend ack_id:  981240
# 982260 b'ack'
# timeout resend ack_id:  982260
# 983280 b'ack'
# timeout resend ack_id:  983280
# 984300 b'ack'
# timeout resend ack_id:  984300
# 985320 b'ack'
# timeout resend ack_id:  985320
# 986340 b'ack'
# timeout resend ack_id:  986340
# 987360 b'ack'
# timeout resend ack_id:  987360
# 988380 b'ack'
# timeout resend ack_id:  988380
# 989400 b'ack'
# timeout resend ack_id:  989400
# 990420 b'ack'
# timeout resend ack_id:  990420
# 991440 b'ack'
# timeout resend ack_id:  991440
# 992460 b'ack'
# timeout resend ack_id:  992460
# 993480 b'ack'
# timeout resend ack_id:  993480
# 994500 b'ack'
# timeout resend ack_id:  994500
# 995520 b'ack'
# timeout resend ack_id:  995520
# 996540 b'ack'
# timeout resend ack_id:  996540
# 997560 b'ack'
# timeout resend ack_id:  997560
# 998580 b'ack'
# timeout resend ack_id:  998580
# 999600 b'ack'
# timeout resend ack_id:  999600
# 1000620 b'ack'
# timeout resend ack_id:  1000620
# 1001640 b'ack'
# timeout resend ack_id:  1001640
# 1002660 b'ack'
# timeout resend ack_id:  1002660
# 1003680 b'ack'
# timeout resend ack_id:  1003680
# 1004700 b'ack'
# timeout resend ack_id:  1004700
# 1005720 b'ack'
# timeout resend ack_id:  1005720
# 1006740 b'ack'
# timeout resend ack_id:  1006740
# 1007760 b'ack'
# timeout resend ack_id:  1007760
# 1008780 b'ack'
# timeout resend ack_id:  1008780
# 1009800 b'ack'
# timeout resend ack_id:  1009800
# 1010820 b'ack'
# timeout resend ack_id:  1010820
# 1011840 b'ack'
# timeout resend ack_id:  1011840
# 1012860 b'ack'
# timeout resend ack_id:  1012860
# 1013880 b'ack'
# timeout resend ack_id:  1013880
# 1014900 b'ack'
# timeout resend ack_id:  1014900
# 1015920 b'ack'
# timeout resend ack_id:  1015920
# 1016940 b'ack'
# timeout resend ack_id:  1016940
# 1017960 b'ack'
# timeout resend ack_id:  1017960
# 1018980 b'ack'
# timeout resend ack_id:  1018980
# 1020000 b'ack'
# timeout resend ack_id:  1020000
# 1021020 b'ack'
# timeout resend ack_id:  1021020
# 1022040 b'ack'
# timeout resend ack_id:  1022040
# 1023060 b'ack'
# timeout resend ack_id:  1023060
# 1024080 b'ack'
# timeout resend ack_id:  1024080
# 1025100 b'ack'
# timeout resend ack_id:  1025100
# 1026120 b'ack'
# timeout resend ack_id:  1026120
# 1027140 b'ack'
# timeout resend ack_id:  1027140
# 1028160 b'ack'
# timeout resend ack_id:  1028160
# 1029180 b'ack'
# timeout resend ack_id:  1029180
# 1030200 b'ack'
# timeout resend ack_id:  1030200
# 1031220 b'ack'
# timeout resend ack_id:  1031220
# 1032240 b'ack'
# timeout resend ack_id:  1032240
# 1033260 b'ack'
# timeout resend ack_id:  1033260
# 1034280 b'ack'
# timeout resend ack_id:  1034280
# 1035300 b'ack'
# timeout resend ack_id:  1035300
# 1036320 b'ack'
# timeout resend ack_id:  1036320
# 1037340 b'ack'
# timeout resend ack_id:  1037340
# 1038360 b'ack'
# timeout resend ack_id:  1038360
# 1039380 b'ack'
# timeout resend ack_id:  1039380
# 1040400 b'ack'
# timeout resend ack_id:  1040400
# 1041420 b'ack'
# timeout resend ack_id:  1041420
# 1042440 b'ack'
# timeout resend ack_id:  1042440
# 1043460 b'ack'
# timeout resend ack_id:  1043460
# 1044480 b'ack'
# timeout resend ack_id:  1044480
# 1045500 b'ack'
# timeout resend ack_id:  1045500
# 1046520 b'ack'
# timeout resend ack_id:  1046520
# 1047540 b'ack'
# timeout resend ack_id:  1047540
# 1048560 b'ack'
# timeout resend ack_id:  1048560
# 1049580 b'ack'
# timeout resend ack_id:  1049580
# 1050600 b'ack'
# timeout resend ack_id:  1050600
# 1051620 b'ack'
# timeout resend ack_id:  1051620
# 1052640 b'ack'
# timeout resend ack_id:  1052640
# 1053660 b'ack'
# timeout resend ack_id:  1053660
# 1054680 b'ack'
# timeout resend ack_id:  1054680
# 1055700 b'ack'
# timeout resend ack_id:  1055700
# 1056720 b'ack'
# timeout resend ack_id:  1056720
# 1057740 b'ack'
# timeout resend ack_id:  1057740
# 1058760 b'ack'
# timeout resend ack_id:  1058760
# 1059780 b'ack'
# timeout resend ack_id:  1059780
# 1060800 b'ack'
# timeout resend ack_id:  1060800
# 1061820 b'ack'
# timeout resend ack_id:  1061820
# 1062840 b'ack'
# timeout resend ack_id:  1062840
# 1063860 b'ack'
# timeout resend ack_id:  1063860
# 1064880 b'ack'
# timeout resend ack_id:  1064880
# 1065900 b'ack'
# timeout resend ack_id:  1065900
# 1066920 b'ack'
# timeout resend ack_id:  1066920
# 1067940 b'ack'
# timeout resend ack_id:  1067940
# 1068960 b'ack'
# timeout resend ack_id:  1068960
# 1069980 b'ack'
# timeout resend ack_id:  1069980
# 1071000 b'ack'
# timeout resend ack_id:  1071000
# 1072020 b'ack'
# timeout resend ack_id:  1072020
# 1073040 b'ack'
# timeout resend ack_id:  1073040
# 1074060 b'ack'
# timeout resend ack_id:  1074060
# 1075080 b'ack'
# timeout resend ack_id:  1075080
# 1076100 b'ack'
# timeout resend ack_id:  1076100
# 1077120 b'ack'
# timeout resend ack_id:  1077120
# 1078140 b'ack'
# timeout resend ack_id:  1078140
# 1079160 b'ack'
# timeout resend ack_id:  1079160
# 1080180 b'ack'
# timeout resend ack_id:  1080180
# 1081200 b'ack'
# timeout resend ack_id:  1081200
# 1082220 b'ack'
# timeout resend ack_id:  1082220
# 1083240 b'ack'
# timeout resend ack_id:  1083240
# 1084260 b'ack'
# timeout resend ack_id:  1084260
# 1085280 b'ack'
# timeout resend ack_id:  1085280
# 1086300 b'ack'
# timeout resend ack_id:  1086300
# 1087320 b'ack'
# timeout resend ack_id:  1087320
# 1088340 b'ack'
# timeout resend ack_id:  1088340
# 1089360 b'ack'
# timeout resend ack_id:  1089360
# 1090380 b'ack'
# timeout resend ack_id:  1090380
# 1091400 b'ack'
# timeout resend ack_id:  1091400
# 1092420 b'ack'
# timeout resend ack_id:  1092420
# 1093440 b'ack'
# timeout resend ack_id:  1093440
# 1094460 b'ack'
# timeout resend ack_id:  1094460
# 1095480 b'ack'
# timeout resend ack_id:  1095480
# 1096500 b'ack'
# timeout resend ack_id:  1096500
# 1097520 b'ack'
# timeout resend ack_id:  1097520
# 1098540 b'ack'
# timeout resend ack_id:  1098540
# 1099560 b'ack'
# timeout resend ack_id:  1099560
# 1100580 b'ack'
# timeout resend ack_id:  1100580
# 1101600 b'ack'
# timeout resend ack_id:  1101600
# 1102620 b'ack'
# timeout resend ack_id:  1102620
# 1103640 b'ack'
# timeout resend ack_id:  1103640
# 1104660 b'ack'
# timeout resend ack_id:  1104660
# 1105680 b'ack'
# timeout resend ack_id:  1105680
# 1106700 b'ack'
# timeout resend ack_id:  1106700
# 1107720 b'ack'
# timeout resend ack_id:  1107720
# 1108740 b'ack'
# timeout resend ack_id:  1108740
# 1109760 b'ack'
# timeout resend ack_id:  1109760
# 1110780 b'ack'
# timeout resend ack_id:  1110780
# 1111800 b'ack'
# timeout resend ack_id:  1111800
# 1112820 b'ack'
# timeout resend ack_id:  1112820
# 1113840 b'ack'
# timeout resend ack_id:  1113840
# 1114860 b'ack'
# timeout resend ack_id:  1114860
# 1115880 b'ack'
# timeout resend ack_id:  1115880
# 1116900 b'ack'
# timeout resend ack_id:  1116900
# 1117920 b'ack'
# timeout resend ack_id:  1117920
# 1118940 b'ack'
# timeout resend ack_id:  1118940
# 1119960 b'ack'
# timeout resend ack_id:  1119960
# 1120980 b'ack'
# timeout resend ack_id:  1120980
# 1122000 b'ack'
# timeout resend ack_id:  1122000
# 1123020 b'ack'
# timeout resend ack_id:  1123020
# 1124040 b'ack'
# timeout resend ack_id:  1124040
# 1125060 b'ack'
# timeout resend ack_id:  1125060
# 1126080 b'ack'
# timeout resend ack_id:  1126080
# 1127100 b'ack'
# timeout resend ack_id:  1127100
# 1128120 b'ack'
# timeout resend ack_id:  1128120
# 1129140 b'ack'
# timeout resend ack_id:  1129140
# 1130160 b'ack'
# timeout resend ack_id:  1130160
# 1131180 b'ack'
# timeout resend ack_id:  1131180
# 1132200 b'ack'
# timeout resend ack_id:  1132200
# 1133220 b'ack'
# timeout resend ack_id:  1133220
# 1134240 b'ack'
# timeout resend ack_id:  1134240
# 1135260 b'ack'
# timeout resend ack_id:  1135260
# 1136280 b'ack'
# timeout resend ack_id:  1136280
# 1137300 b'ack'
# timeout resend ack_id:  1137300
# 1138320 b'ack'
# timeout resend ack_id:  1138320
# 1139340 b'ack'
# timeout resend ack_id:  1139340
# 1140360 b'ack'
# timeout resend ack_id:  1140360
# 1141380 b'ack'
# timeout resend ack_id:  1141380
# 1142400 b'ack'
# timeout resend ack_id:  1142400
# 1143420 b'ack'
# timeout resend ack_id:  1143420
# 1144440 b'ack'
# timeout resend ack_id:  1144440
# 1145460 b'ack'
# timeout resend ack_id:  1145460
# 1146480 b'ack'
# timeout resend ack_id:  1146480
# 1147500 b'ack'
# timeout resend ack_id:  1147500
# 1148520 b'ack'
# timeout resend ack_id:  1148520
# 1149540 b'ack'
# timeout resend ack_id:  1149540
# 1150560 b'ack'
# timeout resend ack_id:  1150560
# 1151580 b'ack'
# timeout resend ack_id:  1151580
# 1152600 b'ack'
# timeout resend ack_id:  1152600
# 1153620 b'ack'
# timeout resend ack_id:  1153620
# 1154640 b'ack'
# timeout resend ack_id:  1154640
# 1155660 b'ack'
# timeout resend ack_id:  1155660
# 1156680 b'ack'
# timeout resend ack_id:  1156680
# 1157700 b'ack'
# timeout resend ack_id:  1157700
# 1158720 b'ack'
# timeout resend ack_id:  1158720
# 1159740 b'ack'
# timeout resend ack_id:  1159740
# 1160760 b'ack'
# timeout resend ack_id:  1160760
# 1161780 b'ack'
# timeout resend ack_id:  1161780
# 1162800 b'ack'
# timeout resend ack_id:  1162800
# 1163820 b'ack'
# timeout resend ack_id:  1163820
# 1164840 b'ack'
# timeout resend ack_id:  1164840
# 1165860 b'ack'
# timeout resend ack_id:  1165860
# 1166880 b'ack'
# timeout resend ack_id:  1166880
# 1167900 b'ack'
# timeout resend ack_id:  1167900
# 1168920 b'ack'
# timeout resend ack_id:  1168920
# 1169940 b'ack'
# timeout resend ack_id:  1169940
# 1170960 b'ack'
# timeout resend ack_id:  1170960
# 1171980 b'ack'
# timeout resend ack_id:  1171980
# 1173000 b'ack'
# timeout resend ack_id:  1173000
# 1174020 b'ack'
# timeout resend ack_id:  1174020
# 1175040 b'ack'
# timeout resend ack_id:  1175040
# 1176060 b'ack'
# timeout resend ack_id:  1176060
# 1177080 b'ack'
# timeout resend ack_id:  1177080
# 1178100 b'ack'
# timeout resend ack_id:  1178100
# 1179120 b'ack'
# timeout resend ack_id:  1179120
# 1180140 b'ack'
# timeout resend ack_id:  1180140
# 1181160 b'ack'
# timeout resend ack_id:  1181160
# 1182180 b'ack'
# timeout resend ack_id:  1182180
# 1183200 b'ack'
# timeout resend ack_id:  1183200
# 1184220 b'ack'
# timeout resend ack_id:  1184220
# 1272960 b'ack'
# timeout resend ack_id:  1272960
# 1273980 b'ack'
# timeout resend ack_id:  1273980
# 1275000 b'ack'
# timeout resend ack_id:  1275000
# 1276020 b'ack'
# timeout resend ack_id:  1276020
# 1277040 b'ack'
# timeout resend ack_id:  1277040
# 1278060 b'ack'
# timeout resend ack_id:  1278060
# 1279080 b'ack'
# timeout resend ack_id:  1279080
# 1280100 b'ack'
# timeout resend ack_id:  1280100
# 1281120 b'ack'
# timeout resend ack_id:  1281120
# 1282140 b'ack'
# timeout resend ack_id:  1282140
# 1283160 b'ack'
# timeout resend ack_id:  1283160
# 1284180 b'ack'
# timeout resend ack_id:  1284180
# 1285200 b'ack'
# timeout resend ack_id:  1285200
# 1286220 b'ack'
# timeout resend ack_id:  1286220
# 1287240 b'ack'
# timeout resend ack_id:  1287240
# 1288260 b'ack'
# timeout resend ack_id:  1288260
# 1289280 b'ack'
# timeout resend ack_id:  1289280
# 1290300 b'ack'
# timeout resend ack_id:  1290300
# 1291320 b'ack'
# timeout resend ack_id:  1291320
# 1292340 b'ack'
# timeout resend ack_id:  1292340
# 1293360 b'ack'
# timeout resend ack_id:  1293360
# 1294380 b'ack'
# timeout resend ack_id:  1294380
# 1295400 b'ack'
# timeout resend ack_id:  1295400
# 1296420 b'ack'
# timeout resend ack_id:  1296420
# 1297440 b'ack'
# timeout resend ack_id:  1297440
# 1298460 b'ack'
# timeout resend ack_id:  1298460
# 1299480 b'ack'
# timeout resend ack_id:  1299480
# 1300500 b'ack'
# timeout resend ack_id:  1300500
# 1301520 b'ack'
# timeout resend ack_id:  1301520
# 1302540 b'ack'
# timeout resend ack_id:  1302540
# 1303560 b'ack'
# timeout resend ack_id:  1303560
# 1304580 b'ack'
# timeout resend ack_id:  1304580
# 1305600 b'ack'
# timeout resend ack_id:  1305600
# 1306620 b'ack'
# timeout resend ack_id:  1306620
# 1307640 b'ack'
# timeout resend ack_id:  1307640
# 1308660 b'ack'
# timeout resend ack_id:  1308660
# 1309680 b'ack'
# timeout resend ack_id:  1309680
# 1310700 b'ack'
# timeout resend ack_id:  1310700
# 1311720 b'ack'
# timeout resend ack_id:  1311720
# 1312740 b'ack'
# timeout resend ack_id:  1312740
# 1313760 b'ack'
# timeout resend ack_id:  1313760
# 1314780 b'ack'
# timeout resend ack_id:  1314780
# 1315800 b'ack'
# timeout resend ack_id:  1315800
# 1397400 b'ack'
# timeout resend ack_id:  1397400
# 1398420 b'ack'
# timeout resend ack_id:  1398420
# 1399440 b'ack'
# timeout resend ack_id:  1399440
# 1400460 b'ack'
# timeout resend ack_id:  1400460
# 1401480 b'ack'
# timeout resend ack_id:  1401480
# 1402500 b'ack'
# timeout resend ack_id:  1402500
# 1403520 b'ack'
# timeout resend ack_id:  1403520
# 1404540 b'ack'
# timeout resend ack_id:  1404540
# 1405560 b'ack'
# timeout resend ack_id:  1405560
# 1406580 b'ack'
# timeout resend ack_id:  1406580
# 1407600 b'ack'
# timeout resend ack_id:  1407600
# 1408620 b'ack'
# timeout resend ack_id:  1408620
# 1409640 b'ack'
# timeout resend ack_id:  1409640
# 1410660 b'ack'
# timeout resend ack_id:  1410660
# 1411680 b'ack'
# timeout resend ack_id:  1411680
# 1412700 b'ack'
# timeout resend ack_id:  1412700
# 1413720 b'ack'
# timeout resend ack_id:  1413720
# 1414740 b'ack'
# timeout resend ack_id:  1414740
# 1415760 b'ack'
# timeout resend ack_id:  1415760
# 1416780 b'ack'
# timeout resend ack_id:  1416780
# 1417800 b'ack'
# timeout resend ack_id:  1417800
# 1418820 b'ack'
# timeout resend ack_id:  1418820
# 1419840 b'ack'
# timeout resend ack_id:  1419840
# 1420860 b'ack'
# timeout resend ack_id:  1420860
# 1421880 b'ack'
# timeout resend ack_id:  1421880
# 1422900 b'ack'
# timeout resend ack_id:  1422900
# 1423920 b'ack'
# timeout resend ack_id:  1423920
# 1424940 b'ack'
# timeout resend ack_id:  1424940
# 1425960 b'ack'
# timeout resend ack_id:  1425960
# 1426980 b'ack'
# timeout resend ack_id:  1426980
# 1428000 b'ack'
# timeout resend ack_id:  1428000
# 1429020 b'ack'
# timeout resend ack_id:  1429020
# 1430040 b'ack'
# timeout resend ack_id:  1430040
# 1431060 b'ack'
# timeout resend ack_id:  1431060
# 1432080 b'ack'
# timeout resend ack_id:  1432080
# 1433100 b'ack'
# timeout resend ack_id:  1433100
# 1434120 b'ack'
# timeout resend ack_id:  1434120
# 1435140 b'ack'
# timeout resend ack_id:  1435140
# 1436160 b'ack'
# timeout resend ack_id:  1436160
# 1437180 b'ack'
# timeout resend ack_id:  1437180
# 1438200 b'ack'
# timeout resend ack_id:  1438200
# 1439220 b'ack'
# timeout resend ack_id:  1439220
# 1440240 b'ack'
# timeout resend ack_id:  1440240
# 1441260 b'ack'
# timeout resend ack_id:  1441260
# 1442280 b'ack'
# timeout resend ack_id:  1442280
# 1443300 b'ack'
# timeout resend ack_id:  1443300
# 1444320 b'ack'
# timeout resend ack_id:  1444320
# 1445340 b'ack'
# timeout resend ack_id:  1445340
# 1446360 b'ack'
# timeout resend ack_id:  1446360
# 1447380 b'ack'
# timeout resend ack_id:  1447380
# 1448400 b'ack'
# timeout resend ack_id:  1448400
# 1449420 b'ack'
# timeout resend ack_id:  1449420
# 1450440 b'ack'
# timeout resend ack_id:  1450440
# 1451460 b'ack'
# timeout resend ack_id:  1451460
# 1452480 b'ack'
# timeout resend ack_id:  1452480
# 1453500 b'ack'
# timeout resend ack_id:  1453500
# 1454520 b'ack'
# timeout resend ack_id:  1454520
# 1455540 b'ack'
# timeout resend ack_id:  1455540
# 1456560 b'ack'
# timeout resend ack_id:  1456560
# 1457580 b'ack'
# timeout resend ack_id:  1457580
# 1458600 b'ack'
# timeout resend ack_id:  1458600
# 1459620 b'ack'
# timeout resend ack_id:  1459620
# 1460640 b'ack'
# timeout resend ack_id:  1460640
# 1461660 b'ack'
# timeout resend ack_id:  1461660
# 1462680 b'ack'
# timeout resend ack_id:  1462680
# 1463700 b'ack'
# timeout resend ack_id:  1463700
# 1464720 b'ack'
# timeout resend ack_id:  1464720
# 1465740 b'ack'
# timeout resend ack_id:  1465740
# 1466760 b'ack'
# timeout resend ack_id:  1466760
# 1467780 b'ack'
# timeout resend ack_id:  1467780
# 1468800 b'ack'
# timeout resend ack_id:  1468800
# 1469820 b'ack'
# timeout resend ack_id:  1469820
# 1470840 b'ack'
# timeout resend ack_id:  1470840
# 1471860 b'ack'
# timeout resend ack_id:  1471860
# 1472880 b'ack'
# timeout resend ack_id:  1472880
# 1473900 b'ack'
# timeout resend ack_id:  1473900
# 1474920 b'ack'
# timeout resend ack_id:  1474920
# 1475940 b'ack'
# timeout resend ack_id:  1475940
# 1476960 b'ack'
# timeout resend ack_id:  1476960
# 1477980 b'ack'
# timeout resend ack_id:  1477980
# 1479000 b'ack'
# timeout resend ack_id:  1479000
# 1480020 b'ack'
# timeout resend ack_id:  1480020
# 1481040 b'ack'
# timeout resend ack_id:  1481040
# 1482060 b'ack'
# timeout resend ack_id:  1482060
# 1483080 b'ack'
# timeout resend ack_id:  1483080
# 1484100 b'ack'
# timeout resend ack_id:  1484100
# 1485120 b'ack'
# timeout resend ack_id:  1485120
# 1486140 b'ack'
# timeout resend ack_id:  1486140
# 1487160 b'ack'
# timeout resend ack_id:  1487160
# 1488180 b'ack'
# timeout resend ack_id:  1488180
# 1489200 b'ack'
# timeout resend ack_id:  1489200
# 1490220 b'ack'
# timeout resend ack_id:  1490220
# 1491240 b'ack'
# timeout resend ack_id:  1491240
# 1492260 b'ack'
# timeout resend ack_id:  1492260
# 1493280 b'ack'
# timeout resend ack_id:  1493280
# 1494300 b'ack'
# timeout resend ack_id:  1494300
# 1495320 b'ack'
# timeout resend ack_id:  1495320
# 1496340 b'ack'
# timeout resend ack_id:  1496340
# 1497360 b'ack'
# timeout resend ack_id:  1497360
# 1498380 b'ack'
# timeout resend ack_id:  1498380
# 1499400 b'ack'
# timeout resend ack_id:  1499400
# 1500420 b'ack'
# timeout resend ack_id:  1500420
# 1501440 b'ack'
# timeout resend ack_id:  1501440
# 1502460 b'ack'
# timeout resend ack_id:  1502460
# 1503480 b'ack'
# timeout resend ack_id:  1503480
# 1504500 b'ack'
# timeout resend ack_id:  1504500
# 1505520 b'ack'
# timeout resend ack_id:  1505520
# 1506540 b'ack'
# timeout resend ack_id:  1506540
# 1507560 b'ack'
# timeout resend ack_id:  1507560
# 1508580 b'ack'
# timeout resend ack_id:  1508580
# 1509600 b'ack'
# timeout resend ack_id:  1509600
# 1510620 b'ack'
# timeout resend ack_id:  1510620
# 1511640 b'ack'
# timeout resend ack_id:  1511640
# 1512660 b'ack'
# timeout resend ack_id:  1512660
# 1513680 b'ack'
# timeout resend ack_id:  1513680
# 1514700 b'ack'
# timeout resend ack_id:  1514700
# 1515720 b'ack'
# timeout resend ack_id:  1515720
# 1516740 b'ack'
# timeout resend ack_id:  1516740
# 1517760 b'ack'
# timeout resend ack_id:  1517760
# 1518780 b'ack'
# timeout resend ack_id:  1518780
# 1519800 b'ack'
# timeout resend ack_id:  1519800
# 1520820 b'ack'
# timeout resend ack_id:  1520820
# 1521840 b'ack'
# timeout resend ack_id:  1521840
# 1522860 b'ack'
# timeout resend ack_id:  1522860
# 1523880 b'ack'
# timeout resend ack_id:  1523880
# 1524900 b'ack'
# timeout resend ack_id:  1524900
# 1525920 b'ack'
# timeout resend ack_id:  1525920
# 1526940 b'ack'
# timeout resend ack_id:  1526940
# 1527960 b'ack'
# timeout resend ack_id:  1527960
# 1528980 b'ack'
# timeout resend ack_id:  1528980
# 1530000 b'ack'
# timeout resend ack_id:  1530000
# 1531020 b'ack'
# timeout resend ack_id:  1531020
# 1532040 b'ack'
# timeout resend ack_id:  1532040
# 1533060 b'ack'
# timeout resend ack_id:  1533060
# 1534080 b'ack'
# timeout resend ack_id:  1534080
# 1535100 b'ack'
# timeout resend ack_id:  1535100
# 1536120 b'ack'
# timeout resend ack_id:  1536120
# 1537140 b'ack'
# timeout resend ack_id:  1537140
# 1538160 b'ack'
# timeout resend ack_id:  1538160
# 1539180 b'ack'
# timeout resend ack_id:  1539180
# 1540200 b'ack'
# timeout resend ack_id:  1540200
# 1541220 b'ack'
# timeout resend ack_id:  1541220
# 1542240 b'ack'
# timeout resend ack_id:  1542240
# 1543260 b'ack'
# timeout resend ack_id:  1543260
# 1544280 b'ack'
# timeout resend ack_id:  1544280
# 1545300 b'ack'
# timeout resend ack_id:  1545300
# 1546320 b'ack'
# timeout resend ack_id:  1546320
# 1547340 b'ack'
# timeout resend ack_id:  1547340
# 1548360 b'ack'
# timeout resend ack_id:  1548360
# 1549380 b'ack'
# timeout resend ack_id:  1549380
# 1550400 b'ack'
# timeout resend ack_id:  1550400
# 1551420 b'ack'
# timeout resend ack_id:  1551420
# 1552440 b'ack'
# timeout resend ack_id:  1552440
# 1553460 b'ack'
# timeout resend ack_id:  1553460
# 1554480 b'ack'
# timeout resend ack_id:  1554480
# 1555500 b'ack'
# timeout resend ack_id:  1555500
# 1556520 b'ack'
# timeout resend ack_id:  1556520
# 1557540 b'ack'
# timeout resend ack_id:  1557540
# 1558560 b'ack'
# timeout resend ack_id:  1558560
# 1559580 b'ack'
# timeout resend ack_id:  1559580
# 1560600 b'ack'
# timeout resend ack_id:  1560600
# 1561620 b'ack'
# timeout resend ack_id:  1561620
# 1562640 b'ack'
# timeout resend ack_id:  1562640
# 1563660 b'ack'
# timeout resend ack_id:  1563660
# 1564680 b'ack'
# timeout resend ack_id:  1564680
# 1565700 b'ack'
# timeout resend ack_id:  1565700
# 1566720 b'ack'
# timeout resend ack_id:  1566720
# 1567740 b'ack'
# timeout resend ack_id:  1567740
# 1568760 b'ack'
# timeout resend ack_id:  1568760
# 1569780 b'ack'
# timeout resend ack_id:  1569780
# 1570800 b'ack'
# timeout resend ack_id:  1570800
# 1571820 b'ack'
# timeout resend ack_id:  1571820
# 1572840 b'ack'
# timeout resend ack_id:  1572840
# 1573860 b'ack'
# timeout resend ack_id:  1573860
# 1574880 b'ack'
# timeout resend ack_id:  1574880
# 1575900 b'ack'
# timeout resend ack_id:  1575900
# 1576920 b'ack'
# timeout resend ack_id:  1576920
# 1577940 b'ack'
# timeout resend ack_id:  1577940
# 1578960 b'ack'
# timeout resend ack_id:  1578960
# 1579980 b'ack'
# timeout resend ack_id:  1579980
# 1581000 b'ack'
# timeout resend ack_id:  1581000
# 1582020 b'ack'
# timeout resend ack_id:  1582020
# 1583040 b'ack'
# timeout resend ack_id:  1583040
# 1584060 b'ack'
# timeout resend ack_id:  1584060
# 1585080 b'ack'
# timeout resend ack_id:  1585080
# 1586100 b'ack'
# timeout resend ack_id:  1586100
# 1587120 b'ack'
# timeout resend ack_id:  1587120
# 1588140 b'ack'
# timeout resend ack_id:  1588140
# 1589160 b'ack'
# timeout resend ack_id:  1589160
# 1590180 b'ack'
# timeout resend ack_id:  1590180
# 1591200 b'ack'
# timeout resend ack_id:  1591200
# 1592220 b'ack'
# timeout resend ack_id:  1592220
# 1593240 b'ack'
# timeout resend ack_id:  1593240
# 1594260 b'ack'
# timeout resend ack_id:  1594260
# 1595280 b'ack'
# timeout resend ack_id:  1595280
# 1596300 b'ack'
# timeout resend ack_id:  1596300
# 1597320 b'ack'
# timeout resend ack_id:  1597320
# 1598340 b'ack'
# timeout resend ack_id:  1598340
# 1599360 b'ack'
# timeout resend ack_id:  1599360
# 1600380 b'ack'
# timeout resend ack_id:  1600380
# 1601400 b'ack'
# timeout resend ack_id:  1601400
# 1602420 b'ack'
# timeout resend ack_id:  1602420
# 1603440 b'ack'
# timeout resend ack_id:  1603440
# 1604460 b'ack'
# timeout resend ack_id:  1604460
# 1605480 b'ack'
# timeout resend ack_id:  1605480
# 1606500 b'ack'
# timeout resend ack_id:  1606500
# 1607520 b'ack'
# timeout resend ack_id:  1607520
# 1608540 b'ack'
# timeout resend ack_id:  1608540
# 1609560 b'ack'
# timeout resend ack_id:  1609560
# 1610580 b'ack'
# timeout resend ack_id:  1610580
# 1611600 b'ack'
# timeout resend ack_id:  1611600
# 1612620 b'ack'
# timeout resend ack_id:  1612620
# 1613640 b'ack'
# timeout resend ack_id:  1613640
# 1614660 b'ack'
# timeout resend ack_id:  1614660
# 1615680 b'ack'
# timeout resend ack_id:  1615680
# 1616700 b'ack'
# timeout resend ack_id:  1616700
# 1617720 b'ack'
# timeout resend ack_id:  1617720
# 1618740 b'ack'
# timeout resend ack_id:  1618740
# 1619760 b'ack'
# timeout resend ack_id:  1619760
# 1620780 b'ack'
# timeout resend ack_id:  1620780
# 1621800 b'ack'
# timeout resend ack_id:  1621800
# 1622820 b'ack'
# timeout resend ack_id:  1622820
# 1623840 b'ack'
# timeout resend ack_id:  1623840
# 1624860 b'ack'
# timeout resend ack_id:  1624860
# 1625880 b'ack'
# timeout resend ack_id:  1625880
# 1626900 b'ack'
# timeout resend ack_id:  1626900
# 1627920 b'ack'
# timeout resend ack_id:  1627920
# 1628940 b'ack'
# timeout resend ack_id:  1628940
# 1629960 b'ack'
# timeout resend ack_id:  1629960
# 1630980 b'ack'
# timeout resend ack_id:  1630980
# 1632000 b'ack'
# timeout resend ack_id:  1632000
# 1633020 b'ack'
# timeout resend ack_id:  1633020
# 1634040 b'ack'
# timeout resend ack_id:  1634040
# 1635060 b'ack'
# timeout resend ack_id:  1635060
# 1636080 b'ack'
# timeout resend ack_id:  1636080
# 1637100 b'ack'
# timeout resend ack_id:  1637100
# 1638120 b'ack'
# timeout resend ack_id:  1638120
# 1639140 b'ack'
# timeout resend ack_id:  1639140
# 1640160 b'ack'
# timeout resend ack_id:  1640160
# 1641180 b'ack'
# timeout resend ack_id:  1641180
# 1642200 b'ack'
# timeout resend ack_id:  1642200
# 1643220 b'ack'
# timeout resend ack_id:  1643220
# 1644240 b'ack'
# timeout resend ack_id:  1644240
# 1645260 b'ack'
# timeout resend ack_id:  1645260
# 1646280 b'ack'
# timeout resend ack_id:  1646280
# 1647300 b'ack'
# timeout resend ack_id:  1647300
# 1648320 b'ack'
# timeout resend ack_id:  1648320
# 1649340 b'ack'
# timeout resend ack_id:  1649340
# 1650360 b'ack'
# timeout resend ack_id:  1650360
# 1651380 b'ack'
# timeout resend ack_id:  1651380
# 1652400 b'ack'
# timeout resend ack_id:  1652400
# 1730940 b'ack'
# timeout resend ack_id:  1730940
# 1731960 b'ack'
# timeout resend ack_id:  1731960
# 1732980 b'ack'
# timeout resend ack_id:  1732980
# 1734000 b'ack'
# timeout resend ack_id:  1734000
# 1735020 b'ack'
# timeout resend ack_id:  1735020
# 1736040 b'ack'
# timeout resend ack_id:  1736040
# 1737060 b'ack'
# timeout resend ack_id:  1737060
# 1738080 b'ack'
# timeout resend ack_id:  1738080
# 1739100 b'ack'
# timeout resend ack_id:  1739100
# 1740120 b'ack'
# timeout resend ack_id:  1740120
# 1741140 b'ack'
# timeout resend ack_id:  1741140
# 1742160 b'ack'
# timeout resend ack_id:  1742160
# 1743180 b'ack'
# timeout resend ack_id:  1743180
# 1744200 b'ack'
# timeout resend ack_id:  1744200
# 1745220 b'ack'
# timeout resend ack_id:  1745220
# 1746240 b'ack'
# timeout resend ack_id:  1746240
# 1747260 b'ack'
# timeout resend ack_id:  1747260
# 1748280 b'ack'
# timeout resend ack_id:  1748280
# 1749300 b'ack'
# timeout resend ack_id:  1749300
# 1750320 b'ack'
# timeout resend ack_id:  1750320
# 1751340 b'ack'
# timeout resend ack_id:  1751340
# 1752360 b'ack'
# timeout resend ack_id:  1752360
# 1753380 b'ack'
# timeout resend ack_id:  1753380
# 1754400 b'ack'
# timeout resend ack_id:  1754400
# 1755420 b'ack'
# timeout resend ack_id:  1755420
# 1756440 b'ack'
# timeout resend ack_id:  1756440
# 1757460 b'ack'
# timeout resend ack_id:  1757460
# 1758480 b'ack'
# timeout resend ack_id:  1758480
# 1759500 b'ack'
# timeout resend ack_id:  1759500
# 1760520 b'ack'
# timeout resend ack_id:  1760520
# 1761540 b'ack'
# timeout resend ack_id:  1761540
# 1762560 b'ack'
# timeout resend ack_id:  1762560
# 1763580 b'ack'
# timeout resend ack_id:  1763580
# 1764600 b'ack'
# timeout resend ack_id:  1764600
# 1765620 b'ack'
# timeout resend ack_id:  1765620
# 1766640 b'ack'
# timeout resend ack_id:  1766640
# 1767660 b'ack'
# timeout resend ack_id:  1767660
# 1768680 b'ack'
# timeout resend ack_id:  1768680
# 1769700 b'ack'
# timeout resend ack_id:  1769700
# 1770720 b'ack'
# timeout resend ack_id:  1770720
# 1771740 b'ack'
# timeout resend ack_id:  1771740
# 1772760 b'ack'
# timeout resend ack_id:  1772760
# 1773780 b'ack'
# timeout resend ack_id:  1773780
# 1774800 b'ack'
# timeout resend ack_id:  1774800
# 1775820 b'ack'
# timeout resend ack_id:  1775820
# 1776840 b'ack'
# timeout resend ack_id:  1776840
# 1777860 b'ack'
# timeout resend ack_id:  1777860
# 1778880 b'ack'
# timeout resend ack_id:  1778880
# 1779900 b'ack'
# timeout resend ack_id:  1779900
# 1780920 b'ack'
# timeout resend ack_id:  1780920
# 1781940 b'ack'
# timeout resend ack_id:  1781940
# 1782960 b'ack'
# timeout resend ack_id:  1782960
# 1783980 b'ack'
# timeout resend ack_id:  1783980
# 1785000 b'ack'
# timeout resend ack_id:  1785000
# 1786020 b'ack'
# timeout resend ack_id:  1786020
# 1787040 b'ack'
# timeout resend ack_id:  1787040
# 1788060 b'ack'
# timeout resend ack_id:  1788060
# 1789080 b'ack'
# timeout resend ack_id:  1789080
# 1790100 b'ack'
# timeout resend ack_id:  1790100
# 1791120 b'ack'
# timeout resend ack_id:  1791120
# 1792140 b'ack'
# timeout resend ack_id:  1792140
# 1793160 b'ack'
# timeout resend ack_id:  1793160
# 1794180 b'ack'
# timeout resend ack_id:  1794180
# 1795200 b'ack'
# timeout resend ack_id:  1795200
# 1796220 b'ack'
# timeout resend ack_id:  1796220
# 1797240 b'ack'
# timeout resend ack_id:  1797240
# 1798260 b'ack'
# timeout resend ack_id:  1798260
# 1799280 b'ack'
# timeout resend ack_id:  1799280
# 1800300 b'ack'
# timeout resend ack_id:  1800300
# 1801320 b'ack'
# timeout resend ack_id:  1801320
# 1802340 b'ack'
# timeout resend ack_id:  1802340
# 1814580 b'ack'
# timeout resend ack_id:  1814580
# 1847220 b'ack'
# timeout resend ack_id:  1847220
# 1848240 b'ack'
# timeout resend ack_id:  1848240
# 1849260 b'ack'
# timeout resend ack_id:  1849260
# 1850280 b'ack'
# timeout resend ack_id:  1850280
# 1851300 b'ack'
# timeout resend ack_id:  1851300
# 1852320 b'ack'
# timeout resend ack_id:  1852320
# 1853340 b'ack'
# timeout resend ack_id:  1853340
# 1854360 b'ack'
# timeout resend ack_id:  1854360
# 1855380 b'ack'
# timeout resend ack_id:  1855380
# 1856400 b'ack'
# timeout resend ack_id:  1856400
# 1857420 b'ack'
# timeout resend ack_id:  1857420
# 1858440 b'ack'
# timeout resend ack_id:  1858440
# 1859460 b'ack'
# timeout resend ack_id:  1859460
# 1860480 b'ack'
# timeout resend ack_id:  1860480
# 1861500 b'ack'
# timeout resend ack_id:  1861500
# 1862520 b'ack'
# timeout resend ack_id:  1862520
# 1863540 b'ack'
# timeout resend ack_id:  1863540
# 1864560 b'ack'
# timeout resend ack_id:  1864560
# 1865580 b'ack'
# timeout resend ack_id:  1865580
# 1866600 b'ack'
# timeout resend ack_id:  1866600
# 1867620 b'ack'
# timeout resend ack_id:  1867620
# 1868640 b'ack'
# timeout resend ack_id:  1868640
# 1869660 b'ack'
# timeout resend ack_id:  1869660
# 1870680 b'ack'
# timeout resend ack_id:  1870680
# 1871700 b'ack'
# timeout resend ack_id:  1871700
# 1872720 b'ack'
# timeout resend ack_id:  1872720
# 1873740 b'ack'
# timeout resend ack_id:  1873740
# 1874760 b'ack'
# timeout resend ack_id:  1874760
# 1875780 b'ack'
# timeout resend ack_id:  1875780
# 1876800 b'ack'
# timeout resend ack_id:  1876800
# 1877820 b'ack'
# timeout resend ack_id:  1877820
# 1878840 b'ack'
# timeout resend ack_id:  1878840
# 1879860 b'ack'
# timeout resend ack_id:  1879860
# 1880880 b'ack'
# timeout resend ack_id:  1880880
# 1881900 b'ack'
# timeout resend ack_id:  1881900
# 1882920 b'ack'
# timeout resend ack_id:  1882920
# 1883940 b'ack'
# timeout resend ack_id:  1883940
# 1884960 b'ack'
# timeout resend ack_id:  1884960
# 1885980 b'ack'
# timeout resend ack_id:  1885980
# 1887000 b'ack'
# timeout resend ack_id:  1887000
# 1888020 b'ack'
# timeout resend ack_id:  1888020
# 1889040 b'ack'
# timeout resend ack_id:  1889040
# 1890060 b'ack'
# timeout resend ack_id:  1890060
# 1891080 b'ack'
# timeout resend ack_id:  1891080
# 1892100 b'ack'
# timeout resend ack_id:  1892100
# 1893120 b'ack'
# timeout resend ack_id:  1893120
# 1894140 b'ack'
# timeout resend ack_id:  1894140
# 1895160 b'ack'
# timeout resend ack_id:  1895160
# 1896180 b'ack'
# timeout resend ack_id:  1896180
# 1897200 b'ack'
# timeout resend ack_id:  1897200
# 1898220 b'ack'
# timeout resend ack_id:  1898220
# 1899240 b'ack'
# timeout resend ack_id:  1899240
# 1900260 b'ack'
# timeout resend ack_id:  1900260
# 1901280 b'ack'
# timeout resend ack_id:  1901280
# 1902300 b'ack'
# timeout resend ack_id:  1902300
# 1903320 b'ack'
# timeout resend ack_id:  1903320
# 1904340 b'ack'
# timeout resend ack_id:  1904340
# 1905360 b'ack'
# timeout resend ack_id:  1905360
# 1906380 b'ack'
# timeout resend ack_id:  1906380
# 1907400 b'ack'
# timeout resend ack_id:  1907400
# 1908420 b'ack'
# ...
# timeout resend ack_id:  4960260
# 4961280 b'ack'
# timeout resend ack_id:  4961280
# 4962300 b'ack'
# timeout resend ack_id:  4962300
# 4963320 b'ack'
# timeout resend ack_id:  4963320
# 4964340 b'ack'
# timeout resend ack_id:  4964340
# 4965360 b'ack'
# timeout resend ack_id:  4965360
# 4966380 b'ack'
# timeout resend ack_id:  4966380
# 4967400 b'ack'
# timeout resend ack_id:  4967400
# 4968420 b'ack'
# timeout resend ack_id:  4968420
# 4969440 b'ack'
# timeout resend ack_id:  4969440
# 4970460 b'ack'
# timeout resend ack_id:  4970460
# 4971480 b'ack'
# timeout resend ack_id:  4971480
# 4972500 b'ack'
# timeout resend ack_id:  4972500
# 4973520 b'ack'
# timeout resend ack_id:  4973520
# 4974540 b'ack'
# timeout resend ack_id:  4974540
# 4975560 b'ack'
# timeout resend ack_id:  4975560
# 4976580 b'ack'
# timeout resend ack_id:  4976580
# 4977600 b'ack'
# timeout resend ack_id:  4977600
# 4978620 b'ack'
# timeout resend ack_id:  4978620
# 4979640 b'ack'
# timeout resend ack_id:  4979640
# 4980660 b'ack'
# timeout resend ack_id:  4980660
# 4981680 b'ack'
# timeout resend ack_id:  4981680
# 4982700 b'ack'
# timeout resend ack_id:  4982700
# 4983720 b'ack'
# timeout resend ack_id:  4983720
# 4984740 b'ack'
# timeout resend ack_id:  4984740
# 4985760 b'ack'
# timeout resend ack_id:  4985760
# 4986780 b'ack'
# timeout resend ack_id:  4986780
# 4987800 b'ack'
# timeout resend ack_id:  4987800
# 4988820 b'ack'
# timeout resend ack_id:  4988820
# 4989840 b'ack'
# timeout resend ack_id:  4989840
# 4990860 b'ack'
# timeout resend ack_id:  4990860
# 4991880 b'ack'
# timeout resend ack_id:  4991880
# 4992900 b'ack'
# timeout resend ack_id:  4992900
# 4993920 b'ack'
# timeout resend ack_id:  4993920
# 4994940 b'ack'
# timeout resend ack_id:  4994940
# 4995960 b'ack'
# timeout resend ack_id:  4995960
# 4996980 b'ack'
# timeout resend ack_id:  4996980
# 4998000 b'ack'
# timeout resend ack_id:  4998000
# 4999020 b'ack'
# timeout resend ack_id:  4999020
# 5000040 b'ack'
# timeout resend ack_id:  5000040
# 5001060 b'ack'
# timeout resend ack_id:  5001060
# 5002080 b'ack'
# timeout resend ack_id:  5002080
# 5003100 b'ack'
# timeout resend ack_id:  5003100
# 5004120 b'ack'
# timeout resend ack_id:  5004120
# 5005140 b'ack'
# timeout resend ack_id:  5005140
# 5006160 b'ack'
# timeout resend ack_id:  5006160
# 5007180 b'ack'
# timeout resend ack_id:  5007180
# 5008200 b'ack'
# timeout resend ack_id:  5008200
# 5009220 b'ack'
# timeout resend ack_id:  5009220
# 5010240 b'ack'
# timeout resend ack_id:  5010240
# 5011260 b'ack'
# timeout resend ack_id:  5011260
# 5012280 b'ack'
# timeout resend ack_id:  5012280
# 5013300 b'ack'
# timeout resend ack_id:  5013300
# 5014320 b'ack'
# timeout resend ack_id:  5014320
# 5015340 b'ack'
# timeout resend ack_id:  5015340
# 5016360 b'ack'
# timeout resend ack_id:  5016360
# 5017380 b'ack'
# timeout resend ack_id:  5017380
# 5018400 b'ack'
# timeout resend ack_id:  5018400
# 5019420 b'ack'
# timeout resend ack_id:  5019420
# 5020440 b'ack'
# timeout resend ack_id:  5020440
# 5021460 b'ack'
# timeout resend ack_id:  5021460
# 5022480 b'ack'
# timeout resend ack_id:  5022480
# 5023500 b'ack'
# timeout resend ack_id:  5023500
# 5024520 b'ack'
# timeout resend ack_id:  5024520
# 5025540 b'ack'
# timeout resend ack_id:  5025540
# 5026560 b'ack'
# timeout resend ack_id:  5026560
# 5027580 b'ack'
# timeout resend ack_id:  5027580
# 5028600 b'ack'
# timeout resend ack_id:  5028600
# 5029620 b'ack'
# timeout resend ack_id:  5029620
# 5030640 b'ack'
# timeout resend ack_id:  5030640
# 5031660 b'ack'
# timeout resend ack_id:  5031660
# 5032680 b'ack'
# timeout resend ack_id:  5032680
# 5033700 b'ack'
# timeout resend ack_id:  5033700
# 5045940 b'ack'
# timeout resend ack_id:  5045940
# 5046960 b'ack'
# timeout resend ack_id:  5046960
# 5047980 b'ack'
# timeout resend ack_id:  5047980
# 5049000 b'ack'
# timeout resend ack_id:  5049000
# 5050020 b'ack'
# timeout resend ack_id:  5050020
# 5051040 b'ack'
# timeout resend ack_id:  5051040
# 5052060 b'ack'
# timeout resend ack_id:  5052060
# 5053080 b'ack'
# timeout resend ack_id:  5053080
# 5054100 b'ack'
# timeout resend ack_id:  5054100
# 5055120 b'ack'
# timeout resend ack_id:  5055120
# 5056140 b'ack'
# timeout resend ack_id:  5056140
# 5057160 b'ack'
# timeout resend ack_id:  5057160
# 5058180 b'ack'
# timeout resend ack_id:  5058180
# 5059200 b'ack'
# timeout resend ack_id:  5059200
# 5060220 b'ack'
# timeout resend ack_id:  5060220
# 5061240 b'ack'
# timeout resend ack_id:  5061240
# 5062260 b'ack'
# timeout resend ack_id:  5062260
# 5063280 b'ack'
# timeout resend ack_id:  5063280
# 5064300 b'ack'
# timeout resend ack_id:  5064300
# 5065320 b'ack'
# timeout resend ack_id:  5065320
# 5066340 b'ack'
# timeout resend ack_id:  5066340
# 5067360 b'ack'
# timeout resend ack_id:  5067360
# 5068380 b'ack'
# timeout resend ack_id:  5068380
# 5069400 b'ack'
# timeout resend ack_id:  5069400
# 5070420 b'ack'
# timeout resend ack_id:  5070420
# 5071440 b'ack'
# timeout resend ack_id:  5071440
# 5072460 b'ack'
# timeout resend ack_id:  5072460
# 5073480 b'ack'
# timeout resend ack_id:  5073480
# 5074500 b'ack'
# timeout resend ack_id:  5074500
# 5075520 b'ack'
# timeout resend ack_id:  5075520
# 5076540 b'ack'
# timeout resend ack_id:  5076540
# 5077560 b'ack'
# timeout resend ack_id:  5077560
# 5078580 b'ack'
# timeout resend ack_id:  5078580
# 5079600 b'ack'
# timeout resend ack_id:  5079600
# 5080620 b'ack'
# timeout resend ack_id:  5080620
# 5081640 b'ack'
# timeout resend ack_id:  5081640
# 5082660 b'ack'
# timeout resend ack_id:  5082660
# 5083680 b'ack'
# timeout resend ack_id:  5083680
# 5084700 b'ack'
# timeout resend ack_id:  5084700
# 5085720 b'ack'
# timeout resend ack_id:  5085720
# 5086740 b'ack'
# timeout resend ack_id:  5086740
# 5087760 b'ack'
# timeout resend ack_id:  5087760
# 5088780 b'ack'
# timeout resend ack_id:  5088780
# 5089800 b'ack'
# timeout resend ack_id:  5089800
# 5090820 b'ack'
# timeout resend ack_id:  5090820
# 5091840 b'ack'
# timeout resend ack_id:  5091840
# 5092860 b'ack'
# timeout resend ack_id:  5092860
# 5093880 b'ack'
# timeout resend ack_id:  5093880
# 5096940 b'ack'
# timeout resend ack_id:  5096940
# 5097960 b'ack'
# timeout resend ack_id:  5097960
# 5098980 b'ack'
# timeout resend ack_id:  5098980
# 5100000 b'ack'
# timeout resend ack_id:  5100000
# 5101020 b'ack'
# timeout resend ack_id:  5101020
# 5102040 b'ack'
# timeout resend ack_id:  5102040
# 5103060 b'ack'
# timeout resend ack_id:  5103060
# 5104080 b'ack'
# timeout resend ack_id:  5104080
# 5105100 b'ack'
# timeout resend ack_id:  5105100
# 5106120 b'ack'
# timeout resend ack_id:  5106120
# 5107140 b'ack'
# timeout resend ack_id:  5107140
# 5108160 b'ack'
# timeout resend ack_id:  5108160
# 5109180 b'ack'
# timeout resend ack_id:  5109180
# 5110200 b'ack'
# timeout resend ack_id:  5110200
# 5111220 b'ack'
# timeout resend ack_id:  5111220
# 5112240 b'ack'
# timeout resend ack_id:  5112240
# 5113260 b'ack'
# timeout resend ack_id:  5113260
# 5114280 b'ack'
# timeout resend ack_id:  5114280
# 5115300 b'ack'
# timeout resend ack_id:  5115300
# 5116320 b'ack'
# timeout resend ack_id:  5116320
# 5117340 b'ack'
# timeout resend ack_id:  5117340
# 5118360 b'ack'
# timeout resend ack_id:  5118360
# 5119380 b'ack'
# timeout resend ack_id:  5119380
# 5120400 b'ack'
# timeout resend ack_id:  5120400
# 5121420 b'ack'
# timeout resend ack_id:  5121420
# 5122440 b'ack'
# timeout resend ack_id:  5122440
# 5123460 b'ack'
# timeout resend ack_id:  5123460
# 5124480 b'ack'
# timeout resend ack_id:  5124480
# 5125500 b'ack'
# timeout resend ack_id:  5125500
# 5126520 b'ack'
# timeout resend ack_id:  5126520
# 5127540 b'ack'
# timeout resend ack_id:  5127540
# 5128560 b'ack'
# timeout resend ack_id:  5128560
# 5129580 b'ack'
# timeout resend ack_id:  5129580
# 5130600 b'ack'
# timeout resend ack_id:  5130600
# 5131620 b'ack'
# timeout resend ack_id:  5131620
# 5132640 b'ack'
# timeout resend ack_id:  5132640
# 5133660 b'ack'
# timeout resend ack_id:  5133660
# 5134680 b'ack'
# timeout resend ack_id:  5134680
# 5135700 b'ack'
# timeout resend ack_id:  5135700
# 5136720 b'ack'
# timeout resend ack_id:  5136720
# 5137740 b'ack'
# timeout resend ack_id:  5137740
# 5138760 b'ack'
# timeout resend ack_id:  5138760
# 5139780 b'ack'
# timeout resend ack_id:  5139780
# 5140800 b'ack'
# timeout resend ack_id:  5140800
# 5141820 b'ack'
# timeout resend ack_id:  5141820
# 5142840 b'ack'
# timeout resend ack_id:  5142840
# 5143860 b'ack'
# timeout resend ack_id:  5143860
# 5144880 b'ack'
# timeout resend ack_id:  5144880
# 5145900 b'ack'
# timeout resend ack_id:  5145900
# 5146920 b'ack'
# timeout resend ack_id:  5146920
# 5147940 b'ack'
# timeout resend ack_id:  5147940
# 5148960 b'ack'
# timeout resend ack_id:  5148960
# 5149980 b'ack'
# timeout resend ack_id:  5149980
# 5151000 b'ack'
# timeout resend ack_id:  5151000
# 5152020 b'ack'
# timeout resend ack_id:  5152020
# 5153040 b'ack'
# timeout resend ack_id:  5153040
# 5154060 b'ack'
# timeout resend ack_id:  5154060
# 5155080 b'ack'
# timeout resend ack_id:  5155080
# 5156100 b'ack'
# timeout resend ack_id:  5156100
# 5157120 b'ack'
# timeout resend ack_id:  5157120
# 5158140 b'ack'
# timeout resend ack_id:  5158140
# 5159160 b'ack'
# timeout resend ack_id:  5159160
# 5160180 b'ack'
# timeout resend ack_id:  5160180
# 5161200 b'ack'
# timeout resend ack_id:  5161200
# 5162220 b'ack'
# timeout resend ack_id:  5162220
# 5163240 b'ack'
# timeout resend ack_id:  5163240
# 5164260 b'ack'
# timeout resend ack_id:  5164260
# 5165280 b'ack'
# timeout resend ack_id:  5165280
# 5166300 b'ack'
# timeout resend ack_id:  5166300
# 5167320 b'ack'
# timeout resend ack_id:  5167320
# 5168340 b'ack'
# timeout resend ack_id:  5168340
# 5169360 b'ack'
# timeout resend ack_id:  5169360
# 5170380 b'ack'
# timeout resend ack_id:  5170380
# 5171400 b'ack'
# timeout resend ack_id:  5171400
# 5172420 b'ack'
# timeout resend ack_id:  5172420
# 5173440 b'ack'
# timeout resend ack_id:  5173440
# 5174460 b'ack'
# timeout resend ack_id:  5174460
# 5175480 b'ack'
# timeout resend ack_id:  5175480
# 5176500 b'ack'
# timeout resend ack_id:  5176500
# 5177520 b'ack'
# timeout resend ack_id:  5177520
# 5178540 b'ack'
# timeout resend ack_id:  5178540
# 5179560 b'ack'
# timeout resend ack_id:  5179560
# 5180580 b'ack'
# timeout resend ack_id:  5180580
# 5181600 b'ack'
# timeout resend ack_id:  5181600
# 5182620 b'ack'
# timeout resend ack_id:  5182620
# 5183640 b'ack'
# timeout resend ack_id:  5183640
# 5184660 b'ack'
# timeout resend ack_id:  5184660
# 5185680 b'ack'
# timeout resend ack_id:  5185680
# 5186700 b'ack'
# timeout resend ack_id:  5186700
# 5187720 b'ack'
# timeout resend ack_id:  5187720
# 5188740 b'ack'
# timeout resend ack_id:  5188740
# 5189760 b'ack'
# timeout resend ack_id:  5189760
# 5190780 b'ack'
# timeout resend ack_id:  5190780
# 5191800 b'ack'
# timeout resend ack_id:  5191800
# 5192820 b'ack'
# timeout resend ack_id:  5192820
# 5193840 b'ack'
# timeout resend ack_id:  5193840
# 5194860 b'ack'
# timeout resend ack_id:  5194860
# 5195880 b'ack'
# timeout resend ack_id:  5195880
# 5196900 b'ack'
# timeout resend ack_id:  5196900
# 5197920 b'ack'
# timeout resend ack_id:  5197920
# 5198940 b'ack'
# timeout resend ack_id:  5198940
# 5199960 b'ack'
# timeout resend ack_id:  5199960
# 5200980 b'ack'
# timeout resend ack_id:  5200980
# 5202000 b'ack'
# timeout resend ack_id:  5202000
# 5203020 b'ack'
# timeout resend ack_id:  5203020
# 5204040 b'ack'
# timeout resend ack_id:  5204040
# 5205060 b'ack'
# timeout resend ack_id:  5205060
# 5206080 b'ack'
# timeout resend ack_id:  5206080
# 5207100 b'ack'
# timeout resend ack_id:  5207100
# 5208120 b'ack'
# timeout resend ack_id:  5208120
# 5209140 b'ack'
# timeout resend ack_id:  5209140
# 5210160 b'ack'
# timeout resend ack_id:  5210160
# 5211180 b'ack'
# timeout resend ack_id:  5211180
# 5212200 b'ack'
# timeout resend ack_id:  5212200
# 5213220 b'ack'
# timeout resend ack_id:  5213220
# 5214240 b'ack'
# timeout resend ack_id:  5214240
# 5215260 b'ack'
# timeout resend ack_id:  5215260
# 5216280 b'ack'
# timeout resend ack_id:  5216280
# 5217300 b'ack'
# timeout resend ack_id:  5217300
# 5218320 b'ack'
# timeout resend ack_id:  5218320
# 5320320 5319693 :D
#
# timeout resend ack_id:  5219340
# 5220360 b'ack'
# timeout resend ack_id:  5220360
# 5221380 b'ack'
# timeout resend ack_id:  5221380
# 5222400 b'ack'
# timeout resend ack_id:  5222400
# 5223420 b'ack'
# timeout resend ack_id:  5223420
# 5224440 b'ack'
# timeout resend ack_id:  5224440
# 5225460 b'ack'
# timeout resend ack_id:  5225460
# 5226480 b'ack'
# timeout resend ack_id:  5226480
# 5227500 b'ack'
# timeout resend ack_id:  5227500
# 5228520 b'ack'
# timeout resend ack_id:  5228520
# 5229540 b'ack'
# timeout resend ack_id:  5229540
# 5230560 b'ack'
# timeout resend ack_id:  5230560
# 5231580 b'ack'
# timeout resend ack_id:  5231580
# 5232600 b'ack'
# timeout resend ack_id:  5232600
# 5233620 b'ack'
# timeout resend ack_id:  5233620
# 5234640 b'ack'
# timeout resend ack_id:  5234640
# 5235660 b'ack'
# timeout resend ack_id:  5235660
# 5236680 b'ack'
# timeout resend ack_id:  5236680
# 5237700 b'ack'
# timeout resend ack_id:  5237700
# 5238720 b'ack'
# timeout resend ack_id:  5238720
# 5239740 b'ack'
# timeout resend ack_id:  5239740
# 5240760 b'ack'
# timeout resend ack_id:  5240760
# 5241780 b'ack'
# timeout resend ack_id:  5241780
# 5242800 b'ack'
# timeout resend ack_id:  5242800
# 5243820 b'ack'
# timeout resend ack_id:  5243820
# 5244840 b'ack'
# timeout resend ack_id:  5244840
# 5245860 b'ack'
# timeout resend ack_id:  5245860
# 5246880 b'ack'
# timeout resend ack_id:  5246880
# 5247900 b'ack'
# timeout resend ack_id:  5247900
# 5248920 b'ack'
# timeout resend ack_id:  5248920
# 5249940 b'ack'
# timeout resend ack_id:  5249940
# 5250960 b'ack'
# timeout resend ack_id:  5250960
# 5251980 b'ack'
# timeout resend ack_id:  5251980
# 5253000 b'ack'
# timeout resend ack_id:  5253000
# 5254020 b'ack'
# timeout resend ack_id:  5254020
# 5255040 b'ack'
# timeout resend ack_id:  5255040
# 5256060 b'ack'
# timeout resend ack_id:  5256060
# 5257080 b'ack'
# timeout resend ack_id:  5257080
# 5258100 b'ack'
# timeout resend ack_id:  5258100
# 5259120 b'ack'
# timeout resend ack_id:  5259120
# 5260140 b'ack'
# timeout resend ack_id:  5260140
# 5261160 b'ack'
# timeout resend ack_id:  5261160
# 5262180 b'ack'
# timeout resend ack_id:  5262180
# 5263200 b'ack'
# timeout resend ack_id:  5263200
# 5264220 b'ack'
# timeout resend ack_id:  5264220
# 5265240 b'ack'
# timeout resend ack_id:  5265240
# 5266260 b'ack'
# timeout resend ack_id:  5266260
# 5267280 b'ack'
# timeout resend ack_id:  5267280
# 5268300 b'ack'
# timeout resend ack_id:  5268300
# 5269320 b'ack'
# timeout resend ack_id:  5269320
# 5270340 b'ack'
# timeout resend ack_id:  5270340
# 5271360 b'ack'
# timeout resend ack_id:  5271360
# 5272380 b'ack'
# timeout resend ack_id:  5272380
# 5273400 b'ack'
# timeout resend ack_id:  5273400
# 5274420 b'ack'
# timeout resend ack_id:  5274420
# 5275440 b'ack'
# timeout resend ack_id:  5275440
# 5276460 b'ack'
# timeout resend ack_id:  5276460
# 5277480 b'ack'
# timeout resend ack_id:  5277480
# 5278500 b'ack'
# timeout resend ack_id:  5278500
# 5279520 b'ack'
# timeout resend ack_id:  5279520
# 5280540 b'ack'
# timeout resend ack_id:  5280540
# 5281560 b'ack'
# timeout resend ack_id:  5281560
# 5282580 b'ack'
# timeout resend ack_id:  5282580
# 5283600 b'ack'
# timeout resend ack_id:  5283600
# 5284620 b'ack'
# timeout resend ack_id:  5284620
# 5285640 b'ack'
# timeout resend ack_id:  5285640
# 5286660 b'ack'
# timeout resend ack_id:  5286660
# 5287680 b'ack'
# timeout resend ack_id:  5287680
# 5288700 b'ack'
# timeout resend ack_id:  5288700
# 5289720 b'ack'
# timeout resend ack_id:  5289720
# 5290740 b'ack'
# timeout resend ack_id:  5290740
# 5291760 b'ack'
# timeout resend ack_id:  5291760
# 5292780 b'ack'
# timeout resend ack_id:  5292780
# 5293800 b'ack'
# timeout resend ack_id:  5293800
# 5294820 b'ack'
# timeout resend ack_id:  5294820
# 5295840 b'ack'
# timeout resend ack_id:  5295840
# 5296860 b'ack'
# timeout resend ack_id:  5296860
# 5297880 b'ack'
# timeout resend ack_id:  5297880
# 5298900 b'ack'
# timeout resend ack_id:  5298900
# 5299920 b'ack'
# timeout resend ack_id:  5299920
# 5300940 b'ack'
# timeout resend ack_id:  5300940
# 5301960 b'ack'
# timeout resend ack_id:  5301960
# 5302980 b'ack'
# timeout resend ack_id:  5302980
# 5304000 b'ack'
# timeout resend ack_id:  5304000
# 5305020 b'ack'
# timeout resend ack_id:  5305020
# 5306040 b'ack'
# timeout resend ack_id:  5306040
# 5307060 b'ack'
# timeout resend ack_id:  5307060
# 5308080 b'ack'
# timeout resend ack_id:  5308080
# 5309100 b'ack'
# timeout resend ack_id:  5309100
# 5310120 b'ack'
# timeout resend ack_id:  5310120
# 5311140 b'ack'
# timeout resend ack_id:  5311140
# 5312160 b'ack'
# timeout resend ack_id:  5312160
# 5313180 b'ack'
# timeout resend ack_id:  5313180
# 5314200 b'ack'
# timeout resend ack_id:  5314200
# 5315220 b'ack'
# timeout resend ack_id:  5315220
# 5316240 b'ack'
# timeout resend ack_id:  5316240
# 5317260 b'ack'
# timeout resend ack_id:  5317260
# 5318280 b'ack'
# timeout resend ack_id:  5318280
# 5319300 b'ack'
# timeout resend ack_id:  5319300
# 51266.76, 0.29, 174616.9

# %% [markdown]
# 51266.76, 0.29, 174616.9 1.44s
